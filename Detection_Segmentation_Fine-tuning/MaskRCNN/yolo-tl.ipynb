# %%
import pandas as pd
import os
import json
from PIL import Image

IMG_DIR = "/kaggle/input/datasets/dipsy32/sample-dataset/sample_35k/images"
ANNO_DIR = "/kaggle/input/datasets/dipsy32/sample-dataset/sample_35k/annos"

train_df = pd.read_csv("/kaggle/input/datasets/dipsy32/training-datasets/train_annotations.csv")
val_df = pd.read_csv("/kaggle/input/datasets/dipsy32/training-datasets/val_annotations.csv")
test_df = pd.read_csv("/kaggle/input/datasets/dipsy32/training-datasets/test_annotations.csv")

print(len(train_df), len(val_df), len(test_df))
# Out:
# 39241 8386 8453

# %%
classes = [
    "long sleeve top",
    "short sleeve top",
    "shorts",
    "skirt",
    "trousers"
]

class_to_id = {c:i for i,c in enumerate(classes)}

# %%
os.makedirs("/kaggle/working/yolo/seg/train/images", exist_ok=True)
os.makedirs("/kaggle/working/yolo/seg/train/labels", exist_ok=True)

os.makedirs("/kaggle/working/yolo/seg/val/images", exist_ok=True)
os.makedirs("/kaggle/working/yolo/seg/val/labels", exist_ok=True)

# %%
import os
import numpy as np

def compute_class_weights(label_dir, num_classes=5):
    """
    Scan all YOLO label .txt files in label_dir and compute
    inverse-frequency class weights.

    Returns
    -------
    weights : np.ndarray, shape (num_classes,)
        weights[i] = total_instances / (num_classes * count_i)
        Rare classes get higher weight, frequent classes lower.
    counts  : np.ndarray  -- raw instance counts per class
    """
    counts = np.zeros(num_classes, dtype=np.float64)

    for fname in os.listdir(label_dir):
        if not fname.endswith(".txt"):
            continue
        with open(os.path.join(label_dir, fname)) as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                cls_id = int(line.split()[0])
                if 0 <= cls_id < num_classes:
                    counts[cls_id] += 1

    total = counts.sum()
    if total == 0:
        raise ValueError(f"No label files found in '{label_dir}'. Run process_split / process_segmentation first.")
    # Guard against zero-count classes: assign weight = max_weight
    safe_counts = np.where(counts > 0, counts, 1.0)  # avoid div-by-zero in np.divide
    weights = np.where(counts > 0,
                       total / (num_classes * safe_counts),
                       total / num_classes)

    # Normalize so mean weight == 1  (keeps loss scale stable)
    weights = weights / weights.mean()
    return weights, counts

# %%
from torch.utils.data import WeightedRandomSampler

def make_weighted_sampler(label_dir, num_classes=5):
    """
    Build a WeightedRandomSampler that over-samples images containing
    rare classes and under-samples images containing frequent ones.

    Each image's weight = max inverse-frequency weight across all classes
    present in that image — so an image containing a rare class is drawn
    more often regardless of how many common-class instances it also has.
    """
    label_files = sorted(
        f for f in os.listdir(label_dir) if f.endswith(".txt")
    )

    if not label_files:
        raise ValueError(f"No label files found in '{label_dir}'")

    # Compute per-class inverse-frequency weights from the full set
    _, counts = compute_class_weights(label_dir, num_classes)
    total = counts.sum()
    safe  = np.where(counts > 0, counts, 1.0)
    inv_freq = np.where(counts > 0, total / (num_classes * safe), total / num_classes)
    inv_freq = inv_freq / inv_freq.mean()   # normalize so mean = 1

    sample_weights = []
    for fname in label_files:
        with open(os.path.join(label_dir, fname)) as f:
            ids = [int(l.split()[0]) for l in f if l.strip()]
        if ids:
            present_ids = [i for i in ids if 0 <= i < num_classes]
            # Weight = max inv_freq of all classes present in this image
            w = max(inv_freq[i] for i in present_ids) if present_ids else 1.0
        else:
            w = 1.0
        sample_weights.append(w)

    return WeightedRandomSampler(
        weights=sample_weights,
        num_samples=len(sample_weights),
        replacement=True
    )

# %%
seg_yaml = """
path: /kaggle/working/yolo/seg

train: train/images
val: val/images

nc: 5

names:
  0: long sleeve top
  1: short sleeve top
  2: shorts
  3: skirt
  4: trousers
"""

with open("/kaggle/working/yolo/seg_data.yaml", "w") as f:
    f.write(seg_yaml)

print("seg_data.yaml written.")
# Out:
# seg_data.yaml written.

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.32-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.25.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.8.0->ultralytics) (1.3.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.32-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.32 ultralytics-thop-2.0.18

# %%
from ultralytics import YOLO

# yolov8n-seg.pt = pretrained COCO weights → true transfer learning
# yolov8n-seg.yaml = random weights only → training from scratch
model_seg = YOLO("yolov8n-seg.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n-seg.pt to 'yolov8n-seg.pt': 100% ━━━━━━━━━━━━ 6.7MB 76.8MB/s 0.1s

# %%
import os
import shutil
import numpy as np
from tqdm import tqdm

def process_segmentation(df, split):

    for img_name in tqdm(df["image"].unique()):

        img_path = os.path.join(IMG_DIR, img_name)
        anno_path = os.path.join(ANNO_DIR, img_name.replace(".jpg",".json"))

        if not os.path.exists(anno_path):
            continue

        if not os.path.exists(img_path):
            continue

        img = Image.open(img_path)
        W, H = img.size

        with open(anno_path) as f:
            data = json.load(f)

        labels = []

        for item in data.values():

            if not isinstance(item, dict):
                continue

            cat = item.get("category_name")
            if cat not in class_to_id:
                continue

            cls_id = class_to_id[cat]

            segmentations = item.get("segmentation")

            if segmentations is None:
                continue

            # segmentation can have multiple polygons
            for seg in segmentations:

                if len(seg) < 6:
                    continue

                coords = np.array(seg, dtype=np.float32).reshape(-1, 2)

                # normalize
                coords[:, 0] /= W
                coords[:, 1] /= H

                coords = coords.flatten()

                line = f"{cls_id} " + " ".join(map(str, coords))
                labels.append(line)

        if len(labels) == 0:
            continue

        label_path = f"/kaggle/working/yolo/seg/{split}/labels/{img_name.replace('.jpg','.txt')}"

        with open(label_path, "w") as f:
            f.write("\n".join(labels))

        shutil.copy(img_path, f"/kaggle/working/yolo/seg/{split}/images/{img_name}")

# %%
process_segmentation(train_df, "train")
process_segmentation(val_df, "val")
# Out:
# 100%|██████████| 24500/24500 [16:37<00:00, 24.55it/s]
# 100%|██████████| 5250/5250 [02:36<00:00, 33.61it/s]

# %%
seg_weights, seg_counts = compute_class_weights(
    "/kaggle/working/yolo/seg/train/labels", num_classes=5
)

print("Segmentation — train set class distribution")
print("=" * 52)
for i, cls in enumerate(classes):
    print(f"  {cls:20s} | count: {int(seg_counts[i]):6d} | weight: {seg_weights[i]:.4f}")
print(f"  {'Total':20s} | count: {int(seg_counts.sum()):6d}")
# Out:
# Segmentation — train set class distribution
# ====================================================
#   long sleeve top      | count:  24859 | weight: 0.5709
#   short sleeve top     | count:  32119 | weight: 0.4419
#   shorts               | count:  17669 | weight: 0.8033
#   skirt                | count:   5366 | weight: 2.6450
#   trousers             | count:  26338 | weight: 0.5389
#   Total                | count: 106351

# %%
import ultralytics.data.build as _build_mod
import torch.utils.data as tud

# Keep reference to original — needed to restore before re-patching in stage 2
_orig_build_dataloader = _build_mod.build_dataloader

def patch_dataloader_with_sampler(label_dir, num_classes=5):
    """
    Monkey-patch Ultralytics build_dataloader to inject WeightedRandomSampler
    for the training split only. Val/test keep uniform sampling.
    Must be called BEFORE model.train().
    """
    sampler = make_weighted_sampler(label_dir, num_classes)

    def _patched(dataset, batch, workers, shuffle=True, rank=-1):
        if not shuffle:
            return _orig_build_dataloader(dataset, batch, workers, shuffle=False, rank=rank)
        loader = _orig_build_dataloader(dataset, batch, workers, shuffle=False, rank=rank)
        return tud.DataLoader(
            loader.dataset,
            batch_size=loader.batch_size,
            sampler=sampler,
            num_workers=loader.num_workers,
            pin_memory=getattr(loader, 'pin_memory', True),
            collate_fn=loader.collate_fn,
            drop_last=getattr(loader, 'drop_last', False),
        )

    _build_mod.build_dataloader = _patched
    print(f"Dataloader patched — WeightedRandomSampler active for training")
    print(f"  {len(sampler.weights)} images, replacement=True")

patch_dataloader_with_sampler("/kaggle/working/yolo/seg/train/labels", num_classes=5)
# Out:
# Dataloader patched — WeightedRandomSampler active for training
#   24500 images, replacement=True

# %%
# ── Stage 1: freeze backbone (first 10 layers), train heads only ──────────────
model_seg.train(
    data="/kaggle/working/yolo/seg_data.yaml",
    epochs=5,
    imgsz=640,
    batch=16,
    lr0=0.001,
    freeze=5,
    optimizer="auto",
    patience=10,
    project="/kaggle/working/yolo_tl",
    name="stage1_seg"
)

# Load best checkpoint from stage 1 for full fine-tuning
model_seg = YOLO("/kaggle/working/yolo_tl/stage1_seg/weights/best.pt")

# ── Re-apply dataloader patch for stage 2 ─────────────────────────────────────
# New YOLO object created — patch doesn't persist. Restore original first
# to avoid stacking two patches, then re-patch.
_build_mod.build_dataloader = _orig_build_dataloader
patch_dataloader_with_sampler("/kaggle/working/yolo/seg/train/labels", num_classes=5)

# ── Stage 2: unfreeze all layers, full fine-tuning at lower LR ────────────────
model_seg.train(
    data="/kaggle/working/yolo/seg_data.yaml",
    epochs=30,
    imgsz=640,
    batch=16,
    lr0=0.0001,
    freeze=0,
    optimizer="auto",
    patience=15,
    project="/kaggle/working/yolo_ft",
    name="stage2_seg"
)

# Load best checkpoint from stage 2 for evaluation (not last epoch)
model_seg = YOLO(model_seg.trainer.best)
# Out:
# Ultralytics 8.4.32 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/yolo/seg_data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=5, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=stage1_seg, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo_tl, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_tl/stage1_seg, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 14.8MB/s 0.0s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1   1005055  ultralytics.nn.modules.head.Segment          [5, 32, 64, 16, None, [64, 128, 256]]
# YOLOv8n-seg summary: 152 layers, 3,264,591 parameters, 3,264,575 gradients, 11.5 GFLOPs
#
# Transferred 381/417 items from pretrained weights
# Freezing layer 'model.0.conv.weight'
# Freezing layer 'model.0.bn.weight'
# Freezing layer 'model.0.bn.bias'
# Freezing layer 'model.1.conv.weight'
# Freezing layer 'model.1.bn.weight'
# Freezing layer 'model.1.bn.bias'
# Freezing layer 'model.2.cv1.conv.weight'
# Freezing layer 'model.2.cv1.bn.weight'
# Freezing layer 'model.2.cv1.bn.bias'
# Freezing layer 'model.2.cv2.conv.weight'
# Freezing layer 'model.2.cv2.bn.weight'
# Freezing layer 'model.2.cv2.bn.bias'
# Freezing layer 'model.2.m.0.cv1.conv.weight'
# Freezing layer 'model.2.m.0.cv1.bn.weight'
# Freezing layer 'model.2.m.0.cv1.bn.bias'
# Freezing layer 'model.2.m.0.cv2.conv.weight'
# Freezing layer 'model.2.m.0.cv2.bn.weight'
# Freezing layer 'model.2.m.0.cv2.bn.bias'
# Freezing layer 'model.3.conv.weight'
# Freezing layer 'model.3.bn.weight'
# Freezing layer 'model.3.bn.bias'
# Freezing layer 'model.4.cv1.conv.weight'
# Freezing layer 'model.4.cv1.bn.weight'
# Freezing layer 'model.4.cv1.bn.bias'
# Freezing layer 'model.4.cv2.conv.weight'
# Freezing layer 'model.4.cv2.bn.weight'
# Freezing layer 'model.4.cv2.bn.bias'
# Freezing layer 'model.4.m.0.cv1.conv.weight'
# Freezing layer 'model.4.m.0.cv1.bn.weight'
# Freezing layer 'model.4.m.0.cv1.bn.bias'
# Freezing layer 'model.4.m.0.cv2.conv.weight'
# Freezing layer 'model.4.m.0.cv2.bn.weight'
# Freezing layer 'model.4.m.0.cv2.bn.bias'
# Freezing layer 'model.4.m.1.cv1.conv.weight'
# Freezing layer 'model.4.m.1.cv1.bn.weight'
# Freezing layer 'model.4.m.1.cv1.bn.bias'
# Freezing layer 'model.4.m.1.cv2.conv.weight'
# Freezing layer 'model.4.m.1.cv2.bn.weight'
# Freezing layer 'model.4.m.1.cv2.bn.bias'
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 68.4MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1294.8±551.1 MB/s, size: 47.5 KB)
# train: Scanning /kaggle/working/yolo/seg/train/labels... 24500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 24500/24500 1.2Kit/s 19.7s
# train: /kaggle/working/yolo/seg/train/images/000014.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/000253.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/000474.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/000689.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/001149.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/001152.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/001754.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/001996.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/002077.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/002102.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/002601.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/002967.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/002991.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/003174.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/003177.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/003226.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/003900.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/004227.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/004890.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/005256.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/006014.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/006015.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/006148.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/006149.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/007562.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/007568.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/007595.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/008125.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/009895.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/011517.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/012094.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/012470.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/012562.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/012581.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/012693.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/012694.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/012894.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/013275.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/013527.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/014109.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/015221.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/015653.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/017617.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/018089.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/018225.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/019612.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/019627.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/019835.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/020910.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/020911.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/021306.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/021413.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/021426.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/022301.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/022629.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/024149.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/024214.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/024222.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/024223.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/024342.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/024344.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/024400.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/025677.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/026135.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/026943.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/028548.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/028568.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/028999.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/029711.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/029930.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/030064.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/030137.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/030209.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/031387.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/031927.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/031948.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/031980.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/032903.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/033350.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/033353.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/033994.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/033998.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/034001.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/034002.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/034257.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/034380.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/034728.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/035047.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/035844.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/035850.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/036447.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/037905.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/038272.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/038569.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/038865.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/039362.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/039526.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/039805.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/040638.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/040668.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/040885.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/041268.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/041274.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/042229.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/042747.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/042753.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/043278.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/044169.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/045034.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/045919.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/046587.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/047595.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/048194.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/048382.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/049089.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/049957.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/049964.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/051136.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/052124.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/052251.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/056294.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/057047.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/057716.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/057989.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/058228.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/058780.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/059177.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/059659.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/059695.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/060243.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/060546.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/060756.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/060939.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/060940.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/061599.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/061604.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/061642.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/062111.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/062762.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/065437.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/065661.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/067110.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/067113.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/068076.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/068328.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/069203.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/069387.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/070449.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/070623.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/071143.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/071145.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/071599.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/071643.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/073721.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/075088.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/075674.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/075680.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/076137.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/076905.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/077622.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/077842.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/077989.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/078713.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/078767.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/079325.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/079996.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/080070.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/080517.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/081004.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/081600.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/081606.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/081607.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/081693.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/083369.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/083402.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/084329.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/084334.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/084401.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/084537.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/084659.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/084661.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/084682.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/084799.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/085327.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/086533.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/086536.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/086867.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/088164.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/088427.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/088584.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/088599.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/088657.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/088976.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/089134.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/089210.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/090151.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/090783.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/090845.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/091687.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/092197.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/092532.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/093486.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/095477.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/095478.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/095890.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/095895.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/096397.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/097017.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/097246.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/097317.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/097837.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/097920.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/097938.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/098449.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/099743.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/099761.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/100070.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/100290.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/100621.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/100974.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/101790.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/101798.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/101817.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/102160.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/102324.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/103340.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/103347.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/103849.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/103860.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/104454.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/105582.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/105597.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/105701.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/106288.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/107736.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/107897.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/108242.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/108353.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/108355.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/109125.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/109156.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/109437.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/109596.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/109790.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/110537.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/110541.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/111107.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/111829.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/112587.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/112815.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/112965.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/112967.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/113051.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/113243.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/113244.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/113969.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/114755.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/116077.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/116325.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/116529.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/117211.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/117843.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/118280.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/119688.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/119757.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/120289.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/120925.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/121259.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/121580.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/121584.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/122277.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/122419.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/122789.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/122791.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/122795.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/123471.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/124022.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/125187.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/125195.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/126616.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/127271.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/127277.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/127278.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/127281.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/127542.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/127549.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/129862.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/129895.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/130735.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/130737.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/132071.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/133157.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/133215.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/133867.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/134148.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/134884.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/134963.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/135007.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/135085.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/135692.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/136036.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/136577.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/137028.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/137275.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/137562.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/137585.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/137586.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/137710.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/137721.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/137895.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/137901.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/138039.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/138389.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/138391.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/138758.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/138899.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/139178.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/139626.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/139714.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/139715.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/141092.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/141896.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/141996.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/142039.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/143063.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/143120.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/143495.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/143598.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/143800.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/144299.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/144690.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/145169.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/145336.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/145409.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/145864.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/146040.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/146047.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/146060.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/147480.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/147818.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/148058.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/148066.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/148071.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/148077.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/148380.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/148766.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/149116.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/149300.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/151223.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/151421.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/152015.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/152126.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/152232.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/152334.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/152725.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/152728.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/152739.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/152742.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/152743.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/152744.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/153248.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/154404.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/154571.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/154585.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/154834.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/154886.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/155484.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/155703.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/155715.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/155723.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/156273.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/157251.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/158112.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/161409.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/162245.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/162648.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/162845.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/163129.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/163135.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/163136.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/163137.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/163140.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/163435.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/163438.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/164224.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/165981.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/166936.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/167205.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/167430.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/167600.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/167962.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/167984.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/168900.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/169233.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/169847.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/170547.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/171149.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/171671.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/172027.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/172590.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/173044.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/173337.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/173355.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/173833.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/173834.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/174035.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/174625.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/174626.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/175103.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/175237.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/175418.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/175426.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/175441.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/175920.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/176280.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/176898.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/177350.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/178887.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/179251.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/180337.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/180509.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/181589.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/181596.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/181775.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/182049.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/182516.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/183346.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/183366.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/183521.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/184292.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/184541.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/184545.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/184550.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/185316.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/185958.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/186829.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/186832.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/187156.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/189096.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/189436.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/190208.jpg: 1 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/190840.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/190847.jpg: 2 duplicate labels removed
# train: /kaggle/working/yolo/seg/train/images/191403.jpg: 1 duplicate labels removed
# train: New cache created: /kaggle/working/yolo/seg/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1184.5±616.0 MB/s, size: 49.4 KB)
# val: Scanning /kaggle/working/yolo/seg/val/labels... 5250 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5250/5250 1.2Kit/s 4.4s
# val: /kaggle/working/yolo/seg/val/images/002076.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/008000.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/009665.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/010326.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/012224.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/012577.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/012707.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/013276.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/015545.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/015868.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/019110.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/019618.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/019922.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/023364.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/026935.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/028588.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/028804.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/028810.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/028819.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/029937.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/032978.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/034378.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/042231.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/044227.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/044759.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/046843.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/053807.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/054361.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/056051.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/056585.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/056834.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/058668.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/059137.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/065431.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/066054.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/071141.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/071142.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/071789.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/072325.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/072345.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/076908.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/079843.jpg: 1 duplicate labels removed
# ...
#        5/30      4.51G      1.089      2.663      1.204      1.215          0         37        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.4it/s 49.1s
#                    all       5250      22738      0.725      0.712      0.754       0.55      0.596      0.567      0.498      0.311
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        6/30      4.51G      1.063      2.603       1.16      1.199          0         20        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:60
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.4it/s 48.1s
#                    all       5250      22738      0.745      0.733      0.783      0.577      0.605      0.578      0.517      0.325
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        7/30      4.51G       1.04      2.549       1.12      1.186          0         23        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.4it/s 47.9s
#                    all       5250      22738      0.761       0.75      0.803      0.591      0.623      0.603      0.547      0.347
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        8/30      4.51G       1.02      2.496      1.086      1.172          0         25        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.4it/s 48.1s
#                    all       5250      22738      0.769      0.755      0.807      0.605      0.628      0.604      0.544       0.35
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        9/30      4.51G      1.005       2.46      1.061      1.163          0         40        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.7s
#                    all       5250      22738      0.776      0.768      0.817      0.615       0.64      0.622      0.565      0.365
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       10/30      4.51G     0.9951      2.439       1.04      1.157          0         21        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.6s
#                    all       5250      22738      0.786      0.776      0.828      0.627      0.637      0.632      0.571       0.37
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       11/30      4.51G      0.983      2.403      1.023      1.152          0         39        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.7s
#                    all       5250      22738      0.789      0.785      0.831      0.633      0.644      0.642      0.577      0.377
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       12/30      4.51G     0.9725      2.383       1.01      1.145          0         38        640: 100% ━━━━━━━━━━━━ 1532/1532 3.6it/s 7:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.4s
#                    all       5250      22738      0.792      0.787      0.837      0.636      0.652       0.64      0.584      0.383
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       13/30      4.51G     0.9654      2.364     0.9885      1.138          0         42        640: 100% ━━━━━━━━━━━━ 1532/1532 3.6it/s 7:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.7s
#                    all       5250      22738      0.793      0.794       0.84      0.645      0.649      0.646      0.579      0.381
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       14/30      4.51G     0.9507      2.336     0.9742      1.131          0         23        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.2s
#                    all       5250      22738        0.8      0.794      0.846      0.651      0.658      0.649      0.589      0.388
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       15/30      4.51G     0.9445       2.32     0.9589      1.126          0         38        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 46.9s
#                    all       5250      22738        0.8      0.798      0.847      0.655      0.656      0.648      0.588      0.391
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       16/30      4.51G     0.9377      2.286     0.9436      1.119          0         27        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.0s
#                    all       5250      22738      0.809      0.802      0.853      0.661      0.663      0.654      0.595      0.395
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       17/30      4.51G     0.9302      2.275     0.9345      1.115          0         30        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.6s
#                    all       5250      22738      0.805      0.808      0.857      0.666      0.662       0.66      0.602      0.399
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       18/30      4.51G     0.9224      2.254     0.9173      1.111          0         31        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.3s
#                    all       5250      22738      0.804      0.818      0.861      0.671      0.663      0.665      0.604      0.404
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       19/30      4.51G     0.9161      2.231     0.9084      1.108          0         35        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.7s
#                    all       5250      22738      0.825      0.804      0.863      0.674       0.68      0.662      0.608      0.407
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       20/30      4.51G       0.91      2.222     0.8986      1.105          0         19        640: 100% ━━━━━━━━━━━━ 1532/1532 3.7it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.6s
#                    all       5250      22738      0.815      0.812      0.862      0.675       0.67      0.663      0.604      0.404
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       21/30      4.51G     0.8961      1.986     0.7755      1.111          0         14        640: 100% ━━━━━━━━━━━━ 1532/1532 3.8it/s 6:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.4s
#                    all       5250      22738      0.817      0.817      0.866      0.677      0.672      0.667      0.611      0.409
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       22/30      4.51G     0.8854      1.954      0.758      1.103          0         20        640: 100% ━━━━━━━━━━━━ 1532/1532 3.8it/s 6:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.1s
#                    all       5250      22738       0.82      0.821       0.87      0.682      0.677      0.675      0.616      0.414
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       23/30      4.51G     0.8731      1.925     0.7429      1.094          0         18        640: 100% ━━━━━━━━━━━━ 1532/1532 3.8it/s 6:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.4it/s 47.9s
#                    all       5250      22738      0.818      0.824      0.871      0.684      0.675      0.677      0.617      0.416
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       24/30      4.51G      0.864      1.893     0.7238      1.087          0         19        640: 100% ━━━━━━━━━━━━ 1532/1532 3.8it/s 6:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.2s
#                    all       5250      22738      0.823      0.821      0.873      0.686       0.68      0.674      0.619      0.418
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       25/30      4.51G      0.857      1.876     0.7147      1.083          0         20        640: 100% ━━━━━━━━━━━━ 1532/1532 3.8it/s 6:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 46.8s
#                    all       5250      22738      0.825      0.822      0.874      0.688      0.681      0.676       0.62       0.42
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       26/30      4.51G     0.8463      1.847     0.6986      1.076          0         13        640: 100% ━━━━━━━━━━━━ 1532/1532 3.8it/s 6:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 46.7s
#                    all       5250      22738       0.82      0.832      0.876       0.69      0.673      0.686      0.621      0.421
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       27/30      4.51G     0.8395      1.822      0.686      1.071          0         22        640: 100% ━━━━━━━━━━━━ 1532/1532 3.8it/s 6:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.4s
#                    all       5250      22738      0.825       0.83      0.877      0.692       0.68      0.683      0.624      0.424
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       28/30      4.51G     0.8265       1.79     0.6691      1.064          0         15        640: 100% ━━━━━━━━━━━━ 1532/1532 3.8it/s 6:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 47.2s
#                    all       5250      22738      0.823      0.834      0.878      0.693      0.678      0.689      0.626      0.425
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       29/30      4.51G     0.8233      1.769     0.6598       1.06          0         16        640: 100% ━━━━━━━━━━━━ 1532/1532 3.8it/s 6:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 46.7s
#                    all       5250      22738      0.828      0.831      0.879      0.694      0.684      0.683      0.627      0.426
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       30/30      4.51G     0.8158      1.749     0.6487      1.057          0         14        640: 100% ━━━━━━━━━━━━ 1532/1532 3.8it/s 6:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.5it/s 46.8s
#                    all       5250      22738       0.83      0.831      0.879      0.695      0.685      0.686      0.627      0.426
#
# 30 epochs completed in 3.882 hours.
# Optimizer stripped from /kaggle/working/yolo_ft/stage2_seg/weights/last.pt, 6.7MB
# Optimizer stripped from /kaggle/working/yolo_ft/stage2_seg/weights/best.pt, 6.7MB
#
# Validating /kaggle/working/yolo_ft/stage2_seg/weights/best.pt...
# Ultralytics 8.4.32 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n-seg summary (fused): 86 layers, 3,259,039 parameters, 0 gradients, 11.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 165/165 3.6it/s 46.1s
#                    all       5250      22738      0.831      0.831      0.879      0.695      0.685      0.686      0.627      0.426
#        long sleeve top       1312       5319      0.758      0.673      0.747      0.538      0.708      0.623      0.661      0.341
#       short sleeve top       2566       6851      0.824      0.858      0.894      0.701      0.818      0.848      0.879       0.59
#                 shorts       1329       3820      0.884      0.858      0.924      0.723      0.571      0.553      0.386      0.265
#                  skirt       1104       1111      0.797        0.9      0.906      0.772      0.773      0.869      0.842      0.685
#               trousers       1992       5637      0.892      0.867      0.923       0.74      0.556      0.539       0.37       0.25
# Speed: 0.2ms preprocess, 1.9ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /kaggle/working/yolo_ft/stage2_seg

# %% [markdown]
# # Detection-metrics

# %%
# Load best checkpoint from stage 2 for evaluation
metrics = model_seg.val()
print("\n" + "="*50)
print("GLOBAL DETECTION PERFORMANCE")
print("="*50)
print(f"mAP@[0.5:0.95]: {metrics.box.map:.4f}")
print(f"mAP@0.5:       {metrics.box.map50:.4f}")

overall_f1 = 2 * metrics.box.mp * metrics.box.mr / (metrics.box.mp + metrics.box.mr + 1e-16)
print(f"Overall F1:    {overall_f1:.4f}")
# Out:
# Ultralytics 8.4.32 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n-seg summary (fused): 86 layers, 3,259,039 parameters, 0 gradients, 11.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1251.2±605.6 MB/s, size: 43.1 KB)
# val: Scanning /kaggle/working/yolo/seg/val/labels.cache... 5250 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5250/5250 2.4Git/s 0.0s
# val: /kaggle/working/yolo/seg/val/images/002076.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/008000.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/009665.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/010326.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/012224.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/012577.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/012707.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/013276.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/015545.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/015868.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/019110.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/019618.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/019922.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/023364.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/026935.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/028588.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/028804.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/028810.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/028819.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/029937.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/032978.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/034378.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/042231.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/044227.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/044759.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/046843.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/053807.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/054361.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/056051.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/056585.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/056834.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/058668.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/059137.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/065431.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/066054.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/071141.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/071142.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/071789.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/072325.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/072345.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/076908.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/079843.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/080005.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/080058.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/081681.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/081759.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/083415.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/084880.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/085978.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/086804.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/088531.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/089078.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/089289.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/089810.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/090573.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/092384.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/093284.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/093473.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/093518.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/095857.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/097927.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/097940.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/105580.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/108798.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/110710.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/111801.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/112781.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/124986.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/125191.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/127261.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/128130.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/129100.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/129426.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/138396.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/141997.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/143971.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/146152.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/148073.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/150867.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/151343.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/152149.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/153668.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/155680.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/161157.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/162021.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/163375.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/165452.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/171870.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/173352.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/174177.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/175416.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/175423.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/176923.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/177810.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/181105.jpg: 2 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/181109.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/183351.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/188315.jpg: 1 duplicate labels removed
# val: /kaggle/working/yolo/seg/val/images/188901.jpg: 2 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 329/329 6.8it/s 48.5s
#                    all       5250      22738       0.83      0.831      0.879      0.695      0.685      0.686      0.628      0.426
#        long sleeve top       1312       5319      0.758      0.674      0.747      0.538      0.709      0.622      0.661       0.34
#       short sleeve top       2566       6851      0.824      0.857      0.894      0.702      0.818      0.847      0.879       0.59
#                 shorts       1329       3820      0.883      0.859      0.924      0.723      0.571      0.553      0.386      0.265
#                  skirt       1104       1111      0.796        0.9      0.906      0.771      0.772      0.869      0.842      0.684
#               trousers       1992       5637      0.891      0.867      0.923       0.74      0.556      0.539       0.37      0.251
# Speed: 0.6ms preprocess, 3.6ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/segment/val
#
# ==================================================
# GLOBAL DETECTION PERFORMANCE
# ==================================================
# mAP@[0.5:0.95]: 0.6948
# mAP@0.5:       0.8788
# Overall F1:    0.8309

# %%
print("\n" + "="*50)
print("🏷️ PER-CLASS ANALYSIS")
print("="*50)
names = model_seg.names
for i, class_idx in enumerate(metrics.box.ap_class_index):
    class_name = names[class_idx]
    ap50 = metrics.box.ap50[i]
    ap   = metrics.box.ap[i]
    p    = metrics.box.p[i]
    r    = metrics.box.r[i]
    f1   = 2 * (p * r) / (p + r + 1e-16)
    print(f"{class_name:18} | mAP@.5: {ap50:.4f} | mAP@[.5:.95]: {ap:.4f} | P: {p:.4f} | R: {r:.4f} | F1: {f1:.4f}")
# Out:
# ==================================================
# 🏷️ PER-CLASS ANALYSIS
# ==================================================
# long sleeve top    | mAP@.5: 0.7474 | mAP@[.5:.95]: 0.5382 | P: 0.7576 | R: 0.6740 | F1: 0.7134
# short sleeve top   | mAP@.5: 0.8940 | mAP@[.5:.95]: 0.7018 | P: 0.8240 | R: 0.8575 | F1: 0.8404
# shorts             | mAP@.5: 0.9236 | mAP@[.5:.95]: 0.7227 | P: 0.8831 | R: 0.8586 | F1: 0.8707
# skirt              | mAP@.5: 0.9058 | mAP@[.5:.95]: 0.7715 | P: 0.7957 | R: 0.9001 | F1: 0.8447
# trousers           | mAP@.5: 0.9229 | mAP@[.5:.95]: 0.7398 | P: 0.8914 | R: 0.8668 | F1: 0.8789

# %%
import numpy as np
import cv2

def yolo_to_mask(result, H, W):
    pred_mask = np.zeros((H, W), dtype=np.int32)

    if result.masks is None:
        return pred_mask

    # result.masks.data shape: (N, model_H, model_W) — may differ from original (H, W)
    masks   = result.masks.data.cpu().numpy()
    classes = result.boxes.cls.cpu().numpy().astype(int)
    scores  = result.boxes.conf.cpu().numpy()

    # Paint in DESCENDING confidence so highest-confidence masks are painted last (on top)
    for m, cls, score in sorted(zip(masks, classes, scores), key=lambda x: -x[2]):
        # Resize from model resolution to original image resolution
        m_resized = cv2.resize(m, (W, H), interpolation=cv2.INTER_LINEAR)
        pred_mask[m_resized > 0.5] = cls + 1

    return pred_mask

# %%
import numpy as np
import json
import cv2

def json_to_mask(json_path, H, W, class_to_id):
    mask = np.zeros((H, W), dtype=np.int32)  # background = 0

    with open(json_path) as f:
        data = json.load(f)

    for item in data.values():

        if not isinstance(item, dict):
            continue

        cat = item.get("category_name")
        if cat not in class_to_id:
            continue

        cls_id = class_to_id[cat]  # already shifted (1–5)

        segmentations = item.get("segmentation")

        if segmentations is None:
            continue

        for seg in segmentations:

            if len(seg) < 6:
                continue

            coords = np.array(seg).reshape(-1, 2).astype(np.int32)

            # fill polygon
            cv2.fillPoly(mask, [coords], cls_id)

    return mask

# %%
y_true = []
y_pred = []

classes_bg = [
    "background",
    "long sleeve top",
    "short sleeve top",
    "shorts",
    "skirt",
    "trousers"
]

class_to_id_val = {c: i for i, c in enumerate(classes_bg)}

# stream=True: yields results one-by-one instead of loading all val images into RAM at once
results = model_seg.predict("/kaggle/working/yolo/seg/val/images", save=False, stream=True)

for result in results:

    img = Image.open(result.path)
    W, H = img.size

    pred_mask = yolo_to_mask(result, H, W)

    img_name = os.path.basename(result.path)

    anno_path = os.path.join(ANNO_DIR, img_name.replace(".jpg", ".json"))

    if not os.path.exists(anno_path):
        continue

    gt_mask = json_to_mask(anno_path, H, W, class_to_id_val)

    y_pred.append(pred_mask)

    y_true.append(gt_mask)
print(f"Processed {len(y_true)} images for validation.")
# Out:
# image 1/5250 /kaggle/working/yolo/seg/val/images/000037.jpg: 480x640 1 short sleeve top, 2 shortss, 52.9ms
# image 2/5250 /kaggle/working/yolo/seg/val/images/000047.jpg: 640x480 3 short sleeve tops, 2 shortss, 49.4ms
# image 3/5250 /kaggle/working/yolo/seg/val/images/000119.jpg: 640x480 2 long sleeve tops, 2 trouserss, 7.3ms
# image 4/5250 /kaggle/working/yolo/seg/val/images/000125.jpg: 640x480 1 short sleeve top, 7.3ms
# image 5/5250 /kaggle/working/yolo/seg/val/images/000178.jpg: 640x448 1 short sleeve top, 2 trouserss, 49.7ms
# image 6/5250 /kaggle/working/yolo/seg/val/images/000369.jpg: 640x384 3 short sleeve tops, 2 trouserss, 51.5ms
# image 7/5250 /kaggle/working/yolo/seg/val/images/000372.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.8ms
# image 8/5250 /kaggle/working/yolo/seg/val/images/000384.jpg: 640x480 3 short sleeve tops, 8.0ms
# image 9/5250 /kaggle/working/yolo/seg/val/images/000468.jpg: 544x640 3 short sleeve tops, 2 trouserss, 49.8ms
# image 10/5250 /kaggle/working/yolo/seg/val/images/000489.jpg: 640x448 1 short sleeve top, 2 shortss, 7.8ms
# image 11/5250 /kaggle/working/yolo/seg/val/images/000493.jpg: 640x448 1 shorts, 7.2ms
# image 12/5250 /kaggle/working/yolo/seg/val/images/000496.jpg: 640x480 1 skirt, 8.1ms
# image 13/5250 /kaggle/working/yolo/seg/val/images/000578.jpg: 448x640 5 long sleeve tops, 3 trouserss, 49.8ms
# image 14/5250 /kaggle/working/yolo/seg/val/images/000606.jpg: 640x448 3 long sleeve tops, 2 trouserss, 7.8ms
# image 15/5250 /kaggle/working/yolo/seg/val/images/000612.jpg: 576x640 2 shortss, 50.9ms
# image 16/5250 /kaggle/working/yolo/seg/val/images/000655.jpg: 640x448 2 trouserss, 7.8ms
# image 17/5250 /kaggle/working/yolo/seg/val/images/000675.jpg: 640x448 2 short sleeve tops, 1 skirt, 7.2ms
# image 18/5250 /kaggle/working/yolo/seg/val/images/000745.jpg: 640x448 5 long sleeve tops, 2 trouserss, 7.2ms
# image 19/5250 /kaggle/working/yolo/seg/val/images/000832.jpg: 640x480 2 short sleeve tops, 7.9ms
# image 20/5250 /kaggle/working/yolo/seg/val/images/000835.jpg: 640x480 4 short sleeve tops, 7.3ms
# image 21/5250 /kaggle/working/yolo/seg/val/images/000892.jpg: 640x384 3 short sleeve tops, 2 trouserss, 7.5ms
# image 22/5250 /kaggle/working/yolo/seg/val/images/000906.jpg: 640x480 4 short sleeve tops, 8.0ms
# image 23/5250 /kaggle/working/yolo/seg/val/images/000908.jpg: 640x480 3 short sleeve tops, 2 trouserss, 7.3ms
# image 24/5250 /kaggle/working/yolo/seg/val/images/000918.jpg: 640x640 3 short sleeve tops, 2 trouserss, 9.6ms
# image 25/5250 /kaggle/working/yolo/seg/val/images/000945.jpg: 640x448 2 trouserss, 7.8ms
# image 26/5250 /kaggle/working/yolo/seg/val/images/000971.jpg: 448x640 1 short sleeve top, 1 skirt, 7.7ms
# image 27/5250 /kaggle/working/yolo/seg/val/images/001002.jpg: 640x544 5 long sleeve tops, 2 shortss, 47.7ms
# image 28/5250 /kaggle/working/yolo/seg/val/images/001010.jpg: 640x448 4 long sleeve tops, 2 shortss, 8.0ms
# image 29/5250 /kaggle/working/yolo/seg/val/images/001057.jpg: 640x448 4 long sleeve tops, 2 shortss, 7.2ms
# image 30/5250 /kaggle/working/yolo/seg/val/images/001100.jpg: 640x448 2 short sleeve tops, 1 trousers, 7.2ms
# image 31/5250 /kaggle/working/yolo/seg/val/images/001139.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.4ms
# image 32/5250 /kaggle/working/yolo/seg/val/images/001176.jpg: 640x448 3 long sleeve tops, 1 skirt, 7.1ms
# image 33/5250 /kaggle/working/yolo/seg/val/images/001191.jpg: 640x448 2 trouserss, 7.1ms
# image 34/5250 /kaggle/working/yolo/seg/val/images/001271.jpg: 640x384 2 trouserss, 7.6ms
# image 35/5250 /kaggle/working/yolo/seg/val/images/001361.jpg: 512x640 2 long sleeve tops, 2 trouserss, 49.5ms
# image 36/5250 /kaggle/working/yolo/seg/val/images/001402.jpg: 640x448 1 trousers, 7.8ms
# image 37/5250 /kaggle/working/yolo/seg/val/images/001415.jpg: 640x448 2 trouserss, 7.1ms
# image 38/5250 /kaggle/working/yolo/seg/val/images/001453.jpg: 640x448 1 short sleeve top, 2 trouserss, 7.1ms
# image 39/5250 /kaggle/working/yolo/seg/val/images/001472.jpg: 640x480 3 short sleeve tops, 1 skirt, 8.0ms
# image 40/5250 /kaggle/working/yolo/seg/val/images/001516.jpg: 640x448 4 short sleeve tops, 1 shorts, 2 trouserss, 7.8ms
# image 41/5250 /kaggle/working/yolo/seg/val/images/001537.jpg: 640x512 2 long sleeve tops, 1 short sleeve top, 1 skirt, 1 trousers, 47.8ms
# image 42/5250 /kaggle/working/yolo/seg/val/images/001559.jpg: 640x448 2 long sleeve tops, 2 short sleeve tops, 1 trousers, 7.8ms
# image 43/5250 /kaggle/working/yolo/seg/val/images/001590.jpg: 640x512 1 short sleeve top, 1 skirt, 8.0ms
# image 44/5250 /kaggle/working/yolo/seg/val/images/001613.jpg: 640x640 3 short sleeve tops, 1 shorts, 1 trousers, 9.6ms
# image 45/5250 /kaggle/working/yolo/seg/val/images/001665.jpg: 640x448 1 short sleeve top, 1 trousers, 8.0ms
# image 46/5250 /kaggle/working/yolo/seg/val/images/001672.jpg: 640x480 3 short sleeve tops, 1 skirt, 8.0ms
# image 47/5250 /kaggle/working/yolo/seg/val/images/001698.jpg: 640x480 2 long sleeve tops, 2 short sleeve tops, 7.4ms
# image 48/5250 /kaggle/working/yolo/seg/val/images/001730.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.8ms
# image 49/5250 /kaggle/working/yolo/seg/val/images/001737.jpg: 640x416 2 short sleeve tops, 1 shorts, 48.7ms
# image 50/5250 /kaggle/working/yolo/seg/val/images/001772.jpg: 640x448 2 short sleeve tops, 2 trouserss, 7.8ms
# image 51/5250 /kaggle/working/yolo/seg/val/images/001800.jpg: 640x448 6 long sleeve tops, 1 skirt, 7.2ms
# image 52/5250 /kaggle/working/yolo/seg/val/images/001817.jpg: 640x512 3 short sleeve tops, 1 trousers, 8.5ms
# image 53/5250 /kaggle/working/yolo/seg/val/images/001828.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.8ms
# image 54/5250 /kaggle/working/yolo/seg/val/images/001851.jpg: 640x480 3 short sleeve tops, 1 skirt, 1 trousers, 8.0ms
# image 55/5250 /kaggle/working/yolo/seg/val/images/001955.jpg: 640x384 5 long sleeve tops, 2 trouserss, 7.5ms
# image 56/5250 /kaggle/working/yolo/seg/val/images/001972.jpg: 512x640 4 short sleeve tops, 2 skirts, 8.0ms
# image 57/5250 /kaggle/working/yolo/seg/val/images/001986.jpg: 640x448 1 skirt, 7.8ms
# image 58/5250 /kaggle/working/yolo/seg/val/images/002076.jpg: 640x448 2 shortss, 7.1ms
# image 59/5250 /kaggle/working/yolo/seg/val/images/002083.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.1ms
# image 60/5250 /kaggle/working/yolo/seg/val/images/002114.jpg: 640x448 2 trouserss, 7.1ms
# image 61/5250 /kaggle/working/yolo/seg/val/images/002235.jpg: 640x480 3 short sleeve tops, 2 shortss, 8.0ms
# image 62/5250 /kaggle/working/yolo/seg/val/images/002314.jpg: 640x608 3 short sleeve tops, 2 shortss, 48.5ms
# image 63/5250 /kaggle/working/yolo/seg/val/images/002319.jpg: 640x608 3 short sleeve tops, 2 shortss, 8.9ms
# image 64/5250 /kaggle/working/yolo/seg/val/images/002364.jpg: 640x448 4 long sleeve tops, 2 short sleeve tops, 1 skirt, 7.8ms
# image 65/5250 /kaggle/working/yolo/seg/val/images/002498.jpg: 640x480 3 short sleeve tops, 1 shorts, 1 skirt, 8.0ms
# image 66/5250 /kaggle/working/yolo/seg/val/images/002583.jpg: 640x448 5 long sleeve tops, 1 trousers, 7.8ms
# image 67/5250 /kaggle/working/yolo/seg/val/images/002599.jpg: 640x544 2 long sleeve tops, 1 trousers, 9.4ms
# image 68/5250 /kaggle/working/yolo/seg/val/images/002606.jpg: 640x480 2 shortss, 8.5ms
# image 69/5250 /kaggle/working/yolo/seg/val/images/002633.jpg: 640x480 4 short sleeve tops, 1 skirt, 2 trouserss, 7.3ms
# image 70/5250 /kaggle/working/yolo/seg/val/images/002634.jpg: 640x480 1 skirt, 7.3ms
# image 71/5250 /kaggle/working/yolo/seg/val/images/002717.jpg: 640x448 3 trouserss, 7.9ms
# image 72/5250 /kaggle/working/yolo/seg/val/images/002818.jpg: 640x448 1 short sleeve top, 1 skirt, 7.2ms
# image 73/5250 /kaggle/working/yolo/seg/val/images/002833.jpg: 640x448 2 short sleeve tops, 1 skirt, 7.2ms
# image 74/5250 /kaggle/working/yolo/seg/val/images/002880.jpg: 640x480 5 long sleeve tops, 2 trouserss, 8.1ms
# image 75/5250 /kaggle/working/yolo/seg/val/images/002917.jpg: 640x640 3 long sleeve tops, 1 shorts, 1 trousers, 9.6ms
# image 76/5250 /kaggle/working/yolo/seg/val/images/002922.jpg: 640x640 6 long sleeve tops, 2 shortss, 9.0ms
# image 77/5250 /kaggle/working/yolo/seg/val/images/002945.jpg: 640x480 5 long sleeve tops, 2 trouserss, 8.1ms
# image 78/5250 /kaggle/working/yolo/seg/val/images/002953.jpg: 640x640 5 long sleeve tops, 2 shortss, 9.7ms
# image 79/5250 /kaggle/working/yolo/seg/val/images/002973.jpg: 640x448 4 long sleeve tops, 1 skirt, 7.8ms
# image 80/5250 /kaggle/working/yolo/seg/val/images/002998.jpg: 640x480 2 short sleeve tops, 7.9ms
# image 81/5250 /kaggle/working/yolo/seg/val/images/003075.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.7ms
# image 82/5250 /kaggle/working/yolo/seg/val/images/003094.jpg: 640x448 5 long sleeve tops, 1 skirt, 7.2ms
# image 83/5250 /kaggle/working/yolo/seg/val/images/003125.jpg: 640x640 1 short sleeve top, 2 shortss, 9.8ms
# image 84/5250 /kaggle/working/yolo/seg/val/images/003156.jpg: 640x448 3 short sleeve tops, 1 skirt, 7.8ms
# image 85/5250 /kaggle/working/yolo/seg/val/images/003167.jpg: 640x480 4 long sleeve tops, 2 trouserss, 7.9ms
# image 86/5250 /kaggle/working/yolo/seg/val/images/003248.jpg: 640x448 2 shortss, 7.8ms
# image 87/5250 /kaggle/working/yolo/seg/val/images/003324.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.1ms
# image 88/5250 /kaggle/working/yolo/seg/val/images/003379.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.2ms
# image 89/5250 /kaggle/working/yolo/seg/val/images/003387.jpg: 640x544 3 short sleeve tops, 2 shortss, 10.6ms
# image 90/5250 /kaggle/working/yolo/seg/val/images/003393.jpg: 640x544 2 short sleeve tops, 2 shortss, 1 trousers, 8.7ms
# image 91/5250 /kaggle/working/yolo/seg/val/images/003400.jpg: 640x608 4 long sleeve tops, 2 shortss, 9.6ms
# image 92/5250 /kaggle/working/yolo/seg/val/images/003774.jpg: 640x640 1 shorts, 1 skirt, 9.8ms
# image 93/5250 /kaggle/working/yolo/seg/val/images/003797.jpg: 640x512 3 short sleeve tops, 1 skirt, 7.9ms
# image 94/5250 /kaggle/working/yolo/seg/val/images/003945.jpg: 640x384 1 long sleeve top, 7.7ms
# image 95/5250 /kaggle/working/yolo/seg/val/images/003950.jpg: 640x448 5 long sleeve tops, 2 shortss, 7.8ms
# image 96/5250 /kaggle/working/yolo/seg/val/images/003997.jpg: 640x480 2 shortss, 10.6ms
# image 97/5250 /kaggle/working/yolo/seg/val/images/003999.jpg: 640x480 1 long sleeve top, 1 short sleeve top, 13.1ms
# image 98/5250 /kaggle/working/yolo/seg/val/images/004039.jpg: 640x512 2 shortss, 12.3ms
# image 99/5250 /kaggle/working/yolo/seg/val/images/004091.jpg: 640x480 1 short sleeve top, 8.1ms
# image 100/5250 /kaggle/working/yolo/seg/val/images/004129.jpg: 640x576 5 long sleeve tops, 2 trouserss, 46.4ms
# image 101/5250 /kaggle/working/yolo/seg/val/images/004185.jpg: 640x512 3 short sleeve tops, 2 shortss, 8.2ms
# image 102/5250 /kaggle/working/yolo/seg/val/images/004230.jpg: 640x480 5 long sleeve tops, 2 trouserss, 8.0ms
# image 103/5250 /kaggle/working/yolo/seg/val/images/004235.jpg: 480x640 2 shortss, 7.9ms
# image 104/5250 /kaggle/working/yolo/seg/val/images/004241.jpg: 640x480 2 skirts, 2 trouserss, 7.9ms
# image 105/5250 /kaggle/working/yolo/seg/val/images/004269.jpg: 640x480 4 short sleeve tops, 7.3ms
# image 106/5250 /kaggle/working/yolo/seg/val/images/004317.jpg: 640x640 3 short sleeve tops, 2 trouserss, 9.6ms
# image 107/5250 /kaggle/working/yolo/seg/val/images/004339.jpg: 640x480 2 short sleeve tops, 8.0ms
# image 108/5250 /kaggle/working/yolo/seg/val/images/004340.jpg: 640x480 3 short sleeve tops, 7.3ms
# image 109/5250 /kaggle/working/yolo/seg/val/images/004366.jpg: 640x480 1 long sleeve top, 2 short sleeve tops, 7.3ms
# image 110/5250 /kaggle/working/yolo/seg/val/images/004376.jpg: 640x480 3 long sleeve tops, 7.3ms
# image 111/5250 /kaggle/working/yolo/seg/val/images/004418.jpg: 640x480 1 short sleeve top, 7.4ms
# image 112/5250 /kaggle/working/yolo/seg/val/images/004524.jpg: 640x448 3 trouserss, 7.8ms
# image 113/5250 /kaggle/working/yolo/seg/val/images/004531.jpg: 640x448 2 trouserss, 7.1ms
# image 114/5250 /kaggle/working/yolo/seg/val/images/004560.jpg: 640x512 1 short sleeve top, 1 skirt, 7.9ms
# image 115/5250 /kaggle/working/yolo/seg/val/images/004565.jpg: 640x416 3 long sleeve tops, 1 short sleeve top, 1 skirt, 7.6ms
# image 116/5250 /kaggle/working/yolo/seg/val/images/004601.jpg: 640x448 4 short sleeve tops, 7.8ms
# image 117/5250 /kaggle/working/yolo/seg/val/images/004716.jpg: 640x480 2 trouserss, 7.9ms
# image 118/5250 /kaggle/working/yolo/seg/val/images/004719.jpg: 640x480 1 long sleeve top, 7.3ms
# image 119/5250 /kaggle/working/yolo/seg/val/images/004769.jpg: 480x640 1 long sleeve top, 4 short sleeve tops, 8.0ms
# image 120/5250 /kaggle/working/yolo/seg/val/images/004777.jpg: 480x640 2 long sleeve tops, 1 skirt, 7.4ms
# image 121/5250 /kaggle/working/yolo/seg/val/images/004794.jpg: 640x384 3 long sleeve tops, 2 trouserss, 8.0ms
# image 122/5250 /kaggle/working/yolo/seg/val/images/004797.jpg: 640x480 4 long sleeve tops, 8.0ms
# image 123/5250 /kaggle/working/yolo/seg/val/images/004802.jpg: 640x448 3 long sleeve tops, 2 trouserss, 8.0ms
# image 124/5250 /kaggle/working/yolo/seg/val/images/004838.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.3ms
# image 125/5250 /kaggle/working/yolo/seg/val/images/004862.jpg: 352x640 2 long sleeve tops, 2 short sleeve tops, 49.2ms
# image 126/5250 /kaggle/working/yolo/seg/val/images/004882.jpg: 640x480 3 short sleeve tops, 1 skirt, 2 trouserss, 8.1ms
# image 127/5250 /kaggle/working/yolo/seg/val/images/004885.jpg: 640x640 4 long sleeve tops, 1 short sleeve top, 1 skirt, 2 trouserss, 9.7ms
# image 128/5250 /kaggle/working/yolo/seg/val/images/004900.jpg: 640x640 1 short sleeve top, 2 trouserss, 9.0ms
# image 129/5250 /kaggle/working/yolo/seg/val/images/004924.jpg: 640x448 4 long sleeve tops, 2 trouserss, 7.9ms
# image 130/5250 /kaggle/working/yolo/seg/val/images/004974.jpg: 640x448 2 short sleeve tops, 2 shortss, 7.7ms
# image 131/5250 /kaggle/working/yolo/seg/val/images/005062.jpg: 640x448 5 long sleeve tops, 1 skirt, 7.4ms
# image 132/5250 /kaggle/working/yolo/seg/val/images/005078.jpg: 640x480 3 long sleeve tops, 8.1ms
# image 133/5250 /kaggle/working/yolo/seg/val/images/005156.jpg: 640x448 4 long sleeve tops, 2 shortss, 7.9ms
# image 134/5250 /kaggle/working/yolo/seg/val/images/005198.jpg: 640x512 5 long sleeve tops, 1 skirt, 8.1ms
# image 135/5250 /kaggle/working/yolo/seg/val/images/005247.jpg: 640x448 4 long sleeve tops, 3 shortss, 7.9ms
# image 136/5250 /kaggle/working/yolo/seg/val/images/005257.jpg: 640x448 3 trouserss, 7.4ms
# image 137/5250 /kaggle/working/yolo/seg/val/images/005293.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.2ms
# image 138/5250 /kaggle/working/yolo/seg/val/images/005337.jpg: 640x448 4 short sleeve tops, 7.3ms
# image 139/5250 /kaggle/working/yolo/seg/val/images/005345.jpg: 640x448 2 short sleeve tops, 2 trouserss, 7.3ms
# image 140/5250 /kaggle/working/yolo/seg/val/images/005348.jpg: 640x480 3 short sleeve tops, 2 shortss, 8.2ms
# image 141/5250 /kaggle/working/yolo/seg/val/images/005396.jpg: 448x640 2 short sleeve tops, 2 trouserss, 8.0ms
# image 142/5250 /kaggle/working/yolo/seg/val/images/005426.jpg: 640x448 3 shortss, 1 skirt, 8.4ms
# image 143/5250 /kaggle/working/yolo/seg/val/images/005504.jpg: 640x480 1 skirt, 2 trouserss, 8.2ms
# image 144/5250 /kaggle/working/yolo/seg/val/images/005506.jpg: 640x448 2 trouserss, 7.9ms
# image 145/5250 /kaggle/working/yolo/seg/val/images/005528.jpg: 640x448 2 trouserss, 7.3ms
# image 146/5250 /kaggle/working/yolo/seg/val/images/005555.jpg: 640x256 5 long sleeve tops, 2 trouserss, 49.7ms
# image 147/5250 /kaggle/working/yolo/seg/val/images/005603.jpg: 640x480 4 short sleeve tops, 1 skirt, 8.6ms
# image 148/5250 /kaggle/working/yolo/seg/val/images/005611.jpg: 640x544 2 long sleeve tops, 2 short sleeve tops, 1 skirt, 9.6ms
# image 149/5250 /kaggle/working/yolo/seg/val/images/005668.jpg: 640x640 2 trouserss, 9.7ms
# image 150/5250 /kaggle/working/yolo/seg/val/images/005670.jpg: 640x480 1 long sleeve top, 2 trouserss, 8.2ms
# image 151/5250 /kaggle/working/yolo/seg/val/images/005678.jpg: 640x448 5 long sleeve tops, 2 trouserss, 8.0ms
# image 152/5250 /kaggle/working/yolo/seg/val/images/005798.jpg: 640x448 2 trouserss, 7.3ms
# image 153/5250 /kaggle/working/yolo/seg/val/images/005799.jpg: 640x448 2 trouserss, 7.3ms
# image 154/5250 /kaggle/working/yolo/seg/val/images/005837.jpg: 608x640 3 long sleeve tops, 2 trouserss, 48.4ms
# image 155/5250 /kaggle/working/yolo/seg/val/images/005844.jpg: 640x448 1 short sleeve top, 1 trousers, 8.3ms
# image 156/5250 /kaggle/working/yolo/seg/val/images/005879.jpg: 640x448 2 short sleeve tops, 1 skirt, 7.2ms
# image 157/5250 /kaggle/working/yolo/seg/val/images/005882.jpg: 640x384 4 long sleeve tops, 1 trousers, 7.7ms
# image 158/5250 /kaggle/working/yolo/seg/val/images/005940.jpg: 640x576 2 shortss, 9.5ms
# image 159/5250 /kaggle/working/yolo/seg/val/images/005987.jpg: 640x640 3 shortss, 9.6ms
# image 160/5250 /kaggle/working/yolo/seg/val/images/006095.jpg: 640x448 1 skirt, 7.8ms
# image 161/5250 /kaggle/working/yolo/seg/val/images/006109.jpg: 640x480 4 long sleeve tops, 2 shortss, 8.0ms
# image 162/5250 /kaggle/working/yolo/seg/val/images/006119.jpg: 640x448 2 trouserss, 7.8ms
# image 163/5250 /kaggle/working/yolo/seg/val/images/006125.jpg: 640x480 1 short sleeve top, 1 trousers, 7.9ms
# image 164/5250 /kaggle/working/yolo/seg/val/images/006265.jpg: 640x640 2 shortss, 9.6ms
# image 165/5250 /kaggle/working/yolo/seg/val/images/006325.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.8ms
# image 166/5250 /kaggle/working/yolo/seg/val/images/006375.jpg: 640x384 1 short sleeve top, 2 trouserss, 7.6ms
# image 167/5250 /kaggle/working/yolo/seg/val/images/006394.jpg: 640x640 3 short sleeve tops, 2 shortss, 9.6ms
# image 168/5250 /kaggle/working/yolo/seg/val/images/006498.jpg: 640x480 1 short sleeve top, 1 skirt, 7.9ms
# image 169/5250 /kaggle/working/yolo/seg/val/images/006563.jpg: 640x480 2 long sleeve tops, 2 short sleeve tops, 2 trouserss, 7.3ms
# image 170/5250 /kaggle/working/yolo/seg/val/images/006764.jpg: 640x512 3 short sleeve tops, 2 shortss, 2 trouserss, 7.9ms
# image 171/5250 /kaggle/working/yolo/seg/val/images/006767.jpg: 640x480 3 short sleeve tops, 2 trouserss, 7.9ms
# image 172/5250 /kaggle/working/yolo/seg/val/images/006770.jpg: 640x480 3 short sleeve tops, 7.3ms
# image 173/5250 /kaggle/working/yolo/seg/val/images/006771.jpg: 384x640 4 short sleeve tops, 46.7ms
# image 174/5250 /kaggle/working/yolo/seg/val/images/006807.jpg: 544x640 3 long sleeve tops, 1 skirt, 9.2ms
# image 175/5250 /kaggle/working/yolo/seg/val/images/006877.jpg: 640x448 2 shortss, 7.8ms
# image 176/5250 /kaggle/working/yolo/seg/val/images/006878.jpg: 640x448 2 shortss, 7.1ms
# image 177/5250 /kaggle/working/yolo/seg/val/images/006906.jpg: 640x448 1 skirt, 7.1ms
# image 178/5250 /kaggle/working/yolo/seg/val/images/006955.jpg: 640x480 2 short sleeve tops, 1 skirt, 7.9ms
# image 179/5250 /kaggle/working/yolo/seg/val/images/006982.jpg: 640x448 1 trousers, 7.8ms
# image 180/5250 /kaggle/working/yolo/seg/val/images/007077.jpg: 640x448 5 long sleeve tops, 2 shortss, 7.2ms
# image 181/5250 /kaggle/working/yolo/seg/val/images/007146.jpg: 480x640 5 long sleeve tops, 1 skirt, 7.9ms
# image 182/5250 /kaggle/working/yolo/seg/val/images/007152.jpg: 640x608 1 skirt, 9.7ms
# image 183/5250 /kaggle/working/yolo/seg/val/images/007154.jpg: 640x512 4 long sleeve tops, 1 skirt, 7.9ms
# image 184/5250 /kaggle/working/yolo/seg/val/images/007243.jpg: 640x480 1 short sleeve top, 1 skirt, 8.0ms
# image 185/5250 /kaggle/working/yolo/seg/val/images/007254.jpg: 608x640 2 short sleeve tops, 1 skirt, 9.6ms
# image 186/5250 /kaggle/working/yolo/seg/val/images/007279.jpg: 576x640 1 shorts, 1 skirt, 9.3ms
# image 187/5250 /kaggle/working/yolo/seg/val/images/007317.jpg: 640x384 1 long sleeve top, 2 short sleeve tops, 1 skirt, 7.5ms
# image 188/5250 /kaggle/working/yolo/seg/val/images/007370.jpg: 448x640 3 short sleeve tops, 7.7ms
# image 189/5250 /kaggle/working/yolo/seg/val/images/007372.jpg: 448x640 2 short sleeve tops, 7.1ms
# image 190/5250 /kaggle/working/yolo/seg/val/images/007390.jpg: 640x448 1 short sleeve top, 1 skirt, 7.8ms
# image 191/5250 /kaggle/working/yolo/seg/val/images/007395.jpg: 640x480 1 short sleeve top, 1 shorts, 7.9ms
# image 192/5250 /kaggle/working/yolo/seg/val/images/007475.jpg: 640x640 3 short sleeve tops, 2 trouserss, 9.6ms
# image 193/5250 /kaggle/working/yolo/seg/val/images/007590.jpg: 640x448 2 short sleeve tops, 2 trouserss, 7.8ms
# image 194/5250 /kaggle/working/yolo/seg/val/images/007609.jpg: 640x448 2 short sleeve tops, 2 shortss, 7.2ms
# image 195/5250 /kaggle/working/yolo/seg/val/images/007619.jpg: 640x512 5 long sleeve tops, 2 trouserss, 7.9ms
# image 196/5250 /kaggle/working/yolo/seg/val/images/007663.jpg: 640x384 1 short sleeve top, 2 shortss, 7.3ms
# image 197/5250 /kaggle/working/yolo/seg/val/images/007890.jpg: 640x480 4 short sleeve tops, 2 shortss, 7.9ms
# image 198/5250 /kaggle/working/yolo/seg/val/images/007927.jpg: 640x448 2 short sleeve tops, 2 shortss, 7.8ms
# image 199/5250 /kaggle/working/yolo/seg/val/images/008000.jpg: 640x640 2 long sleeve tops, 2 trouserss, 9.6ms
# image 200/5250 /kaggle/working/yolo/seg/val/images/008010.jpg: 640x544 2 short sleeve tops, 9.3ms
# image 201/5250 /kaggle/working/yolo/seg/val/images/008012.jpg: 640x480 4 short sleeve tops, 8.0ms
# image 202/5250 /kaggle/working/yolo/seg/val/images/008064.jpg: 640x448 1 short sleeve top, 1 shorts, 1 skirt, 7.8ms
# image 203/5250 /kaggle/working/yolo/seg/val/images/008071.jpg: 640x640 3 short sleeve tops, 2 trouserss, 9.7ms
# image 204/5250 /kaggle/working/yolo/seg/val/images/008122.jpg: 640x608 5 long sleeve tops, 2 trouserss, 9.5ms
# image 205/5250 /kaggle/working/yolo/seg/val/images/008132.jpg: 640x480 1 short sleeve top, 1 skirt, 8.0ms
# image 206/5250 /kaggle/working/yolo/seg/val/images/008180.jpg: 640x480 6 long sleeve tops, 2 trouserss, 7.3ms
# image 207/5250 /kaggle/working/yolo/seg/val/images/008243.jpg: 640x640 1 long sleeve top, 1 short sleeve top, 9.6ms
# image 208/5250 /kaggle/working/yolo/seg/val/images/008262.jpg: 640x480 5 long sleeve tops, 3 trouserss, 7.9ms
# image 209/5250 /kaggle/working/yolo/seg/val/images/008413.jpg: 640x480 2 short sleeve tops, 1 skirt, 7.5ms
# image 210/5250 /kaggle/working/yolo/seg/val/images/008418.jpg: 640x480 4 short sleeve tops, 1 skirt, 7.3ms
# image 211/5250 /kaggle/working/yolo/seg/val/images/008419.jpg: 640x640 3 short sleeve tops, 1 skirt, 9.6ms
# image 212/5250 /kaggle/working/yolo/seg/val/images/008426.jpg: 448x640 2 short sleeve tops, 1 skirt, 7.7ms
# image 213/5250 /kaggle/working/yolo/seg/val/images/008471.jpg: 640x448 6 long sleeve tops, 2 shortss, 7.8ms
# image 214/5250 /kaggle/working/yolo/seg/val/images/008472.jpg: 640x416 3 long sleeve tops, 3 short sleeve tops, 2 shortss, 7.7ms
# image 215/5250 /kaggle/working/yolo/seg/val/images/008507.jpg: 640x640 1 skirt, 9.6ms
# image 216/5250 /kaggle/working/yolo/seg/val/images/008510.jpg: 640x448 1 skirt, 7.8ms
# image 217/5250 /kaggle/working/yolo/seg/val/images/008526.jpg: 640x448 2 short sleeve tops, 1 shorts, 1 skirt, 7.1ms
# image 218/5250 /kaggle/working/yolo/seg/val/images/008599.jpg: 640x640 3 short sleeve tops, 2 shortss, 9.7ms
# image 219/5250 /kaggle/working/yolo/seg/val/images/008622.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.7ms
# image 220/5250 /kaggle/working/yolo/seg/val/images/008674.jpg: 640x544 3 short sleeve tops, 1 skirt, 9.3ms
# image 221/5250 /kaggle/working/yolo/seg/val/images/008682.jpg: 640x480 2 shortss, 8.0ms
# image 222/5250 /kaggle/working/yolo/seg/val/images/008685.jpg: 640x640 2 short sleeve tops, 2 shortss, 9.6ms
# image 223/5250 /kaggle/working/yolo/seg/val/images/008747.jpg: 640x448 1 skirt, 7.8ms
# image 224/5250 /kaggle/working/yolo/seg/val/images/008819.jpg: 640x352 2 short sleeve tops, 1 skirt, 46.9ms
# image 225/5250 /kaggle/working/yolo/seg/val/images/008831.jpg: 640x640 3 short sleeve tops, 1 skirt, 9.6ms
# image 226/5250 /kaggle/working/yolo/seg/val/images/008856.jpg: 640x448 1 short sleeve top, 1 shorts, 2 trouserss, 7.8ms
# image 227/5250 /kaggle/working/yolo/seg/val/images/008861.jpg: 480x640 1 short sleeve top, 2 shortss, 7.9ms
# image 228/5250 /kaggle/working/yolo/seg/val/images/008869.jpg: 640x480 1 short sleeve top, 2 shortss, 8.0ms
# image 229/5250 /kaggle/working/yolo/seg/val/images/008918.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.7ms
# image 230/5250 /kaggle/working/yolo/seg/val/images/009141.jpg: 640x448 1 skirt, 7.2ms
# image 231/5250 /kaggle/working/yolo/seg/val/images/009220.jpg: 640x480 3 short sleeve tops, 7.9ms
# image 232/5250 /kaggle/working/yolo/seg/val/images/009222.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.7ms
# image 233/5250 /kaggle/working/yolo/seg/val/images/009264.jpg: 640x480 5 long sleeve tops, 7.9ms
# image 234/5250 /kaggle/working/yolo/seg/val/images/009267.jpg: 640x640 5 long sleeve tops, 1 skirt, 9.6ms
# image 235/5250 /kaggle/working/yolo/seg/val/images/009310.jpg: 640x448 4 short sleeve tops, 2 trouserss, 7.8ms
# image 236/5250 /kaggle/working/yolo/seg/val/images/009338.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.2ms
# image 237/5250 /kaggle/working/yolo/seg/val/images/009378.jpg: 640x416 5 long sleeve tops, 2 trouserss, 7.6ms
# image 238/5250 /kaggle/working/yolo/seg/val/images/009411.jpg: 640x448 3 short sleeve tops, 1 skirt, 7.8ms
# image 239/5250 /kaggle/working/yolo/seg/val/images/009451.jpg: 640x448 2 long sleeve tops, 1 skirt, 7.2ms
# image 240/5250 /kaggle/working/yolo/seg/val/images/009511.jpg: 640x608 6 long sleeve tops, 2 trouserss, 9.6ms
# image 241/5250 /kaggle/working/yolo/seg/val/images/009540.jpg: 640x480 1 skirt, 8.0ms
# image 242/5250 /kaggle/working/yolo/seg/val/images/009541.jpg: 640x480 2 long sleeve tops, 1 trousers, 7.3ms
# image 243/5250 /kaggle/working/yolo/seg/val/images/009551.jpg: 640x416 6 long sleeve tops, 2 trouserss, 7.7ms
# image 244/5250 /kaggle/working/yolo/seg/val/images/009566.jpg: 640x480 3 short sleeve tops, 7.9ms
# image 245/5250 /kaggle/working/yolo/seg/val/images/009649.jpg: 640x640 5 long sleeve tops, 2 trouserss, 9.6ms
# image 246/5250 /kaggle/working/yolo/seg/val/images/009663.jpg: 640x448 6 long sleeve tops, 2 trouserss, 7.8ms
# image 247/5250 /kaggle/working/yolo/seg/val/images/009665.jpg: 640x448 4 long sleeve tops, 2 trouserss, 7.1ms
# image 248/5250 /kaggle/working/yolo/seg/val/images/009681.jpg: 640x448 3 short sleeve tops, 1 skirt, 7.2ms
# image 249/5250 /kaggle/working/yolo/seg/val/images/009702.jpg: 640x480 2 short sleeve tops, 1 skirt, 7.9ms
# image 250/5250 /kaggle/working/yolo/seg/val/images/009741.jpg: 384x640 1 long sleeve top, 2 short sleeve tops, 7.5ms
# image 251/5250 /kaggle/working/yolo/seg/val/images/009790.jpg: 640x448 3 short sleeve tops, 1 shorts, 2 trouserss, 7.8ms
# image 252/5250 /kaggle/working/yolo/seg/val/images/009836.jpg: 640x480 2 short sleeve tops, 2 trouserss, 8.0ms
# image 253/5250 /kaggle/working/yolo/seg/val/images/009949.jpg: 640x480 1 long sleeve top, 7.3ms
# image 254/5250 /kaggle/working/yolo/seg/val/images/009960.jpg: 640x448 2 short sleeve tops, 1 skirt, 7.7ms
# image 255/5250 /kaggle/working/yolo/seg/val/images/009961.jpg: 640x448 2 short sleeve tops, 1 skirt, 7.1ms
# image 256/5250 /kaggle/working/yolo/seg/val/images/009964.jpg: 640x448 3 short sleeve tops, 1 skirt, 7.2ms
# image 257/5250 /kaggle/working/yolo/seg/val/images/009998.jpg: 640x448 2 trouserss, 7.1ms
# image 258/5250 /kaggle/working/yolo/seg/val/images/010009.jpg: 640x448 3 long sleeve tops, 2 shortss, 7.2ms
# image 259/5250 /kaggle/working/yolo/seg/val/images/010029.jpg: 640x448 3 short sleeve tops, 2 shortss, 1 skirt, 7.2ms
# image 260/5250 /kaggle/working/yolo/seg/val/images/010045.jpg: 640x640 3 short sleeve tops, 3 trouserss, 9.7ms
# image 261/5250 /kaggle/working/yolo/seg/val/images/010096.jpg: 640x640 1 shorts, 9.0ms
# image 262/5250 /kaggle/working/yolo/seg/val/images/010100.jpg: 640x480 2 shortss, 7.9ms
# image 263/5250 /kaggle/working/yolo/seg/val/images/010120.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.8ms
# image 264/5250 /kaggle/working/yolo/seg/val/images/010157.jpg: 640x480 1 short sleeve top, 7.9ms
# image 265/5250 /kaggle/working/yolo/seg/val/images/010227.jpg: 640x448 1 shorts, 7.7ms
# image 266/5250 /kaggle/working/yolo/seg/val/images/010299.jpg: 640x512 2 trouserss, 7.9ms
# image 267/5250 /kaggle/working/yolo/seg/val/images/010312.jpg: 640x480 3 short sleeve tops, 2 shortss, 8.0ms
# image 268/5250 /kaggle/working/yolo/seg/val/images/010326.jpg: 640x480 3 long sleeve tops, 2 trouserss, 7.3ms
# image 269/5250 /kaggle/working/yolo/seg/val/images/010418.jpg: 640x576 3 short sleeve tops, 2 trouserss, 9.4ms
# image 270/5250 /kaggle/working/yolo/seg/val/images/010462.jpg: 384x640 1 long sleeve top, 7.6ms
# image 271/5250 /kaggle/working/yolo/seg/val/images/010528.jpg: 640x480 3 short sleeve tops, 1 skirt, 1 trousers, 7.9ms
# image 272/5250 /kaggle/working/yolo/seg/val/images/010529.jpg: 608x640 3 short sleeve tops, 1 trousers, 9.5ms
# image 273/5250 /kaggle/working/yolo/seg/val/images/010625.jpg: 640x448 5 long sleeve tops, 2 shortss, 7.8ms
# image 274/5250 /kaggle/working/yolo/seg/val/images/010722.jpg: 512x640 1 long sleeve top, 2 short sleeve tops, 8.2ms
# image 275/5250 /kaggle/working/yolo/seg/val/images/010732.jpg: 640x640 2 short sleeve tops, 1 skirt, 9.6ms
# image 276/5250 /kaggle/working/yolo/seg/val/images/010755.jpg: 640x448 2 short sleeve tops, 1 trousers, 7.7ms
# image 277/5250 /kaggle/working/yolo/seg/val/images/010766.jpg: 608x640 2 short sleeve tops, 9.5ms
# image 278/5250 /kaggle/working/yolo/seg/val/images/010771.jpg: 640x448 1 long sleeve top, 2 short sleeve tops, 7.9ms
# image 279/5250 /kaggle/working/yolo/seg/val/images/010816.jpg: 640x448 1 short sleeve top, 2 trouserss, 7.1ms
# image 280/5250 /kaggle/working/yolo/seg/val/images/010838.jpg: 576x640 2 short sleeve tops, 1 skirt, 9.4ms
# image 281/5250 /kaggle/working/yolo/seg/val/images/010884.jpg: 640x480 6 long sleeve tops, 2 trouserss, 8.0ms
# image 282/5250 /kaggle/working/yolo/seg/val/images/010907.jpg: 512x640 4 long sleeve tops, 1 skirt, 7.9ms
# image 283/5250 /kaggle/working/yolo/seg/val/images/010944.jpg: 640x448 2 long sleeve tops, 2 short sleeve tops, 1 skirt, 7.9ms
# image 284/5250 /kaggle/working/yolo/seg/val/images/011005.jpg: 640x448 2 trouserss, 7.2ms
# image 285/5250 /kaggle/working/yolo/seg/val/images/011027.jpg: 640x384 2 shortss, 7.6ms
# image 286/5250 /kaggle/working/yolo/seg/val/images/011034.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.8ms
# image 287/5250 /kaggle/working/yolo/seg/val/images/011075.jpg: 640x608 2 shortss, 9.6ms
# image 288/5250 /kaggle/working/yolo/seg/val/images/011096.jpg: 640x480 3 short sleeve tops, 1 skirt, 8.0ms
# image 289/5250 /kaggle/working/yolo/seg/val/images/011105.jpg: 640x480 3 short sleeve tops, 1 skirt, 7.3ms
# image 290/5250 /kaggle/working/yolo/seg/val/images/011113.jpg: 640x640 2 short sleeve tops, 1 skirt, 9.6ms
# image 291/5250 /kaggle/working/yolo/seg/val/images/011197.jpg: 640x448 2 short sleeve tops, 2 shortss, 7.8ms
# image 292/5250 /kaggle/working/yolo/seg/val/images/011249.jpg: 640x576 1 shorts, 1 skirt, 9.4ms
# image 293/5250 /kaggle/working/yolo/seg/val/images/011265.jpg: 640x448 3 short sleeve tops, 1 skirt, 1 trousers, 7.8ms
# image 294/5250 /kaggle/working/yolo/seg/val/images/011298.jpg: 448x640 6 long sleeve tops, 2 trouserss, 7.7ms
# image 295/5250 /kaggle/working/yolo/seg/val/images/011315.jpg: 640x448 4 long sleeve tops, 2 trouserss, 7.8ms
# image 296/5250 /kaggle/working/yolo/seg/val/images/011317.jpg: 448x640 5 long sleeve tops, 2 trouserss, 7.7ms
# image 297/5250 /kaggle/working/yolo/seg/val/images/011320.jpg: 640x448 3 long sleeve tops, 2 trouserss, 7.8ms
# image 298/5250 /kaggle/working/yolo/seg/val/images/011327.jpg: 640x640 5 short sleeve tops, 2 shortss, 2 trouserss, 9.6ms
# image 299/5250 /kaggle/working/yolo/seg/val/images/011454.jpg: 640x640 1 short sleeve top, 9.0ms
# image 300/5250 /kaggle/working/yolo/seg/val/images/011536.jpg: 640x384 1 long sleeve top, 2 short sleeve tops, 7.6ms
# image 301/5250 /kaggle/working/yolo/seg/val/images/011545.jpg: 480x640 2 long sleeve tops, 7.9ms
# image 302/5250 /kaggle/working/yolo/seg/val/images/011559.jpg: 640x448 3 long sleeve tops, 2 shortss, 7.8ms
# image 303/5250 /kaggle/working/yolo/seg/val/images/011563.jpg: 640x384 1 short sleeve top, 1 skirt, 7.4ms
# image 304/5250 /kaggle/working/yolo/seg/val/images/011577.jpg: 640x640 4 long sleeve tops, 2 trouserss, 9.6ms
# image 305/5250 /kaggle/working/yolo/seg/val/images/011611.jpg: 640x640 1 skirt, 9.0ms
# image 306/5250 /kaggle/working/yolo/seg/val/images/011618.jpg: 640x640 1 skirt, 9.0ms
# image 307/5250 /kaggle/working/yolo/seg/val/images/011647.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.8ms
# image 308/5250 /kaggle/working/yolo/seg/val/images/011652.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.2ms
# image 309/5250 /kaggle/working/yolo/seg/val/images/011737.jpg: 448x640 1 shorts, 7.7ms
# image 310/5250 /kaggle/working/yolo/seg/val/images/011741.jpg: 640x480 2 trouserss, 7.9ms
# image 311/5250 /kaggle/working/yolo/seg/val/images/011786.jpg: 576x640 4 short sleeve tops, 1 skirt, 9.3ms
# image 312/5250 /kaggle/working/yolo/seg/val/images/011792.jpg: 544x640 2 skirts, 9.2ms
# image 313/5250 /kaggle/working/yolo/seg/val/images/011801.jpg: 416x640 1 long sleeve top, 1 skirt, 47.8ms
# image 314/5250 /kaggle/working/yolo/seg/val/images/011869.jpg: 640x448 1 short sleeve top, 2 trouserss, 7.8ms
# image 315/5250 /kaggle/working/yolo/seg/val/images/011945.jpg: 448x640 1 skirt, 7.7ms
# image 316/5250 /kaggle/working/yolo/seg/val/images/011971.jpg: 640x448 1 short sleeve top, 2 trouserss, 7.8ms
# image 317/5250 /kaggle/working/yolo/seg/val/images/012015.jpg: 640x480 2 trouserss, 7.9ms
# image 318/5250 /kaggle/working/yolo/seg/val/images/012017.jpg: 640x480 2 trouserss, 7.3ms
# image 319/5250 /kaggle/working/yolo/seg/val/images/012037.jpg: 640x448 1 short sleeve top, 2 trouserss, 7.7ms
# image 320/5250 /kaggle/working/yolo/seg/val/images/012111.jpg: 640x576 2 shortss, 1 trousers, 9.4ms
# image 321/5250 /kaggle/working/yolo/seg/val/images/012116.jpg: 640x512 3 short sleeve tops, 1 trousers, 7.9ms
# image 322/5250 /kaggle/working/yolo/seg/val/images/012132.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.7ms
# image 323/5250 /kaggle/working/yolo/seg/val/images/012152.jpg: 640x480 1 skirt, 7.9ms
# image 324/5250 /kaggle/working/yolo/seg/val/images/012171.jpg: 640x448 1 skirt, 7.8ms
# image 325/5250 /kaggle/working/yolo/seg/val/images/012224.jpg: 640x448 4 long sleeve tops, 2 trouserss, 7.1ms
# image 326/5250 /kaggle/working/yolo/seg/val/images/012239.jpg: 640x480 4 short sleeve tops, 7.9ms
# image 327/5250 /kaggle/working/yolo/seg/val/images/012259.jpg: 640x544 3 short sleeve tops, 1 skirt, 9.3ms
# image 328/5250 /kaggle/working/yolo/seg/val/images/012275.jpg: 576x640 5 long sleeve tops, 1 skirt, 9.4ms
# image 329/5250 /kaggle/working/yolo/seg/val/images/012282.jpg: 640x640 1 short sleeve top, 2 shortss, 9.6ms
# image 330/5250 /kaggle/working/yolo/seg/val/images/012326.jpg: 640x448 2 long sleeve tops, 2 short sleeve tops, 2 shortss, 7.8ms
# image 331/5250 /kaggle/working/yolo/seg/val/images/012329.jpg: 640x448 2 long sleeve tops, 2 short sleeve tops, 2 shortss, 7.2ms
# image 332/5250 /kaggle/working/yolo/seg/val/images/012352.jpg: 640x480 1 long sleeve top, 3 short sleeve tops, 2 shortss, 7.9ms
# image 333/5250 /kaggle/working/yolo/seg/val/images/012379.jpg: 640x384 2 short sleeve tops, 2 trouserss, 7.7ms
# image 334/5250 /kaggle/working/yolo/seg/val/images/012495.jpg: 640x640 3 short sleeve tops, 1 shorts, 2 trouserss, 9.6ms
# image 335/5250 /kaggle/working/yolo/seg/val/images/012529.jpg: 640x512 3 short sleeve tops, 2 shortss, 7.9ms
# image 336/5250 /kaggle/working/yolo/seg/val/images/012554.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.8ms
# image 337/5250 /kaggle/working/yolo/seg/val/images/012577.jpg: 640x448 3 long sleeve tops, 2 trouserss, 7.2ms
# image 338/5250 /kaggle/working/yolo/seg/val/images/012627.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.2ms
# image 339/5250 /kaggle/working/yolo/seg/val/images/012680.jpg: 640x480 1 short sleeve top, 1 trousers, 8.0ms
# image 340/5250 /kaggle/working/yolo/seg/val/images/012707.jpg: 640x448 3 long sleeve tops, 2 trouserss, 7.9ms
# image 341/5250 /kaggle/working/yolo/seg/val/images/012762.jpg: 640x448 1 short sleeve top, 1 trousers, 7.2ms
# image 342/5250 /kaggle/working/yolo/seg/val/images/012830.jpg: 640x448 3 shortss, 7.1ms
# image 343/5250 /kaggle/working/yolo/seg/val/images/012903.jpg: 640x512 2 long sleeve tops, 3 short sleeve tops, 2 shortss, 8.1ms
# image 344/5250 /kaggle/working/yolo/seg/val/images/012933.jpg: 640x480 2 long sleeve tops, 1 short sleeve top, 8.0ms
# image 345/5250 /kaggle/working/yolo/seg/val/images/012949.jpg: 640x480 3 short sleeve tops, 7.3ms
# image 346/5250 /kaggle/working/yolo/seg/val/images/013040.jpg: 640x480 2 long sleeve tops, 7.3ms
# image 347/5250 /kaggle/working/yolo/seg/val/images/013102.jpg: 640x512 2 short sleeve tops, 1 skirt, 7.9ms
# image 348/5250 /kaggle/working/yolo/seg/val/images/013276.jpg: 640x608 2 long sleeve tops, 1 trousers, 9.5ms
# image 349/5250 /kaggle/working/yolo/seg/val/images/013286.jpg: 640x384 2 short sleeve tops, 2 trouserss, 7.4ms
# image 350/5250 /kaggle/working/yolo/seg/val/images/013317.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.8ms
# image 351/5250 /kaggle/working/yolo/seg/val/images/013321.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.1ms
# image 352/5250 /kaggle/working/yolo/seg/val/images/013396.jpg: 480x640 2 long sleeve tops, 3 short sleeve tops, 2 shortss, 1 trousers, 7.9ms
# image 353/5250 /kaggle/working/yolo/seg/val/images/013408.jpg: 640x640 1 long sleeve top, 2 short sleeve tops, 2 shortss, 9.6ms
# image 354/5250 /kaggle/working/yolo/seg/val/images/013420.jpg: 640x448 1 trousers, 7.8ms
# image 355/5250 /kaggle/working/yolo/seg/val/images/013595.jpg: 640x480 3 short sleeve tops, 2 trouserss, 8.2ms
# image 356/5250 /kaggle/working/yolo/seg/val/images/013597.jpg: 640x544 3 short sleeve tops, 2 trouserss, 9.3ms
# image 357/5250 /kaggle/working/yolo/seg/val/images/013604.jpg: 640x544 3 short sleeve tops, 2 trouserss, 8.7ms
# image 358/5250 /kaggle/working/yolo/seg/val/images/013636.jpg: 640x480 4 long sleeve tops, 1 short sleeve top, 2 trouserss, 7.9ms
# image 359/5250 /kaggle/working/yolo/seg/val/images/013734.jpg: 640x480 5 long sleeve tops, 1 skirt, 7.9ms
# image 360/5250 /kaggle/working/yolo/seg/val/images/013762.jpg: 640x480 2 trouserss, 7.4ms
# image 361/5250 /kaggle/working/yolo/seg/val/images/013784.jpg: 640x480 3 short sleeve tops, 2 shortss, 7.3ms
# image 362/5250 /kaggle/working/yolo/seg/val/images/013845.jpg: 640x512 1 short sleeve top, 1 trousers, 8.0ms
# image 363/5250 /kaggle/working/yolo/seg/val/images/013919.jpg: 640x480 3 short sleeve tops, 7.9ms
# image 364/5250 /kaggle/working/yolo/seg/val/images/013926.jpg: 640x448 2 short sleeve tops, 2 trouserss, 7.7ms
# image 365/5250 /kaggle/working/yolo/seg/val/images/013929.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.2ms
# image 366/5250 /kaggle/working/yolo/seg/val/images/013949.jpg: 640x480 3 short sleeve tops, 7.9ms
# image 367/5250 /kaggle/working/yolo/seg/val/images/013970.jpg: 640x480 3 short sleeve tops, 2 trouserss, 7.3ms
# image 368/5250 /kaggle/working/yolo/seg/val/images/013997.jpg: 640x448 2 shortss, 2 trouserss, 7.8ms
# image 369/5250 /kaggle/working/yolo/seg/val/images/014029.jpg: 640x448 3 short sleeve tops, 1 skirt, 7.2ms
# image 370/5250 /kaggle/working/yolo/seg/val/images/014061.jpg: 640x640 1 trousers, 9.6ms
# image 371/5250 /kaggle/working/yolo/seg/val/images/014151.jpg: 640x448 1 short sleeve top, 2 shortss, 7.8ms
# image 372/5250 /kaggle/working/yolo/seg/val/images/014175.jpg: 480x640 3 short sleeve tops, 8.1ms
# image 373/5250 /kaggle/working/yolo/seg/val/images/014202.jpg: 640x640 1 long sleeve top, 2 trouserss, 9.6ms
# image 374/5250 /kaggle/working/yolo/seg/val/images/014219.jpg: 640x448 1 skirt, 7.8ms
# image 375/5250 /kaggle/working/yolo/seg/val/images/014224.jpg: 640x448 2 trouserss, 7.1ms
# image 376/5250 /kaggle/working/yolo/seg/val/images/014247.jpg: 640x448 2 trouserss, 7.1ms
# image 377/5250 /kaggle/working/yolo/seg/val/images/014260.jpg: 640x480 1 long sleeve top, 3 short sleeve tops, 8.0ms
# image 378/5250 /kaggle/working/yolo/seg/val/images/014311.jpg: 640x480 3 short sleeve tops, 2 shortss, 7.3ms
# image 379/5250 /kaggle/working/yolo/seg/val/images/014319.jpg: 640x480 3 short sleeve tops, 1 skirt, 7.3ms
# image 380/5250 /kaggle/working/yolo/seg/val/images/014406.jpg: 640x448 2 trouserss, 7.8ms
# image 381/5250 /kaggle/working/yolo/seg/val/images/014443.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.2ms
# image 382/5250 /kaggle/working/yolo/seg/val/images/014449.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.1ms
# image 383/5250 /kaggle/working/yolo/seg/val/images/014458.jpg: 640x640 3 short sleeve tops, 2 shortss, 9.6ms
# image 384/5250 /kaggle/working/yolo/seg/val/images/014528.jpg: 640x640 4 long sleeve tops, 1 skirt, 9.0ms
# image 385/5250 /kaggle/working/yolo/seg/val/images/014529.jpg: 512x640 5 long sleeve tops, 1 skirt, 7.9ms
# image 386/5250 /kaggle/working/yolo/seg/val/images/014563.jpg: 640x448 2 short sleeve tops, 1 shorts, 7.8ms
# image 387/5250 /kaggle/working/yolo/seg/val/images/014588.jpg: 640x480 3 short sleeve tops, 2 shortss, 7.9ms
# image 388/5250 /kaggle/working/yolo/seg/val/images/014593.jpg: 640x480 1 long sleeve top, 3 short sleeve tops, 1 skirt, 7.3ms
# image 389/5250 /kaggle/working/yolo/seg/val/images/014631.jpg: 640x480 2 short sleeve tops, 2 trouserss, 7.4ms
# image 390/5250 /kaggle/working/yolo/seg/val/images/014653.jpg: 640x480 1 skirt, 7.3ms
# image 391/5250 /kaggle/working/yolo/seg/val/images/014729.jpg: 640x640 2 short sleeve tops, 1 skirt, 9.5ms
# image 392/5250 /kaggle/working/yolo/seg/val/images/014740.jpg: 640x448 5 long sleeve tops, 2 shortss, 7.7ms
# image 393/5250 /kaggle/working/yolo/seg/val/images/014795.jpg: 640x448 1 long sleeve top, 2 shortss, 2 trouserss, 7.2ms
# image 394/5250 /kaggle/working/yolo/seg/val/images/014806.jpg: 640x640 3 short sleeve tops, 2 trouserss, 9.6ms
# image 395/5250 /kaggle/working/yolo/seg/val/images/014959.jpg: 640x448 2 shortss, 7.8ms
# image 396/5250 /kaggle/working/yolo/seg/val/images/014963.jpg: 640x448 2 shortss, 1 skirt, 7.2ms
# image 397/5250 /kaggle/working/yolo/seg/val/images/015086.jpg: 640x576 1 skirt, 9.4ms
# image 398/5250 /kaggle/working/yolo/seg/val/images/015127.jpg: 608x640 3 short sleeve tops, 2 shortss, 9.7ms
# image 399/5250 /kaggle/working/yolo/seg/val/images/015138.jpg: 480x640 3 shortss, 1 skirt, 9.0ms
# image 400/5250 /kaggle/working/yolo/seg/val/images/015143.jpg: 640x480 1 long sleeve top, 1 short sleeve top, 2 trouserss, 7.9ms
# image 401/5250 /kaggle/working/yolo/seg/val/images/015149.jpg: 576x640 1 short sleeve top, 2 trouserss, 9.3ms
# image 402/5250 /kaggle/working/yolo/seg/val/images/015180.jpg: 608x640 3 long sleeve tops, 2 trouserss, 9.5ms
# image 403/5250 /kaggle/working/yolo/seg/val/images/015196.jpg: 640x480 2 long sleeve tops, 2 short sleeve tops, 2 trouserss, 7.9ms
# image 404/5250 /kaggle/working/yolo/seg/val/images/015217.jpg: 640x448 4 long sleeve tops, 2 shortss, 1 skirt, 7.9ms
# image 405/5250 /kaggle/working/yolo/seg/val/images/015301.jpg: 640x448 1 short sleeve top, 2 trouserss, 7.2ms
# image 406/5250 /kaggle/working/yolo/seg/val/images/015303.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.2ms
# image 407/5250 /kaggle/working/yolo/seg/val/images/015315.jpg: 640x384 2 shortss, 7.4ms
# image 408/5250 /kaggle/working/yolo/seg/val/images/015319.jpg: 640x480 1 skirt, 1 trousers, 7.9ms
# image 409/5250 /kaggle/working/yolo/seg/val/images/015363.jpg: 640x480 1 long sleeve top, 3 short sleeve tops, 7.3ms
# image 410/5250 /kaggle/working/yolo/seg/val/images/015365.jpg: 640x480 3 long sleeve tops, 1 trousers, 7.3ms
# image 411/5250 /kaggle/working/yolo/seg/val/images/015367.jpg: 640x480 2 long sleeve tops, 7.3ms
# image 412/5250 /kaggle/working/yolo/seg/val/images/015376.jpg: 640x448 4 long sleeve tops, 2 trouserss, 8.2ms
# image 413/5250 /kaggle/working/yolo/seg/val/images/015384.jpg: 640x448 3 long sleeve tops, 1 trousers, 7.1ms
# image 414/5250 /kaggle/working/yolo/seg/val/images/015398.jpg: 640x448 3 short sleeve tops, 1 skirt, 7.1ms
# image 415/5250 /kaggle/working/yolo/seg/val/images/015414.jpg: 640x608 2 short sleeve tops, 1 skirt, 9.6ms
# image 416/5250 /kaggle/working/yolo/seg/val/images/015451.jpg: 640x480 3 short sleeve tops, 2 shortss, 1 trousers, 7.9ms
# image 417/5250 /kaggle/working/yolo/seg/val/images/015465.jpg: 640x480 2 short sleeve tops, 1 skirt, 7.3ms
# image 418/5250 /kaggle/working/yolo/seg/val/images/015480.jpg: 640x448 2 trouserss, 7.8ms
# image 419/5250 /kaggle/working/yolo/seg/val/images/015507.jpg: 448x640 1 skirt, 7.7ms
# image 420/5250 /kaggle/working/yolo/seg/val/images/015511.jpg: 640x448 2 shortss, 7.9ms
# image 421/5250 /kaggle/working/yolo/seg/val/images/015543.jpg: 448x640 1 long sleeve top, 1 trousers, 7.7ms
# image 422/5250 /kaggle/working/yolo/seg/val/images/015545.jpg: 640x448 2 long sleeve tops, 2 trouserss, 7.9ms
# image 423/5250 /kaggle/working/yolo/seg/val/images/015605.jpg: 640x480 4 long sleeve tops, 2 trouserss, 7.9ms
# image 424/5250 /kaggle/working/yolo/seg/val/images/015606.jpg: 640x512 5 long sleeve tops, 2 trouserss, 8.0ms
# image 425/5250 /kaggle/working/yolo/seg/val/images/015612.jpg: 640x448 5 long sleeve tops, 2 trouserss, 7.8ms
# image 426/5250 /kaggle/working/yolo/seg/val/images/015646.jpg: 640x480 4 short sleeve tops, 8.0ms
# image 427/5250 /kaggle/working/yolo/seg/val/images/015671.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.8ms
# image 428/5250 /kaggle/working/yolo/seg/val/images/015690.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.1ms
# image 429/5250 /kaggle/working/yolo/seg/val/images/015695.jpg: 640x384 (no detections), 7.4ms
# image 430/5250 /kaggle/working/yolo/seg/val/images/015705.jpg: 640x384 1 long sleeve top, 1 short sleeve top, 7.0ms
# image 431/5250 /kaggle/working/yolo/seg/val/images/015806.jpg: 640x448 1 trousers, 7.7ms
# image 432/5250 /kaggle/working/yolo/seg/val/images/015807.jpg: 640x640 4 long sleeve tops, 2 trouserss, 9.6ms
# image 433/5250 /kaggle/working/yolo/seg/val/images/015823.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.8ms
# image 434/5250 /kaggle/working/yolo/seg/val/images/015868.jpg: 640x448 3 long sleeve tops, 1 trousers, 7.2ms
# image 435/5250 /kaggle/working/yolo/seg/val/images/015888.jpg: 640x480 2 short sleeve tops, 8.0ms
# image 436/5250 /kaggle/working/yolo/seg/val/images/015976.jpg: 640x544 1 short sleeve top, 1 skirt, 9.3ms
# image 437/5250 /kaggle/working/yolo/seg/val/images/015981.jpg: 640x608 1 short sleeve top, 1 skirt, 9.5ms
# image 438/5250 /kaggle/working/yolo/seg/val/images/016001.jpg: 640x480 3 short sleeve tops, 1 skirt, 7.9ms
# image 439/5250 /kaggle/working/yolo/seg/val/images/016154.jpg: 640x640 3 short sleeve tops, 2 trouserss, 9.8ms
# image 440/5250 /kaggle/working/yolo/seg/val/images/016161.jpg: 640x480 5 short sleeve tops, 7.9ms
# image 441/5250 /kaggle/working/yolo/seg/val/images/016162.jpg: 640x480 3 short sleeve tops, 7.3ms
# image 442/5250 /kaggle/working/yolo/seg/val/images/016175.jpg: 640x448 2 trouserss, 7.8ms
# image 443/5250 /kaggle/working/yolo/seg/val/images/016187.jpg: 640x544 2 trouserss, 9.4ms
# image 444/5250 /kaggle/working/yolo/seg/val/images/016209.jpg: 640x544 3 short sleeve tops, 2 shortss, 8.7ms
# image 445/5250 /kaggle/working/yolo/seg/val/images/016221.jpg: 640x480 2 trouserss, 7.9ms
# image 446/5250 /kaggle/working/yolo/seg/val/images/016330.jpg: 512x640 2 short sleeve tops, 2 shortss, 7.9ms
# image 447/5250 /kaggle/working/yolo/seg/val/images/016348.jpg: 640x448 3 long sleeve tops, 3 trouserss, 7.8ms
# image 448/5250 /kaggle/working/yolo/seg/val/images/016368.jpg: 640x448 2 trouserss, 7.2ms
# image 449/5250 /kaggle/working/yolo/seg/val/images/016388.jpg: 640x448 3 short sleeve tops, 1 shorts, 2 trouserss, 7.1ms
# image 450/5250 /kaggle/working/yolo/seg/val/images/016389.jpg: 640x448 3 short sleeve tops, 1 trousers, 7.1ms
# image 451/5250 /kaggle/working/yolo/seg/val/images/016407.jpg: 640x448 2 short sleeve tops, 2 shortss, 7.2ms
# image 452/5250 /kaggle/working/yolo/seg/val/images/016426.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.1ms
# image 453/5250 /kaggle/working/yolo/seg/val/images/016442.jpg: 640x640 2 trouserss, 9.8ms
# image 454/5250 /kaggle/working/yolo/seg/val/images/016457.jpg: 640x448 1 short sleeve top, 2 shortss, 7.8ms
# image 455/5250 /kaggle/working/yolo/seg/val/images/016522.jpg: 640x640 3 long sleeve tops, 2 trouserss, 9.7ms
# image 456/5250 /kaggle/working/yolo/seg/val/images/016537.jpg: 640x640 1 long sleeve top, 2 trouserss, 9.0ms
# ...
# image 5104/5250 /kaggle/working/yolo/seg/val/images/186875.jpg: 640x512 2 short sleeve tops, 1 skirt, 8.0ms
# image 5105/5250 /kaggle/working/yolo/seg/val/images/186903.jpg: 640x448 3 short sleeve tops, 2 shortss, 8.1ms
# image 5106/5250 /kaggle/working/yolo/seg/val/images/186933.jpg: 640x448 3 short sleeve tops, 1 skirt, 7.4ms
# image 5107/5250 /kaggle/working/yolo/seg/val/images/186991.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.4ms
# image 5108/5250 /kaggle/working/yolo/seg/val/images/187032.jpg: 640x448 2 trouserss, 7.2ms
# image 5109/5250 /kaggle/working/yolo/seg/val/images/187094.jpg: 480x640 3 short sleeve tops, 8.3ms
# image 5110/5250 /kaggle/working/yolo/seg/val/images/187158.jpg: 640x544 5 long sleeve tops, 2 trouserss, 9.5ms
# image 5111/5250 /kaggle/working/yolo/seg/val/images/187260.jpg: 640x640 3 short sleeve tops, 2 trouserss, 9.6ms
# image 5112/5250 /kaggle/working/yolo/seg/val/images/187292.jpg: 640x480 2 short sleeve tops, 8.0ms
# image 5113/5250 /kaggle/working/yolo/seg/val/images/187310.jpg: 640x384 2 trouserss, 8.1ms
# image 5114/5250 /kaggle/working/yolo/seg/val/images/187317.jpg: 640x448 4 short sleeve tops, 1 trousers, 7.8ms
# image 5115/5250 /kaggle/working/yolo/seg/val/images/187339.jpg: 640x480 6 long sleeve tops, 2 trouserss, 8.1ms
# image 5116/5250 /kaggle/working/yolo/seg/val/images/187352.jpg: 640x512 1 long sleeve top, 8.0ms
# image 5117/5250 /kaggle/working/yolo/seg/val/images/187390.jpg: 640x448 2 short sleeve tops, 1 skirt, 7.8ms
# image 5118/5250 /kaggle/working/yolo/seg/val/images/187396.jpg: 640x448 3 short sleeve tops, 1 skirt, 7.3ms
# image 5119/5250 /kaggle/working/yolo/seg/val/images/187453.jpg: 640x640 1 short sleeve top, 9.6ms
# image 5120/5250 /kaggle/working/yolo/seg/val/images/187519.jpg: 640x480 3 short sleeve tops, 8.0ms
# image 5121/5250 /kaggle/working/yolo/seg/val/images/187545.jpg: 640x480 3 short sleeve tops, 1 skirt, 7.3ms
# image 5122/5250 /kaggle/working/yolo/seg/val/images/187569.jpg: 640x448 1 trousers, 8.0ms
# image 5123/5250 /kaggle/working/yolo/seg/val/images/187570.jpg: 512x640 1 shorts, 1 trousers, 8.0ms
# image 5124/5250 /kaggle/working/yolo/seg/val/images/187698.jpg: 640x448 1 skirt, 7.8ms
# image 5125/5250 /kaggle/working/yolo/seg/val/images/187756.jpg: 640x640 3 short sleeve tops, 2 trouserss, 9.7ms
# image 5126/5250 /kaggle/working/yolo/seg/val/images/187770.jpg: 640x448 3 short sleeve tops, 2 trouserss, 8.6ms
# image 5127/5250 /kaggle/working/yolo/seg/val/images/187875.jpg: 448x640 2 shortss, 8.1ms
# image 5128/5250 /kaggle/working/yolo/seg/val/images/187951.jpg: 640x448 3 short sleeve tops, 1 skirt, 8.1ms
# image 5129/5250 /kaggle/working/yolo/seg/val/images/187964.jpg: 640x448 2 trouserss, 7.3ms
# image 5130/5250 /kaggle/working/yolo/seg/val/images/188023.jpg: 640x640 1 short sleeve top, 2 shortss, 9.7ms
# image 5131/5250 /kaggle/working/yolo/seg/val/images/188081.jpg: 640x512 2 long sleeve tops, 2 trouserss, 8.1ms
# image 5132/5250 /kaggle/working/yolo/seg/val/images/188147.jpg: 640x448 3 short sleeve tops, 2 shortss, 8.1ms
# image 5133/5250 /kaggle/working/yolo/seg/val/images/188156.jpg: 640x448 2 long sleeve tops, 2 short sleeve tops, 3 shortss, 7.6ms
# image 5134/5250 /kaggle/working/yolo/seg/val/images/188181.jpg: 640x416 2 long sleeve tops, 3 short sleeve tops, 1 skirt, 8.0ms
# image 5135/5250 /kaggle/working/yolo/seg/val/images/188188.jpg: 640x448 2 shortss, 8.1ms
# image 5136/5250 /kaggle/working/yolo/seg/val/images/188196.jpg: 480x640 3 short sleeve tops, 1 skirt, 8.3ms
# image 5137/5250 /kaggle/working/yolo/seg/val/images/188222.jpg: 640x640 3 short sleeve tops, 1 skirt, 2 trouserss, 9.6ms
# image 5138/5250 /kaggle/working/yolo/seg/val/images/188230.jpg: 640x640 4 long sleeve tops, 3 short sleeve tops, 1 shorts, 2 trouserss, 9.0ms
# image 5139/5250 /kaggle/working/yolo/seg/val/images/188256.jpg: 640x480 3 short sleeve tops, 8.5ms
# image 5140/5250 /kaggle/working/yolo/seg/val/images/188271.jpg: 640x480 2 shortss, 7.5ms
# image 5141/5250 /kaggle/working/yolo/seg/val/images/188284.jpg: 640x384 2 trouserss, 7.9ms
# image 5142/5250 /kaggle/working/yolo/seg/val/images/188302.jpg: 640x448 1 short sleeve top, 2 shortss, 8.7ms
# image 5143/5250 /kaggle/working/yolo/seg/val/images/188304.jpg: 640x512 2 short sleeve tops, 2 shortss, 8.1ms
# image 5144/5250 /kaggle/working/yolo/seg/val/images/188313.jpg: 640x480 2 short sleeve tops, 2 shortss, 8.4ms
# image 5145/5250 /kaggle/working/yolo/seg/val/images/188315.jpg: 416x640 1 short sleeve top, 2 shortss, 8.0ms
# image 5146/5250 /kaggle/working/yolo/seg/val/images/188324.jpg: 640x448 3 short sleeve tops, 1 skirt, 8.1ms
# image 5147/5250 /kaggle/working/yolo/seg/val/images/188352.jpg: 640x480 1 short sleeve top, 8.1ms
# image 5148/5250 /kaggle/working/yolo/seg/val/images/188353.jpg: 640x640 3 long sleeve tops, 1 short sleeve top, 2 trouserss, 9.8ms
# image 5149/5250 /kaggle/working/yolo/seg/val/images/188468.jpg: 640x480 2 skirts, 8.2ms
# image 5150/5250 /kaggle/working/yolo/seg/val/images/188496.jpg: 512x640 5 long sleeve tops, 1 skirt, 8.6ms
# image 5151/5250 /kaggle/working/yolo/seg/val/images/188556.jpg: 640x640 2 short sleeve tops, 2 shortss, 9.8ms
# image 5152/5250 /kaggle/working/yolo/seg/val/images/188575.jpg: 640x448 3 long sleeve tops, 2 trouserss, 8.3ms
# image 5153/5250 /kaggle/working/yolo/seg/val/images/188595.jpg: 640x640 3 short sleeve tops, 1 shorts, 1 trousers, 9.7ms
# image 5154/5250 /kaggle/working/yolo/seg/val/images/188638.jpg: 640x480 1 short sleeve top, 8.6ms
# image 5155/5250 /kaggle/working/yolo/seg/val/images/188667.jpg: 640x480 2 short sleeve tops, 2 trouserss, 7.5ms
# image 5156/5250 /kaggle/working/yolo/seg/val/images/188702.jpg: 640x480 1 short sleeve top, 8.0ms
# image 5157/5250 /kaggle/working/yolo/seg/val/images/188748.jpg: 640x480 3 short sleeve tops, 1 skirt, 7.4ms
# image 5158/5250 /kaggle/working/yolo/seg/val/images/188750.jpg: 640x480 3 short sleeve tops, 1 skirt, 8.2ms
# image 5159/5250 /kaggle/working/yolo/seg/val/images/188796.jpg: 640x448 2 long sleeve tops, 1 short sleeve top, 1 skirt, 2 trouserss, 8.9ms
# image 5160/5250 /kaggle/working/yolo/seg/val/images/188807.jpg: 640x480 4 short sleeve tops, 8.3ms
# image 5161/5250 /kaggle/working/yolo/seg/val/images/188815.jpg: 640x640 3 short sleeve tops, 2 trouserss, 9.7ms
# image 5162/5250 /kaggle/working/yolo/seg/val/images/188878.jpg: 640x448 2 trouserss, 8.4ms
# image 5163/5250 /kaggle/working/yolo/seg/val/images/188889.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.4ms
# image 5164/5250 /kaggle/working/yolo/seg/val/images/188901.jpg: 640x448 4 long sleeve tops, 2 trouserss, 7.3ms
# image 5165/5250 /kaggle/working/yolo/seg/val/images/188907.jpg: 640x480 1 short sleeve top, 8.6ms
# image 5166/5250 /kaggle/working/yolo/seg/val/images/188918.jpg: 640x480 6 long sleeve tops, 1 skirt, 2 trouserss, 7.5ms
# image 5167/5250 /kaggle/working/yolo/seg/val/images/188931.jpg: 576x640 2 long sleeve tops, 2 short sleeve tops, 9.4ms
# image 5168/5250 /kaggle/working/yolo/seg/val/images/189019.jpg: 480x640 4 short sleeve tops, 2 shortss, 8.3ms
# image 5169/5250 /kaggle/working/yolo/seg/val/images/189061.jpg: 640x448 5 long sleeve tops, 2 trouserss, 7.9ms
# image 5170/5250 /kaggle/working/yolo/seg/val/images/189067.jpg: 640x384 2 short sleeve tops, 7.9ms
# image 5171/5250 /kaggle/working/yolo/seg/val/images/189131.jpg: 608x640 2 short sleeve tops, 2 trouserss, 9.6ms
# image 5172/5250 /kaggle/working/yolo/seg/val/images/189187.jpg: 640x448 3 short sleeve tops, 1 skirt, 8.1ms
# image 5173/5250 /kaggle/working/yolo/seg/val/images/189229.jpg: 640x640 2 short sleeve tops, 1 skirt, 9.8ms
# image 5174/5250 /kaggle/working/yolo/seg/val/images/189247.jpg: 640x640 3 short sleeve tops, 1 skirt, 9.1ms
# image 5175/5250 /kaggle/working/yolo/seg/val/images/189258.jpg: 640x640 3 short sleeve tops, 2 shortss, 1 skirt, 9.0ms
# image 5176/5250 /kaggle/working/yolo/seg/val/images/189326.jpg: 416x640 3 short sleeve tops, 2 shortss, 8.3ms
# image 5177/5250 /kaggle/working/yolo/seg/val/images/189362.jpg: 640x640 4 long sleeve tops, 9.6ms
# image 5178/5250 /kaggle/working/yolo/seg/val/images/189412.jpg: 640x448 2 shortss, 8.2ms
# image 5179/5250 /kaggle/working/yolo/seg/val/images/189421.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.5ms
# image 5180/5250 /kaggle/working/yolo/seg/val/images/189480.jpg: 640x448 1 trousers, 7.7ms
# image 5181/5250 /kaggle/working/yolo/seg/val/images/189487.jpg: 640x448 1 trousers, 7.3ms
# image 5182/5250 /kaggle/working/yolo/seg/val/images/189517.jpg: 640x448 2 short sleeve tops, 1 skirt, 8.3ms
# image 5183/5250 /kaggle/working/yolo/seg/val/images/189622.jpg: 640x640 3 long sleeve tops, 1 skirt, 9.9ms
# image 5184/5250 /kaggle/working/yolo/seg/val/images/189632.jpg: 640x544 3 short sleeve tops, 1 skirt, 9.6ms
# image 5185/5250 /kaggle/working/yolo/seg/val/images/189667.jpg: 640x480 2 shortss, 9.0ms
# image 5186/5250 /kaggle/working/yolo/seg/val/images/189801.jpg: 640x480 1 long sleeve top, 3 short sleeve tops, 8.5ms
# image 5187/5250 /kaggle/working/yolo/seg/val/images/189815.jpg: 640x416 2 long sleeve tops, 8.8ms
# image 5188/5250 /kaggle/working/yolo/seg/val/images/189912.jpg: 640x480 1 skirt, 8.5ms
# image 5189/5250 /kaggle/working/yolo/seg/val/images/189948.jpg: 640x640 2 long sleeve tops, 2 short sleeve tops, 2 shortss, 9.7ms
# image 5190/5250 /kaggle/working/yolo/seg/val/images/189985.jpg: 448x640 6 long sleeve tops, 2 trouserss, 8.1ms
# image 5191/5250 /kaggle/working/yolo/seg/val/images/190025.jpg: 416x640 1 long sleeve top, 2 short sleeve tops, 1 skirt, 8.4ms
# image 5192/5250 /kaggle/working/yolo/seg/val/images/190049.jpg: 640x448 4 short sleeve tops, 8.0ms
# image 5193/5250 /kaggle/working/yolo/seg/val/images/190052.jpg: 640x448 1 long sleeve top, 4 short sleeve tops, 10.7ms
# image 5194/5250 /kaggle/working/yolo/seg/val/images/190067.jpg: 640x448 2 short sleeve tops, 3 shortss, 10.6ms
# image 5195/5250 /kaggle/working/yolo/seg/val/images/190070.jpg: 640x448 2 shortss, 1 skirt, 7.7ms
# image 5196/5250 /kaggle/working/yolo/seg/val/images/190169.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.4ms
# image 5197/5250 /kaggle/working/yolo/seg/val/images/190170.jpg: 640x448 5 short sleeve tops, 3 shortss, 7.6ms
# image 5198/5250 /kaggle/working/yolo/seg/val/images/190212.jpg: 640x544 3 short sleeve tops, 1 trousers, 9.5ms
# image 5199/5250 /kaggle/working/yolo/seg/val/images/190284.jpg: 640x512 5 long sleeve tops, 2 shortss, 8.4ms
# image 5200/5250 /kaggle/working/yolo/seg/val/images/190299.jpg: 640x416 3 short sleeve tops, 1 skirt, 8.5ms
# image 5201/5250 /kaggle/working/yolo/seg/val/images/190320.jpg: 640x640 3 short sleeve tops, 2 trouserss, 9.7ms
# image 5202/5250 /kaggle/working/yolo/seg/val/images/190357.jpg: 640x448 3 short sleeve tops, 1 skirt, 1 trousers, 9.1ms
# image 5203/5250 /kaggle/working/yolo/seg/val/images/190374.jpg: 640x448 3 short sleeve tops, 2 shortss, 1 skirt, 7.4ms
# image 5204/5250 /kaggle/working/yolo/seg/val/images/190389.jpg: 640x384 3 short sleeve tops, 1 skirt, 7.8ms
# image 5205/5250 /kaggle/working/yolo/seg/val/images/190391.jpg: 640x480 4 short sleeve tops, 1 skirt, 1 trousers, 8.2ms
# image 5206/5250 /kaggle/working/yolo/seg/val/images/190404.jpg: 640x640 3 short sleeve tops, 1 skirt, 9.7ms
# image 5207/5250 /kaggle/working/yolo/seg/val/images/190465.jpg: 640x448 3 short sleeve tops, 1 skirt, 8.1ms
# image 5208/5250 /kaggle/working/yolo/seg/val/images/190589.jpg: 640x512 2 shortss, 8.0ms
# image 5209/5250 /kaggle/working/yolo/seg/val/images/190728.jpg: 640x480 1 long sleeve top, 1 trousers, 8.2ms
# image 5210/5250 /kaggle/working/yolo/seg/val/images/190745.jpg: 640x480 1 trousers, 7.3ms
# image 5211/5250 /kaggle/working/yolo/seg/val/images/190779.jpg: 640x480 3 short sleeve tops, 2 shortss, 7.7ms
# image 5212/5250 /kaggle/working/yolo/seg/val/images/190791.jpg: 640x544 1 short sleeve top, 2 shortss, 9.4ms
# image 5213/5250 /kaggle/working/yolo/seg/val/images/190889.jpg: 640x448 3 short sleeve tops, 1 trousers, 8.1ms
# image 5214/5250 /kaggle/working/yolo/seg/val/images/191006.jpg: 640x480 3 short sleeve tops, 3 shortss, 8.2ms
# image 5215/5250 /kaggle/working/yolo/seg/val/images/191022.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.9ms
# image 5216/5250 /kaggle/working/yolo/seg/val/images/191058.jpg: 512x640 5 long sleeve tops, 2 trouserss, 8.3ms
# image 5217/5250 /kaggle/working/yolo/seg/val/images/191123.jpg: 576x640 3 short sleeve tops, 2 trouserss, 9.5ms
# image 5218/5250 /kaggle/working/yolo/seg/val/images/191198.jpg: 640x512 3 short sleeve tops, 2 trouserss, 8.3ms
# image 5219/5250 /kaggle/working/yolo/seg/val/images/191203.jpg: 640x480 4 long sleeve tops, 2 trouserss, 8.3ms
# image 5220/5250 /kaggle/working/yolo/seg/val/images/191206.jpg: 640x480 5 long sleeve tops, 1 skirt, 2 trouserss, 7.4ms
# image 5221/5250 /kaggle/working/yolo/seg/val/images/191209.jpg: 640x512 3 short sleeve tops, 1 skirt, 8.2ms
# image 5222/5250 /kaggle/working/yolo/seg/val/images/191240.jpg: 640x448 3 short sleeve tops, 2 trouserss, 8.3ms
# image 5223/5250 /kaggle/working/yolo/seg/val/images/191257.jpg: 640x640 3 short sleeve tops, 9.8ms
# image 5224/5250 /kaggle/working/yolo/seg/val/images/191293.jpg: 640x384 4 long sleeve tops, 2 shortss, 8.3ms
# image 5225/5250 /kaggle/working/yolo/seg/val/images/191299.jpg: 640x480 2 long sleeve tops, 2 short sleeve tops, 8.8ms
# image 5226/5250 /kaggle/working/yolo/seg/val/images/191321.jpg: 640x640 3 short sleeve tops, 1 skirt, 9.8ms
# image 5227/5250 /kaggle/working/yolo/seg/val/images/191339.jpg: 640x640 3 trouserss, 9.0ms
# image 5228/5250 /kaggle/working/yolo/seg/val/images/191349.jpg: 640x640 1 skirt, 9.0ms
# image 5229/5250 /kaggle/working/yolo/seg/val/images/191351.jpg: 640x448 5 long sleeve tops, 1 skirt, 8.1ms
# image 5230/5250 /kaggle/working/yolo/seg/val/images/191429.jpg: 640x608 7 long sleeve tops, 2 trouserss, 9.8ms
# image 5231/5250 /kaggle/working/yolo/seg/val/images/191431.jpg: 640x480 6 long sleeve tops, 2 trouserss, 8.2ms
# image 5232/5250 /kaggle/working/yolo/seg/val/images/191455.jpg: 640x448 4 long sleeve tops, 2 trouserss, 9.5ms
# image 5233/5250 /kaggle/working/yolo/seg/val/images/191478.jpg: 640x640 4 long sleeve tops, 2 shortss, 9.6ms
# image 5234/5250 /kaggle/working/yolo/seg/val/images/191517.jpg: 640x448 3 short sleeve tops, 1 skirt, 8.1ms
# image 5235/5250 /kaggle/working/yolo/seg/val/images/191528.jpg: 640x480 1 short sleeve top, 1 skirt, 8.1ms
# image 5236/5250 /kaggle/working/yolo/seg/val/images/191536.jpg: 640x480 1 short sleeve top, 1 shorts, 1 trousers, 7.4ms
# image 5237/5250 /kaggle/working/yolo/seg/val/images/191590.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.9ms
# image 5238/5250 /kaggle/working/yolo/seg/val/images/191651.jpg: 640x576 3 short sleeve tops, 2 shortss, 9.6ms
# image 5239/5250 /kaggle/working/yolo/seg/val/images/191659.jpg: 640x640 3 short sleeve tops, 2 shortss, 9.7ms
# image 5240/5250 /kaggle/working/yolo/seg/val/images/191707.jpg: 640x448 5 long sleeve tops, 2 shortss, 7.8ms
# image 5241/5250 /kaggle/working/yolo/seg/val/images/191742.jpg: 640x480 1 long sleeve top, 1 short sleeve top, 8.3ms
# image 5242/5250 /kaggle/working/yolo/seg/val/images/191748.jpg: 640x480 3 long sleeve tops, 1 trousers, 7.3ms
# image 5243/5250 /kaggle/working/yolo/seg/val/images/191795.jpg: 640x480 3 short sleeve tops, 2 shortss, 7.4ms
# image 5244/5250 /kaggle/working/yolo/seg/val/images/191797.jpg: 640x448 1 short sleeve top, 2 shortss, 8.1ms
# image 5245/5250 /kaggle/working/yolo/seg/val/images/191819.jpg: 640x384 1 short sleeve top, 1 skirt, 7.7ms
# image 5246/5250 /kaggle/working/yolo/seg/val/images/191858.jpg: 640x384 2 long sleeve tops, 6.9ms
# image 5247/5250 /kaggle/working/yolo/seg/val/images/191891.jpg: 640x448 2 short sleeve tops, 1 trousers, 7.9ms
# image 5248/5250 /kaggle/working/yolo/seg/val/images/191901.jpg: 640x448 3 short sleeve tops, 1 trousers, 7.2ms
# image 5249/5250 /kaggle/working/yolo/seg/val/images/191918.jpg: 640x448 5 long sleeve tops, 2 shortss, 7.2ms
# image 5250/5250 /kaggle/working/yolo/seg/val/images/191919.jpg: 640x448 6 long sleeve tops, 2 trouserss, 7.4ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 448)
# Processed 5250 images for validation.

# %% [markdown]
# # Segmentation-metrics

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os, json

# ── Variables needed for ROC ──────────────────────────────────────
iou_threshold = 0.5
thresholds    = np.linspace(0, 1, 50)
class_ids     = list(model_seg.names.keys())   # [0, 1, 2, 3, 4]

# ── Single pass: cache both predictions and GT ────────────────────
cache = []

results_roc = model_seg.predict(
    "/kaggle/working/yolo/seg/val/images",
    save=False,
    conf=0.001,
    stream=True,   # memory safe
)

for result in results_roc:
    img = Image.open(result.path)
    W, H = img.size
    img.close()

    img_name  = os.path.basename(result.path)
    anno_path = os.path.join(ANNO_DIR, img_name.replace(".jpg", ".json"))

    gt_boxes, gt_classes = [], []
    if os.path.exists(anno_path):
        with open(anno_path) as f:
            data = json.load(f)
        for item in data.values():
            if not isinstance(item, dict):
                continue
            cat = item.get("category_name")
            if cat not in class_to_id:
                continue
            bbox = item.get("bounding_box")
            if bbox is None:
                continue
            x1, y1, x2, y2 = bbox
            if x2 <= x1 or y2 <= y1:
                continue
            gt_classes.append(class_to_id[cat])   # 0-indexed, matches model_seg.names
            gt_boxes.append([x1, y1, x2, y2])

    cache.append({
        "pred_boxes":   result.boxes.xyxy.cpu().numpy(),
        "pred_scores":  result.boxes.conf.cpu().numpy(),
        "pred_classes": result.boxes.cls.cpu().numpy(),
        "gt_boxes":     gt_boxes,
        "gt_classes":   gt_classes,
    })

print(f"Cached {len(cache)} images")

# ── Per-class ROC ─────────────────────────────────────────────────
plt.figure()

for cls_id in class_ids:
    all_tpr, all_fpr = [], []

    for thresh in thresholds:
        TP, FP, FN, TN = 0, 0, 0, 0

        for entry in cache:
            pred_boxes   = entry["pred_boxes"]
            pred_scores  = entry["pred_scores"]
            pred_classes = entry["pred_classes"]
            gt_boxes     = entry["gt_boxes"]
            gt_classes   = entry["gt_classes"]

            used_gt = set()

            for p_box, score, p_cls in zip(pred_boxes, pred_scores, pred_classes):
                if score < thresh or int(p_cls) != cls_id:
                    continue
                best_iou, best_gt_idx = 0, -1
                for i, gt in enumerate(gt_boxes):
                    if i in used_gt or gt_classes[i] != cls_id:
                        continue
                    x1 = max(p_box[0], gt[0]); y1 = max(p_box[1], gt[1])
                    x2 = min(p_box[2], gt[2]); y2 = min(p_box[3], gt[3])
                    inter = max(0, x2-x1) * max(0, y2-y1)
                    union = ((p_box[2]-p_box[0])*(p_box[3]-p_box[1]) +
                             (gt[2]-gt[0])*(gt[3]-gt[1]) - inter)
                    iou = inter / (union + 1e-16)
                    if iou > best_iou:
                        best_iou = iou; best_gt_idx = i

                if best_iou >= iou_threshold:
                    TP += 1; used_gt.add(best_gt_idx)
                else:
                    FP += 1

            FN += sum(1 for i in range(len(gt_boxes))
                      if gt_classes[i] == cls_id and i not in used_gt)
            TN += sum(1 for i in range(len(gt_boxes))
                      if gt_classes[i] != cls_id)

        TPR = TP / (TP + FN + 1e-16)
        FPR = FP / (FP + TN + 1e-16)
        all_tpr.append(TPR); all_fpr.append(FPR)

    all_fpr = np.array(all_fpr)
    all_tpr = np.array(all_tpr)
    idx     = np.argsort(all_fpr)
    roc_auc = float(np.trapz(all_tpr[idx], all_fpr[idx]))
    plt.plot(all_fpr[idx], all_tpr[idx],
             label=f"{model_seg.names[cls_id]} (AUC={roc_auc:.2f})")

plt.plot([0,1],[0,1],"--")
plt.xlabel("FPR"); plt.ylabel("TPR")
plt.title("Per-Class ROC — Detection")
plt.legend(); plt.tight_layout()
plt.show()
# Out:
# image 1/5250 /kaggle/working/yolo/seg/val/images/000037.jpg: 480x640 1 short sleeve top, 2 shortss, 3 trouserss, 10.1ms
# image 2/5250 /kaggle/working/yolo/seg/val/images/000047.jpg: 640x480 13 short sleeve tops, 2 shortss, 1 trousers, 8.2ms
# image 3/5250 /kaggle/working/yolo/seg/val/images/000119.jpg: 640x480 22 long sleeve tops, 4 trouserss, 7.3ms
# image 4/5250 /kaggle/working/yolo/seg/val/images/000125.jpg: 640x480 20 long sleeve tops, 18 short sleeve tops, 1 shorts, 1 skirt, 18 trouserss, 7.3ms
# image 5/5250 /kaggle/working/yolo/seg/val/images/000178.jpg: 640x448 1 short sleeve top, 4 trouserss, 7.8ms
# image 6/5250 /kaggle/working/yolo/seg/val/images/000369.jpg: 640x384 10 long sleeve tops, 12 short sleeve tops, 1 shorts, 2 trouserss, 7.5ms
# image 7/5250 /kaggle/working/yolo/seg/val/images/000372.jpg: 640x448 6 long sleeve tops, 4 short sleeve tops, 2 trouserss, 7.8ms
# image 8/5250 /kaggle/working/yolo/seg/val/images/000384.jpg: 640x480 2 long sleeve tops, 34 short sleeve tops, 24 shortss, 10 trouserss, 8.0ms
# image 9/5250 /kaggle/working/yolo/seg/val/images/000468.jpg: 544x640 13 long sleeve tops, 7 short sleeve tops, 2 shortss, 3 trouserss, 9.2ms
# image 10/5250 /kaggle/working/yolo/seg/val/images/000489.jpg: 640x448 12 short sleeve tops, 2 shortss, 7.8ms
# image 11/5250 /kaggle/working/yolo/seg/val/images/000493.jpg: 640x448 8 short sleeve tops, 6 shortss, 7.2ms
# image 12/5250 /kaggle/working/yolo/seg/val/images/000496.jpg: 640x480 24 long sleeve tops, 1 short sleeve top, 16 shortss, 1 skirt, 8.0ms
# image 13/5250 /kaggle/working/yolo/seg/val/images/000578.jpg: 448x640 28 long sleeve tops, 1 short sleeve top, 1 shorts, 1 skirt, 7 trouserss, 7.7ms
# image 14/5250 /kaggle/working/yolo/seg/val/images/000606.jpg: 640x448 33 long sleeve tops, 10 short sleeve tops, 1 shorts, 6 trouserss, 7.8ms
# image 15/5250 /kaggle/working/yolo/seg/val/images/000612.jpg: 576x640 13 long sleeve tops, 6 short sleeve tops, 6 shortss, 4 trouserss, 9.4ms
# image 16/5250 /kaggle/working/yolo/seg/val/images/000655.jpg: 640x448 8 long sleeve tops, 6 short sleeve tops, 3 trouserss, 8.3ms
# image 17/5250 /kaggle/working/yolo/seg/val/images/000675.jpg: 640x448 22 short sleeve tops, 1 skirt, 4 trouserss, 7.8ms
# image 18/5250 /kaggle/working/yolo/seg/val/images/000745.jpg: 640x448 34 long sleeve tops, 1 short sleeve top, 1 skirt, 2 trouserss, 7.3ms
# image 19/5250 /kaggle/working/yolo/seg/val/images/000832.jpg: 640x480 30 long sleeve tops, 17 short sleeve tops, 7 shortss, 2 skirts, 21 trouserss, 7.9ms
# image 20/5250 /kaggle/working/yolo/seg/val/images/000835.jpg: 640x480 18 long sleeve tops, 6 short sleeve tops, 6 trouserss, 7.3ms
# image 21/5250 /kaggle/working/yolo/seg/val/images/000892.jpg: 640x384 2 long sleeve tops, 5 short sleeve tops, 2 trouserss, 7.7ms
# image 22/5250 /kaggle/working/yolo/seg/val/images/000906.jpg: 640x480 13 long sleeve tops, 30 short sleeve tops, 1 shorts, 7.8ms
# image 23/5250 /kaggle/working/yolo/seg/val/images/000908.jpg: 640x480 6 long sleeve tops, 19 short sleeve tops, 2 shortss, 3 trouserss, 7.1ms
# image 24/5250 /kaggle/working/yolo/seg/val/images/000918.jpg: 640x640 5 short sleeve tops, 1 shorts, 5 trouserss, 9.2ms
# image 25/5250 /kaggle/working/yolo/seg/val/images/000945.jpg: 640x448 5 long sleeve tops, 2 short sleeve tops, 2 trouserss, 7.5ms
# image 26/5250 /kaggle/working/yolo/seg/val/images/000971.jpg: 448x640 10 long sleeve tops, 49 short sleeve tops, 25 shortss, 2 skirts, 14 trouserss, 7.6ms
# image 27/5250 /kaggle/working/yolo/seg/val/images/001002.jpg: 640x544 16 long sleeve tops, 1 short sleeve top, 2 shortss, 9.0ms
# image 28/5250 /kaggle/working/yolo/seg/val/images/001010.jpg: 640x448 42 long sleeve tops, 4 shortss, 7.0ms
# image 29/5250 /kaggle/working/yolo/seg/val/images/001057.jpg: 640x448 13 long sleeve tops, 10 shortss, 1 trousers, 7.0ms
# image 30/5250 /kaggle/working/yolo/seg/val/images/001100.jpg: 640x448 2 long sleeve tops, 5 short sleeve tops, 6 shortss, 10 trouserss, 6.6ms
# image 31/5250 /kaggle/working/yolo/seg/val/images/001139.jpg: 640x448 7 short sleeve tops, 4 shortss, 6.5ms
# image 32/5250 /kaggle/working/yolo/seg/val/images/001176.jpg: 640x448 9 long sleeve tops, 2 shortss, 1 skirt, 3 trouserss, 6.4ms
# image 33/5250 /kaggle/working/yolo/seg/val/images/001191.jpg: 640x448 4 long sleeve tops, 5 short sleeve tops, 2 trouserss, 6.4ms
# image 34/5250 /kaggle/working/yolo/seg/val/images/001271.jpg: 640x384 4 long sleeve tops, 1 short sleeve top, 2 trouserss, 7.1ms
# image 35/5250 /kaggle/working/yolo/seg/val/images/001361.jpg: 512x640 27 long sleeve tops, 3 short sleeve tops, 4 shortss, 1 skirt, 4 trouserss, 7.5ms
# image 36/5250 /kaggle/working/yolo/seg/val/images/001402.jpg: 640x448 20 long sleeve tops, 4 short sleeve tops, 20 trouserss, 7.1ms
# image 37/5250 /kaggle/working/yolo/seg/val/images/001415.jpg: 640x448 11 long sleeve tops, 10 short sleeve tops, 8 trouserss, 6.4ms
# image 38/5250 /kaggle/working/yolo/seg/val/images/001453.jpg: 640x448 6 long sleeve tops, 1 short sleeve top, 2 trouserss, 6.5ms
# image 39/5250 /kaggle/working/yolo/seg/val/images/001472.jpg: 640x480 4 long sleeve tops, 4 short sleeve tops, 3 shortss, 3 skirts, 9.3ms
# image 40/5250 /kaggle/working/yolo/seg/val/images/001516.jpg: 640x448 12 long sleeve tops, 21 short sleeve tops, 1 shorts, 2 trouserss, 7.4ms
# image 41/5250 /kaggle/working/yolo/seg/val/images/001537.jpg: 640x512 44 long sleeve tops, 35 short sleeve tops, 2 shortss, 1 skirt, 16 trouserss, 7.2ms
# image 42/5250 /kaggle/working/yolo/seg/val/images/001559.jpg: 640x448 34 long sleeve tops, 25 short sleeve tops, 1 trousers, 7.2ms
# image 43/5250 /kaggle/working/yolo/seg/val/images/001590.jpg: 640x512 22 short sleeve tops, 5 shortss, 1 skirt, 3 trouserss, 7.5ms
# image 44/5250 /kaggle/working/yolo/seg/val/images/001613.jpg: 640x640 2 long sleeve tops, 10 short sleeve tops, 3 shortss, 5 trouserss, 8.2ms
# image 45/5250 /kaggle/working/yolo/seg/val/images/001665.jpg: 640x448 13 long sleeve tops, 4 short sleeve tops, 1 shorts, 1 trousers, 7.4ms
# image 46/5250 /kaggle/working/yolo/seg/val/images/001672.jpg: 640x480 6 long sleeve tops, 5 short sleeve tops, 1 skirt, 7.3ms
# image 47/5250 /kaggle/working/yolo/seg/val/images/001698.jpg: 640x480 35 long sleeve tops, 6 short sleeve tops, 1 skirt, 6.9ms
# image 48/5250 /kaggle/working/yolo/seg/val/images/001730.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.1ms
# image 49/5250 /kaggle/working/yolo/seg/val/images/001737.jpg: 640x416 2 long sleeve tops, 29 short sleeve tops, 18 shortss, 7.1ms
# image 50/5250 /kaggle/working/yolo/seg/val/images/001772.jpg: 640x448 2 long sleeve tops, 5 short sleeve tops, 3 trouserss, 7.2ms
# image 51/5250 /kaggle/working/yolo/seg/val/images/001800.jpg: 640x448 20 long sleeve tops, 1 skirt, 3 trouserss, 6.6ms
# image 52/5250 /kaggle/working/yolo/seg/val/images/001817.jpg: 640x512 13 short sleeve tops, 1 trousers, 7.2ms
# image 53/5250 /kaggle/working/yolo/seg/val/images/001828.jpg: 640x448 4 short sleeve tops, 2 trouserss, 7.6ms
# image 54/5250 /kaggle/working/yolo/seg/val/images/001851.jpg: 640x480 9 long sleeve tops, 3 short sleeve tops, 1 skirt, 4 trouserss, 7.2ms
# image 55/5250 /kaggle/working/yolo/seg/val/images/001955.jpg: 640x384 20 long sleeve tops, 1 skirt, 2 trouserss, 7.0ms
# image 56/5250 /kaggle/working/yolo/seg/val/images/001972.jpg: 512x640 30 long sleeve tops, 18 short sleeve tops, 29 shortss, 3 skirts, 27 trouserss, 7.2ms
# image 57/5250 /kaggle/working/yolo/seg/val/images/001986.jpg: 640x448 19 long sleeve tops, 13 short sleeve tops, 1 shorts, 1 skirt, 1 trousers, 7.3ms
# image 58/5250 /kaggle/working/yolo/seg/val/images/002076.jpg: 640x448 3 long sleeve tops, 15 short sleeve tops, 2 shortss, 1 skirt, 3 trouserss, 6.4ms
# image 59/5250 /kaggle/working/yolo/seg/val/images/002083.jpg: 640x448 3 short sleeve tops, 2 shortss, 6.5ms
# image 60/5250 /kaggle/working/yolo/seg/val/images/002114.jpg: 640x448 16 long sleeve tops, 2 short sleeve tops, 3 trouserss, 7.9ms
# image 61/5250 /kaggle/working/yolo/seg/val/images/002235.jpg: 640x480 8 short sleeve tops, 2 shortss, 7.7ms
# image 62/5250 /kaggle/working/yolo/seg/val/images/002314.jpg: 640x608 5 short sleeve tops, 2 shortss, 8.2ms
# image 63/5250 /kaggle/working/yolo/seg/val/images/002319.jpg: 640x608 4 short sleeve tops, 2 shortss, 1 trousers, 7.9ms
# image 64/5250 /kaggle/working/yolo/seg/val/images/002364.jpg: 640x448 25 long sleeve tops, 10 short sleeve tops, 2 shortss, 1 skirt, 8.4ms
# image 65/5250 /kaggle/working/yolo/seg/val/images/002498.jpg: 640x480 12 long sleeve tops, 25 short sleeve tops, 18 shortss, 5 skirts, 5 trouserss, 7.8ms
# image 66/5250 /kaggle/working/yolo/seg/val/images/002583.jpg: 640x448 21 long sleeve tops, 2 short sleeve tops, 3 shortss, 1 skirt, 24 trouserss, 7.1ms
# image 67/5250 /kaggle/working/yolo/seg/val/images/002599.jpg: 640x544 38 long sleeve tops, 2 short sleeve tops, 3 shortss, 1 skirt, 9 trouserss, 7.9ms
# image 68/5250 /kaggle/working/yolo/seg/val/images/002606.jpg: 640x480 3 long sleeve tops, 8 short sleeve tops, 27 shortss, 1 skirt, 3 trouserss, 7.2ms
# image 69/5250 /kaggle/working/yolo/seg/val/images/002633.jpg: 640x480 1 long sleeve top, 9 short sleeve tops, 1 shorts, 1 skirt, 3 trouserss, 6.6ms
# image 70/5250 /kaggle/working/yolo/seg/val/images/002634.jpg: 640x480 18 long sleeve tops, 12 short sleeve tops, 2 shortss, 1 skirt, 6.7ms
# image 71/5250 /kaggle/working/yolo/seg/val/images/002717.jpg: 640x448 1 long sleeve top, 6 short sleeve tops, 3 shortss, 11 trouserss, 7.3ms
# image 72/5250 /kaggle/working/yolo/seg/val/images/002818.jpg: 640x448 1 short sleeve top, 1 shorts, 1 skirt, 6.7ms
# image 73/5250 /kaggle/working/yolo/seg/val/images/002833.jpg: 640x448 11 long sleeve tops, 28 short sleeve tops, 1 shorts, 1 skirt, 6 trouserss, 6.6ms
# image 74/5250 /kaggle/working/yolo/seg/val/images/002880.jpg: 640x480 23 long sleeve tops, 1 short sleeve top, 1 shorts, 1 skirt, 3 trouserss, 7.4ms
# image 75/5250 /kaggle/working/yolo/seg/val/images/002917.jpg: 640x640 26 long sleeve tops, 1 short sleeve top, 10 shortss, 1 skirt, 19 trouserss, 8.1ms
# image 76/5250 /kaggle/working/yolo/seg/val/images/002922.jpg: 640x640 22 long sleeve tops, 6 short sleeve tops, 2 shortss, 7.5ms
# image 77/5250 /kaggle/working/yolo/seg/val/images/002945.jpg: 640x480 15 long sleeve tops, 1 short sleeve top, 2 trouserss, 7.3ms
# image 78/5250 /kaggle/working/yolo/seg/val/images/002953.jpg: 640x640 18 long sleeve tops, 5 short sleeve tops, 4 shortss, 4 skirts, 8.1ms
# image 79/5250 /kaggle/working/yolo/seg/val/images/002973.jpg: 640x448 18 long sleeve tops, 8 shortss, 3 skirts, 1 trousers, 7.3ms
# image 80/5250 /kaggle/working/yolo/seg/val/images/002998.jpg: 640x480 15 long sleeve tops, 47 short sleeve tops, 11 shortss, 4 skirts, 26 trouserss, 7.1ms
# image 81/5250 /kaggle/working/yolo/seg/val/images/003075.jpg: 640x448 16 long sleeve tops, 6 short sleeve tops, 4 trouserss, 7.4ms
# image 82/5250 /kaggle/working/yolo/seg/val/images/003094.jpg: 640x448 19 long sleeve tops, 2 short sleeve tops, 1 skirt, 6.5ms
# image 83/5250 /kaggle/working/yolo/seg/val/images/003125.jpg: 640x640 7 long sleeve tops, 28 short sleeve tops, 9 shortss, 8.1ms
# image 84/5250 /kaggle/working/yolo/seg/val/images/003156.jpg: 640x448 3 short sleeve tops, 3 skirts, 7.2ms
# image 85/5250 /kaggle/working/yolo/seg/val/images/003167.jpg: 640x480 31 long sleeve tops, 1 short sleeve top, 12 shortss, 1 skirt, 19 trouserss, 7.4ms
# image 86/5250 /kaggle/working/yolo/seg/val/images/003248.jpg: 640x448 4 short sleeve tops, 2 shortss, 7.3ms
# image 87/5250 /kaggle/working/yolo/seg/val/images/003324.jpg: 640x448 4 short sleeve tops, 3 shortss, 8.5ms
# image 88/5250 /kaggle/working/yolo/seg/val/images/003379.jpg: 640x448 6 short sleeve tops, 2 shortss, 7.2ms
# image 89/5250 /kaggle/working/yolo/seg/val/images/003387.jpg: 640x544 21 short sleeve tops, 2 shortss, 7.7ms
# image 90/5250 /kaggle/working/yolo/seg/val/images/003393.jpg: 640x544 7 long sleeve tops, 16 short sleeve tops, 2 shortss, 2 trouserss, 6.9ms
# image 91/5250 /kaggle/working/yolo/seg/val/images/003400.jpg: 640x608 23 long sleeve tops, 1 short sleeve top, 3 shortss, 7.7ms
# image 92/5250 /kaggle/working/yolo/seg/val/images/003774.jpg: 640x640 2 long sleeve tops, 12 short sleeve tops, 2 shortss, 1 skirt, 7.7ms
# image 93/5250 /kaggle/working/yolo/seg/val/images/003797.jpg: 640x512 3 long sleeve tops, 7 short sleeve tops, 3 shortss, 2 skirts, 7.0ms
# image 94/5250 /kaggle/working/yolo/seg/val/images/003945.jpg: 640x384 26 long sleeve tops, 43 short sleeve tops, 6.9ms
# image 95/5250 /kaggle/working/yolo/seg/val/images/003950.jpg: 640x448 37 long sleeve tops, 8 short sleeve tops, 5 shortss, 7.1ms
# image 96/5250 /kaggle/working/yolo/seg/val/images/003997.jpg: 640x480 8 long sleeve tops, 6 short sleeve tops, 3 shortss, 7.3ms
# image 97/5250 /kaggle/working/yolo/seg/val/images/003999.jpg: 640x480 47 long sleeve tops, 39 short sleeve tops, 3 shortss, 1 skirt, 5 trouserss, 6.7ms
# image 98/5250 /kaggle/working/yolo/seg/val/images/004039.jpg: 640x512 2 short sleeve tops, 2 shortss, 7.2ms
# image 99/5250 /kaggle/working/yolo/seg/val/images/004091.jpg: 640x480 4 long sleeve tops, 15 short sleeve tops, 1 skirt, 4 trouserss, 7.2ms
# image 100/5250 /kaggle/working/yolo/seg/val/images/004129.jpg: 640x576 27 long sleeve tops, 1 short sleeve top, 2 trouserss, 7.6ms
# image 101/5250 /kaggle/working/yolo/seg/val/images/004185.jpg: 640x512 8 long sleeve tops, 13 short sleeve tops, 2 shortss, 2 trouserss, 7.4ms
# image 102/5250 /kaggle/working/yolo/seg/val/images/004230.jpg: 640x480 15 long sleeve tops, 2 short sleeve tops, 2 trouserss, 7.7ms
# image 103/5250 /kaggle/working/yolo/seg/val/images/004235.jpg: 480x640 20 long sleeve tops, 6 short sleeve tops, 5 shortss, 7.4ms
# image 104/5250 /kaggle/working/yolo/seg/val/images/004241.jpg: 640x480 86 long sleeve tops, 23 short sleeve tops, 2 shortss, 5 skirts, 8 trouserss, 7.4ms
# image 105/5250 /kaggle/working/yolo/seg/val/images/004269.jpg: 640x480 21 long sleeve tops, 44 short sleeve tops, 23 shortss, 1 skirt, 19 trouserss, 7.0ms
# image 106/5250 /kaggle/working/yolo/seg/val/images/004317.jpg: 640x640 1 long sleeve top, 9 short sleeve tops, 18 shortss, 1 skirt, 14 trouserss, 8.1ms
# image 107/5250 /kaggle/working/yolo/seg/val/images/004339.jpg: 640x480 15 long sleeve tops, 43 short sleeve tops, 9 shortss, 10 trouserss, 7.6ms
# image 108/5250 /kaggle/working/yolo/seg/val/images/004340.jpg: 640x480 9 long sleeve tops, 18 short sleeve tops, 2 shortss, 7.1ms
# image 109/5250 /kaggle/working/yolo/seg/val/images/004366.jpg: 640x480 39 long sleeve tops, 25 short sleeve tops, 9 shortss, 12 trouserss, 6.9ms
# image 110/5250 /kaggle/working/yolo/seg/val/images/004376.jpg: 640x480 165 long sleeve tops, 27 short sleeve tops, 7.0ms
# image 111/5250 /kaggle/working/yolo/seg/val/images/004418.jpg: 640x480 12 long sleeve tops, 24 short sleeve tops, 3 shortss, 1 skirt, 7.0ms
# image 112/5250 /kaggle/working/yolo/seg/val/images/004524.jpg: 640x448 19 long sleeve tops, 2 short sleeve tops, 5 trouserss, 7.2ms
# image 113/5250 /kaggle/working/yolo/seg/val/images/004531.jpg: 640x448 9 long sleeve tops, 9 short sleeve tops, 2 trouserss, 6.7ms
# image 114/5250 /kaggle/working/yolo/seg/val/images/004560.jpg: 640x512 7 long sleeve tops, 49 short sleeve tops, 1 skirt, 7.4ms
# image 115/5250 /kaggle/working/yolo/seg/val/images/004565.jpg: 640x416 16 long sleeve tops, 9 short sleeve tops, 4 shortss, 2 skirts, 7.2ms
# image 116/5250 /kaggle/working/yolo/seg/val/images/004601.jpg: 640x448 1 long sleeve top, 6 short sleeve tops, 4 trouserss, 7.4ms
# image 117/5250 /kaggle/working/yolo/seg/val/images/004716.jpg: 640x480 50 long sleeve tops, 10 short sleeve tops, 3 trouserss, 7.3ms
# image 118/5250 /kaggle/working/yolo/seg/val/images/004719.jpg: 640x480 51 long sleeve tops, 9 short sleeve tops, 14 shortss, 1 skirt, 13 trouserss, 6.9ms
# image 119/5250 /kaggle/working/yolo/seg/val/images/004769.jpg: 480x640 6 long sleeve tops, 5 short sleeve tops, 2 shortss, 19 trouserss, 7.3ms
# image 120/5250 /kaggle/working/yolo/seg/val/images/004777.jpg: 480x640 51 long sleeve tops, 2 short sleeve tops, 8 shortss, 1 skirt, 7 trouserss, 6.8ms
# image 121/5250 /kaggle/working/yolo/seg/val/images/004794.jpg: 640x384 22 long sleeve tops, 6 short sleeve tops, 2 shortss, 11 trouserss, 7.3ms
# image 122/5250 /kaggle/working/yolo/seg/val/images/004797.jpg: 640x480 93 long sleeve tops, 4 short sleeve tops, 1 shorts, 4 trouserss, 7.3ms
# image 123/5250 /kaggle/working/yolo/seg/val/images/004802.jpg: 640x448 11 long sleeve tops, 2 trouserss, 7.3ms
# image 124/5250 /kaggle/working/yolo/seg/val/images/004838.jpg: 640x448 3 short sleeve tops, 4 shortss, 2 trouserss, 6.4ms
# image 125/5250 /kaggle/working/yolo/seg/val/images/004862.jpg: 352x640 8 long sleeve tops, 4 short sleeve tops, 9 shortss, 1 skirt, 6 trouserss, 7.5ms
# image 126/5250 /kaggle/working/yolo/seg/val/images/004882.jpg: 640x480 1 long sleeve top, 5 short sleeve tops, 2 skirts, 4 trouserss, 7.1ms
# image 127/5250 /kaggle/working/yolo/seg/val/images/004885.jpg: 640x640 29 long sleeve tops, 18 short sleeve tops, 1 skirt, 4 trouserss, 7.3ms
# image 128/5250 /kaggle/working/yolo/seg/val/images/004900.jpg: 640x640 6 long sleeve tops, 29 short sleeve tops, 11 shortss, 29 trouserss, 6.7ms
# image 129/5250 /kaggle/working/yolo/seg/val/images/004924.jpg: 640x448 22 long sleeve tops, 1 short sleeve top, 7 trouserss, 7.0ms
# image 130/5250 /kaggle/working/yolo/seg/val/images/004974.jpg: 640x448 11 long sleeve tops, 21 short sleeve tops, 7 shortss, 6.4ms
# image 131/5250 /kaggle/working/yolo/seg/val/images/005062.jpg: 640x448 22 long sleeve tops, 2 shortss, 1 skirt, 2 trouserss, 6.5ms
# image 132/5250 /kaggle/working/yolo/seg/val/images/005078.jpg: 640x480 49 long sleeve tops, 1 short sleeve top, 1 skirt, 11 trouserss, 7.1ms
# image 133/5250 /kaggle/working/yolo/seg/val/images/005156.jpg: 640x448 31 long sleeve tops, 3 shortss, 7.1ms
# image 134/5250 /kaggle/working/yolo/seg/val/images/005198.jpg: 640x512 11 long sleeve tops, 5 short sleeve tops, 1 shorts, 1 skirt, 7.4ms
# image 135/5250 /kaggle/working/yolo/seg/val/images/005247.jpg: 640x448 18 long sleeve tops, 17 shortss, 7.5ms
# image 136/5250 /kaggle/working/yolo/seg/val/images/005257.jpg: 640x448 5 long sleeve tops, 8 short sleeve tops, 3 shortss, 3 skirts, 14 trouserss, 6.9ms
# image 137/5250 /kaggle/working/yolo/seg/val/images/005293.jpg: 640x448 4 short sleeve tops, 2 trouserss, 7.3ms
# image 138/5250 /kaggle/working/yolo/seg/val/images/005337.jpg: 640x448 3 long sleeve tops, 4 short sleeve tops, 6.7ms
# image 139/5250 /kaggle/working/yolo/seg/val/images/005345.jpg: 640x448 2 long sleeve tops, 20 short sleeve tops, 1 skirt, 3 trouserss, 6.6ms
# image 140/5250 /kaggle/working/yolo/seg/val/images/005348.jpg: 640x480 24 long sleeve tops, 20 short sleeve tops, 19 shortss, 10 trouserss, 7.3ms
# image 141/5250 /kaggle/working/yolo/seg/val/images/005396.jpg: 448x640 14 short sleeve tops, 2 trouserss, 7.3ms
# image 142/5250 /kaggle/working/yolo/seg/val/images/005426.jpg: 640x448 29 short sleeve tops, 4 shortss, 1 skirt, 7.4ms
# image 143/5250 /kaggle/working/yolo/seg/val/images/005504.jpg: 640x480 11 short sleeve tops, 2 skirts, 5 trouserss, 7.3ms
# image 144/5250 /kaggle/working/yolo/seg/val/images/005506.jpg: 640x448 1 long sleeve top, 14 short sleeve tops, 2 trouserss, 7.3ms
# image 145/5250 /kaggle/working/yolo/seg/val/images/005528.jpg: 640x448 1 long sleeve top, 6 short sleeve tops, 2 trouserss, 7.1ms
# image 146/5250 /kaggle/working/yolo/seg/val/images/005555.jpg: 640x256 40 long sleeve tops, 3 short sleeve tops, 2 skirts, 2 trouserss, 7.1ms
# image 147/5250 /kaggle/working/yolo/seg/val/images/005603.jpg: 640x480 67 short sleeve tops, 6 shortss, 1 skirt, 1 trousers, 7.6ms
# image 148/5250 /kaggle/working/yolo/seg/val/images/005611.jpg: 640x544 36 long sleeve tops, 13 short sleeve tops, 2 skirts, 7 trouserss, 7.7ms
# image 149/5250 /kaggle/working/yolo/seg/val/images/005668.jpg: 640x640 4 long sleeve tops, 10 short sleeve tops, 2 trouserss, 7.9ms
# image 150/5250 /kaggle/working/yolo/seg/val/images/005670.jpg: 640x480 11 long sleeve tops, 6 short sleeve tops, 2 skirts, 2 trouserss, 7.3ms
# image 151/5250 /kaggle/working/yolo/seg/val/images/005678.jpg: 640x448 15 long sleeve tops, 1 shorts, 2 trouserss, 7.3ms
# image 152/5250 /kaggle/working/yolo/seg/val/images/005798.jpg: 640x448 13 long sleeve tops, 3 short sleeve tops, 5 shortss, 1 skirt, 3 trouserss, 6.6ms
# image 153/5250 /kaggle/working/yolo/seg/val/images/005799.jpg: 640x448 10 long sleeve tops, 9 short sleeve tops, 5 trouserss, 6.6ms
# image 154/5250 /kaggle/working/yolo/seg/val/images/005837.jpg: 608x640 13 long sleeve tops, 2 trouserss, 7.5ms
# image 155/5250 /kaggle/working/yolo/seg/val/images/005844.jpg: 640x448 12 short sleeve tops, 9 trouserss, 7.3ms
# image 156/5250 /kaggle/working/yolo/seg/val/images/005879.jpg: 640x448 9 long sleeve tops, 18 short sleeve tops, 4 shortss, 1 skirt, 6.9ms
# image 157/5250 /kaggle/working/yolo/seg/val/images/005882.jpg: 640x384 11 long sleeve tops, 2 short sleeve tops, 4 shortss, 1 skirt, 6 trouserss, 7.2ms
# image 158/5250 /kaggle/working/yolo/seg/val/images/005940.jpg: 640x576 1 short sleeve top, 2 shortss, 7.4ms
# image 159/5250 /kaggle/working/yolo/seg/val/images/005987.jpg: 640x640 2 short sleeve tops, 3 shortss, 1 trousers, 7.7ms
# image 160/5250 /kaggle/working/yolo/seg/val/images/006095.jpg: 640x448 3 short sleeve tops, 1 shorts, 1 skirt, 3 trouserss, 7.0ms
# image 161/5250 /kaggle/working/yolo/seg/val/images/006109.jpg: 640x480 16 long sleeve tops, 6 short sleeve tops, 2 shortss, 7.3ms
# image 162/5250 /kaggle/working/yolo/seg/val/images/006119.jpg: 640x448 17 long sleeve tops, 2 short sleeve tops, 8 trouserss, 7.2ms
# image 163/5250 /kaggle/working/yolo/seg/val/images/006125.jpg: 640x480 46 long sleeve tops, 28 short sleeve tops, 16 trouserss, 7.1ms
# image 164/5250 /kaggle/working/yolo/seg/val/images/006265.jpg: 640x640 6 long sleeve tops, 32 short sleeve tops, 14 shortss, 7.4ms
# image 165/5250 /kaggle/working/yolo/seg/val/images/006325.jpg: 640x448 3 short sleeve tops, 2 shortss, 7.0ms
# image 166/5250 /kaggle/working/yolo/seg/val/images/006375.jpg: 640x384 8 long sleeve tops, 8 short sleeve tops, 3 shortss, 5 trouserss, 7.0ms
# image 167/5250 /kaggle/working/yolo/seg/val/images/006394.jpg: 640x640 10 short sleeve tops, 4 shortss, 7.4ms
# image 168/5250 /kaggle/working/yolo/seg/val/images/006498.jpg: 640x480 63 long sleeve tops, 38 short sleeve tops, 3 skirts, 5 trouserss, 7.2ms
# image 169/5250 /kaggle/working/yolo/seg/val/images/006563.jpg: 640x480 26 long sleeve tops, 7 short sleeve tops, 2 shortss, 16 trouserss, 6.7ms
# image 170/5250 /kaggle/working/yolo/seg/val/images/006764.jpg: 640x512 3 short sleeve tops, 2 shortss, 2 trouserss, 7.1ms
# image 171/5250 /kaggle/working/yolo/seg/val/images/006767.jpg: 640x480 8 long sleeve tops, 3 short sleeve tops, 3 trouserss, 6.9ms
# image 172/5250 /kaggle/working/yolo/seg/val/images/006770.jpg: 640x480 16 long sleeve tops, 17 short sleeve tops, 1 shorts, 4 skirts, 14 trouserss, 6.4ms
# image 173/5250 /kaggle/working/yolo/seg/val/images/006771.jpg: 384x640 18 long sleeve tops, 14 short sleeve tops, 6.8ms
# image 174/5250 /kaggle/working/yolo/seg/val/images/006807.jpg: 544x640 41 long sleeve tops, 4 short sleeve tops, 2 shortss, 1 skirt, 1 trousers, 7.2ms
# image 175/5250 /kaggle/working/yolo/seg/val/images/006877.jpg: 640x448 9 long sleeve tops, 2 shortss, 2 trouserss, 7.1ms
# image 176/5250 /kaggle/working/yolo/seg/val/images/006878.jpg: 640x448 12 long sleeve tops, 2 shortss, 6.3ms
# image 177/5250 /kaggle/working/yolo/seg/val/images/006906.jpg: 640x448 5 long sleeve tops, 30 short sleeve tops, 2 shortss, 1 skirt, 1 trousers, 6.5ms
# image 178/5250 /kaggle/working/yolo/seg/val/images/006955.jpg: 640x480 12 short sleeve tops, 1 skirt, 7.0ms
# image 179/5250 /kaggle/working/yolo/seg/val/images/006982.jpg: 640x448 20 long sleeve tops, 3 short sleeve tops, 4 shortss, 8 trouserss, 6.8ms
# image 180/5250 /kaggle/working/yolo/seg/val/images/007077.jpg: 640x448 12 long sleeve tops, 1 short sleeve top, 2 shortss, 6.4ms
# image 181/5250 /kaggle/working/yolo/seg/val/images/007146.jpg: 480x640 8 long sleeve tops, 1 shorts, 1 skirt, 2 trouserss, 7.0ms
# image 182/5250 /kaggle/working/yolo/seg/val/images/007152.jpg: 640x608 8 long sleeve tops, 3 short sleeve tops, 4 shortss, 1 skirt, 11 trouserss, 7.5ms
# image 183/5250 /kaggle/working/yolo/seg/val/images/007154.jpg: 640x512 17 long sleeve tops, 1 shorts, 3 skirts, 6 trouserss, 7.0ms
# image 184/5250 /kaggle/working/yolo/seg/val/images/007243.jpg: 640x480 53 long sleeve tops, 36 short sleeve tops, 14 shortss, 4 skirts, 12 trouserss, 7.4ms
# image 185/5250 /kaggle/working/yolo/seg/val/images/007254.jpg: 608x640 4 long sleeve tops, 17 short sleeve tops, 7 shortss, 1 skirt, 1 trousers, 7.3ms
# image 186/5250 /kaggle/working/yolo/seg/val/images/007279.jpg: 576x640 26 short sleeve tops, 5 shortss, 2 skirts, 7.5ms
# image 187/5250 /kaggle/working/yolo/seg/val/images/007317.jpg: 640x384 12 long sleeve tops, 14 short sleeve tops, 2 skirts, 4 trouserss, 7.6ms
# image 188/5250 /kaggle/working/yolo/seg/val/images/007370.jpg: 448x640 4 short sleeve tops, 1 skirt, 1 trousers, 7.4ms
# image 189/5250 /kaggle/working/yolo/seg/val/images/007372.jpg: 448x640 4 short sleeve tops, 12 shortss, 1 skirt, 2 trouserss, 7.0ms
# image 190/5250 /kaggle/working/yolo/seg/val/images/007390.jpg: 640x448 3 long sleeve tops, 7 short sleeve tops, 1 skirt, 7.3ms
# image 191/5250 /kaggle/working/yolo/seg/val/images/007395.jpg: 640x480 10 long sleeve tops, 57 short sleeve tops, 7 shortss, 4 trouserss, 7.3ms
# image 192/5250 /kaggle/working/yolo/seg/val/images/007475.jpg: 640x640 3 short sleeve tops, 2 trouserss, 8.0ms
# image 193/5250 /kaggle/working/yolo/seg/val/images/007590.jpg: 640x448 23 long sleeve tops, 17 short sleeve tops, 1 shorts, 2 trouserss, 7.5ms
# image 194/5250 /kaggle/working/yolo/seg/val/images/007609.jpg: 640x448 28 short sleeve tops, 2 shortss, 7.1ms
# image 195/5250 /kaggle/working/yolo/seg/val/images/007619.jpg: 640x512 21 long sleeve tops, 2 trouserss, 7.6ms
# image 196/5250 /kaggle/working/yolo/seg/val/images/007663.jpg: 640x384 37 long sleeve tops, 15 short sleeve tops, 5 shortss, 7.3ms
# image 197/5250 /kaggle/working/yolo/seg/val/images/007890.jpg: 640x480 9 long sleeve tops, 27 short sleeve tops, 2 shortss, 7.5ms
# image 198/5250 /kaggle/working/yolo/seg/val/images/007927.jpg: 640x448 1 long sleeve top, 3 short sleeve tops, 2 shortss, 7.6ms
# image 199/5250 /kaggle/working/yolo/seg/val/images/008000.jpg: 640x640 11 long sleeve tops, 2 short sleeve tops, 1 skirt, 2 trouserss, 7.7ms
# image 200/5250 /kaggle/working/yolo/seg/val/images/008010.jpg: 640x544 20 long sleeve tops, 10 short sleeve tops, 17 shortss, 1 skirt, 2 trouserss, 9.0ms
# image 201/5250 /kaggle/working/yolo/seg/val/images/008012.jpg: 640x480 16 long sleeve tops, 44 short sleeve tops, 7.5ms
# image 202/5250 /kaggle/working/yolo/seg/val/images/008064.jpg: 640x448 16 short sleeve tops, 2 shortss, 1 skirt, 7.7ms
# image 203/5250 /kaggle/working/yolo/seg/val/images/008071.jpg: 640x640 7 short sleeve tops, 1 shorts, 6 trouserss, 7.8ms
# image 204/5250 /kaggle/working/yolo/seg/val/images/008122.jpg: 640x608 9 long sleeve tops, 1 shorts, 1 skirt, 5 trouserss, 8.3ms
# image 205/5250 /kaggle/working/yolo/seg/val/images/008132.jpg: 640x480 11 long sleeve tops, 26 short sleeve tops, 1 skirt, 7.6ms
# image 206/5250 /kaggle/working/yolo/seg/val/images/008180.jpg: 640x480 15 long sleeve tops, 2 short sleeve tops, 3 trouserss, 6.9ms
# image 207/5250 /kaggle/working/yolo/seg/val/images/008243.jpg: 640x640 81 long sleeve tops, 66 short sleeve tops, 1 shorts, 8.2ms
# image 208/5250 /kaggle/working/yolo/seg/val/images/008262.jpg: 640x480 47 long sleeve tops, 1 short sleeve top, 2 shortss, 7 skirts, 15 trouserss, 7.4ms
# image 209/5250 /kaggle/working/yolo/seg/val/images/008413.jpg: 640x480 10 long sleeve tops, 13 short sleeve tops, 2 shortss, 2 skirts, 6 trouserss, 6.7ms
# image 210/5250 /kaggle/working/yolo/seg/val/images/008418.jpg: 640x480 43 short sleeve tops, 3 skirts, 2 trouserss, 6.7ms
# image 211/5250 /kaggle/working/yolo/seg/val/images/008419.jpg: 640x640 6 long sleeve tops, 9 short sleeve tops, 3 skirts, 7.6ms
# image 212/5250 /kaggle/working/yolo/seg/val/images/008426.jpg: 448x640 18 short sleeve tops, 2 skirts, 2 trouserss, 7.3ms
# image 213/5250 /kaggle/working/yolo/seg/val/images/008471.jpg: 640x448 15 long sleeve tops, 3 shortss, 7.3ms
# image 214/5250 /kaggle/working/yolo/seg/val/images/008472.jpg: 640x416 9 long sleeve tops, 6 short sleeve tops, 3 shortss, 7.3ms
# image 215/5250 /kaggle/working/yolo/seg/val/images/008507.jpg: 640x640 2 long sleeve tops, 2 shortss, 2 skirts, 6 trouserss, 7.6ms
# image 216/5250 /kaggle/working/yolo/seg/val/images/008510.jpg: 640x448 2 short sleeve tops, 1 shorts, 1 skirt, 2 trouserss, 7.2ms
# image 217/5250 /kaggle/working/yolo/seg/val/images/008526.jpg: 640x448 15 short sleeve tops, 4 shortss, 1 skirt, 6.6ms
# image 218/5250 /kaggle/working/yolo/seg/val/images/008599.jpg: 640x640 1 long sleeve top, 4 short sleeve tops, 3 shortss, 1 skirt, 7.7ms
# image 219/5250 /kaggle/working/yolo/seg/val/images/008622.jpg: 640x448 16 short sleeve tops, 2 shortss, 7.4ms
# image 220/5250 /kaggle/working/yolo/seg/val/images/008674.jpg: 640x544 3 long sleeve tops, 5 short sleeve tops, 1 skirt, 3 trouserss, 7.7ms
# image 221/5250 /kaggle/working/yolo/seg/val/images/008682.jpg: 640x480 4 long sleeve tops, 8 short sleeve tops, 3 shortss, 7.5ms
# image 222/5250 /kaggle/working/yolo/seg/val/images/008685.jpg: 640x640 5 long sleeve tops, 17 short sleeve tops, 2 shortss, 7.7ms
# image 223/5250 /kaggle/working/yolo/seg/val/images/008747.jpg: 640x448 16 short sleeve tops, 4 skirts, 1 trousers, 7.2ms
# image 224/5250 /kaggle/working/yolo/seg/val/images/008819.jpg: 640x352 17 short sleeve tops, 1 shorts, 1 skirt, 3 trouserss, 7.2ms
# image 225/5250 /kaggle/working/yolo/seg/val/images/008831.jpg: 640x640 8 long sleeve tops, 4 short sleeve tops, 2 shortss, 1 skirt, 7.4ms
# image 226/5250 /kaggle/working/yolo/seg/val/images/008856.jpg: 640x448 3 short sleeve tops, 1 shorts, 2 trouserss, 8.4ms
# image 227/5250 /kaggle/working/yolo/seg/val/images/008861.jpg: 480x640 44 long sleeve tops, 58 short sleeve tops, 16 shortss, 6 trouserss, 7.8ms
# image 228/5250 /kaggle/working/yolo/seg/val/images/008869.jpg: 640x480 2 long sleeve tops, 28 short sleeve tops, 3 shortss, 5 trouserss, 8.1ms
# image 229/5250 /kaggle/working/yolo/seg/val/images/008918.jpg: 640x448 10 long sleeve tops, 8 short sleeve tops, 3 shortss, 1 trousers, 8.7ms
# image 230/5250 /kaggle/working/yolo/seg/val/images/009141.jpg: 640x448 10 short sleeve tops, 1 skirt, 4 trouserss, 7.0ms
# image 231/5250 /kaggle/working/yolo/seg/val/images/009220.jpg: 640x480 17 long sleeve tops, 38 short sleeve tops, 11 shortss, 1 skirt, 7.5ms
# image 232/5250 /kaggle/working/yolo/seg/val/images/009222.jpg: 640x448 3 long sleeve tops, 10 short sleeve tops, 2 shortss, 1 trousers, 7.5ms
# image 233/5250 /kaggle/working/yolo/seg/val/images/009264.jpg: 640x480 31 long sleeve tops, 6 short sleeve tops, 1 shorts, 4 trouserss, 7.5ms
# image 234/5250 /kaggle/working/yolo/seg/val/images/009267.jpg: 640x640 32 long sleeve tops, 1 shorts, 1 skirt, 2 trouserss, 7.6ms
# image 235/5250 /kaggle/working/yolo/seg/val/images/009310.jpg: 640x448 7 long sleeve tops, 25 short sleeve tops, 2 trouserss, 7.2ms
# image 236/5250 /kaggle/working/yolo/seg/val/images/009338.jpg: 640x448 1 long sleeve top, 3 short sleeve tops, 4 trouserss, 6.6ms
# image 237/5250 /kaggle/working/yolo/seg/val/images/009378.jpg: 640x416 43 long sleeve tops, 2 short sleeve tops, 2 skirts, 2 trouserss, 7.3ms
# image 238/5250 /kaggle/working/yolo/seg/val/images/009411.jpg: 640x448 7 long sleeve tops, 14 short sleeve tops, 2 shortss, 1 skirt, 7.0ms
# image 239/5250 /kaggle/working/yolo/seg/val/images/009451.jpg: 640x448 30 long sleeve tops, 5 short sleeve tops, 2 skirts, 3 trouserss, 6.9ms
# image 240/5250 /kaggle/working/yolo/seg/val/images/009511.jpg: 640x608 15 long sleeve tops, 1 skirt, 2 trouserss, 7.7ms
# image 241/5250 /kaggle/working/yolo/seg/val/images/009540.jpg: 640x480 103 long sleeve tops, 59 short sleeve tops, 2 shortss, 2 skirts, 2 trouserss, 7.8ms
# image 242/5250 /kaggle/working/yolo/seg/val/images/009541.jpg: 640x480 38 long sleeve tops, 18 short sleeve tops, 28 trouserss, 7.2ms
# image 243/5250 /kaggle/working/yolo/seg/val/images/009551.jpg: 640x416 24 long sleeve tops, 2 trouserss, 7.6ms
# image 244/5250 /kaggle/working/yolo/seg/val/images/009566.jpg: 640x480 27 long sleeve tops, 27 short sleeve tops, 7.4ms
# image 245/5250 /kaggle/working/yolo/seg/val/images/009649.jpg: 640x640 73 long sleeve tops, 2 short sleeve tops, 2 trouserss, 7.4ms
# image 246/5250 /kaggle/working/yolo/seg/val/images/009663.jpg: 640x448 41 long sleeve tops, 8 short sleeve tops, 1 shorts, 9 trouserss, 7.2ms
# image 247/5250 /kaggle/working/yolo/seg/val/images/009665.jpg: 640x448 31 long sleeve tops, 6 trouserss, 6.7ms
# image 248/5250 /kaggle/working/yolo/seg/val/images/009681.jpg: 640x448 13 long sleeve tops, 3 short sleeve tops, 1 skirt, 6.8ms
# image 249/5250 /kaggle/working/yolo/seg/val/images/009702.jpg: 640x480 30 long sleeve tops, 17 short sleeve tops, 1 skirt, 7.1ms
# image 250/5250 /kaggle/working/yolo/seg/val/images/009741.jpg: 384x640 26 long sleeve tops, 19 short sleeve tops, 1 shorts, 1 trousers, 7.3ms
# image 251/5250 /kaggle/working/yolo/seg/val/images/009790.jpg: 640x448 10 long sleeve tops, 26 short sleeve tops, 4 shortss, 6 trouserss, 11.7ms
# image 252/5250 /kaggle/working/yolo/seg/val/images/009836.jpg: 640x480 11 long sleeve tops, 16 short sleeve tops, 4 trouserss, 9.8ms
# image 253/5250 /kaggle/working/yolo/seg/val/images/009949.jpg: 640x480 59 long sleeve tops, 25 short sleeve tops, 6 shortss, 1 skirt, 3 trouserss, 7.3ms
# image 254/5250 /kaggle/working/yolo/seg/val/images/009960.jpg: 640x448 9 short sleeve tops, 1 shorts, 1 skirt, 4 trouserss, 7.8ms
# image 255/5250 /kaggle/working/yolo/seg/val/images/009961.jpg: 640x448 17 short sleeve tops, 3 skirts, 1 trousers, 7.0ms
# image 256/5250 /kaggle/working/yolo/seg/val/images/009964.jpg: 640x448 1 long sleeve top, 10 short sleeve tops, 1 skirt, 6.8ms
# image 257/5250 /kaggle/working/yolo/seg/val/images/009998.jpg: 640x448 8 short sleeve tops, 2 trouserss, 6.9ms
# image 258/5250 /kaggle/working/yolo/seg/val/images/010009.jpg: 640x448 37 long sleeve tops, 12 short sleeve tops, 2 shortss, 6.8ms
# image 259/5250 /kaggle/working/yolo/seg/val/images/010029.jpg: 640x448 2 long sleeve tops, 4 short sleeve tops, 2 shortss, 1 skirt, 1 trousers, 6.9ms
# image 260/5250 /kaggle/working/yolo/seg/val/images/010045.jpg: 640x640 1 long sleeve top, 3 short sleeve tops, 10 trouserss, 11.2ms
# image 261/5250 /kaggle/working/yolo/seg/val/images/010096.jpg: 640x640 13 long sleeve tops, 9 short sleeve tops, 26 shortss, 1 trousers, 8.2ms
# image 262/5250 /kaggle/working/yolo/seg/val/images/010100.jpg: 640x480 17 long sleeve tops, 11 short sleeve tops, 14 shortss, 3 trouserss, 11.8ms
# image 263/5250 /kaggle/working/yolo/seg/val/images/010120.jpg: 640x448 1 long sleeve top, 4 short sleeve tops, 1 shorts, 3 trouserss, 9.6ms
# image 264/5250 /kaggle/working/yolo/seg/val/images/010157.jpg: 640x480 30 long sleeve tops, 43 short sleeve tops, 5 shortss, 1 skirt, 17 trouserss, 8.0ms
# image 265/5250 /kaggle/working/yolo/seg/val/images/010227.jpg: 640x448 21 long sleeve tops, 9 short sleeve tops, 49 shortss, 3 skirts, 6 trouserss, 7.3ms
# image 266/5250 /kaggle/working/yolo/seg/val/images/010299.jpg: 640x512 5 long sleeve tops, 4 short sleeve tops, 4 shortss, 1 skirt, 3 trouserss, 7.3ms
# image 267/5250 /kaggle/working/yolo/seg/val/images/010312.jpg: 640x480 15 long sleeve tops, 7 short sleeve tops, 4 shortss, 7.6ms
# image 268/5250 /kaggle/working/yolo/seg/val/images/010326.jpg: 640x480 23 long sleeve tops, 1 short sleeve top, 4 trouserss, 6.7ms
# image 269/5250 /kaggle/working/yolo/seg/val/images/010418.jpg: 640x576 1 long sleeve top, 4 short sleeve tops, 1 shorts, 4 trouserss, 7.6ms
# image 270/5250 /kaggle/working/yolo/seg/val/images/010462.jpg: 384x640 122 long sleeve tops, 16 short sleeve tops, 1 shorts, 1 skirt, 5 trouserss, 7.2ms
# image 271/5250 /kaggle/working/yolo/seg/val/images/010528.jpg: 640x480 17 long sleeve tops, 12 short sleeve tops, 6 shortss, 2 skirts, 18 trouserss, 7.3ms
# image 272/5250 /kaggle/working/yolo/seg/val/images/010529.jpg: 608x640 4 short sleeve tops, 2 trouserss, 7.7ms
# image 273/5250 /kaggle/working/yolo/seg/val/images/010625.jpg: 640x448 9 long sleeve tops, 2 shortss, 7.2ms
# image 274/5250 /kaggle/working/yolo/seg/val/images/010722.jpg: 512x640 20 long sleeve tops, 25 short sleeve tops, 5 shortss, 2 trouserss, 7.4ms
# image 275/5250 /kaggle/working/yolo/seg/val/images/010732.jpg: 640x640 9 short sleeve tops, 1 skirt, 7.6ms
# image 276/5250 /kaggle/working/yolo/seg/val/images/010755.jpg: 640x448 16 long sleeve tops, 31 short sleeve tops, 3 skirts, 17 trouserss, 7.6ms
# image 277/5250 /kaggle/working/yolo/seg/val/images/010766.jpg: 608x640 4 long sleeve tops, 5 short sleeve tops, 2 shortss, 3 skirts, 4 trouserss, 7.6ms
# image 278/5250 /kaggle/working/yolo/seg/val/images/010771.jpg: 640x448 21 long sleeve tops, 9 short sleeve tops, 1 skirt, 1 trousers, 7.0ms
# image 279/5250 /kaggle/working/yolo/seg/val/images/010816.jpg: 640x448 17 short sleeve tops, 2 trouserss, 7.3ms
# image 280/5250 /kaggle/working/yolo/seg/val/images/010838.jpg: 576x640 1 long sleeve top, 19 short sleeve tops, 7 shortss, 1 skirt, 5 trouserss, 7.5ms
# image 281/5250 /kaggle/working/yolo/seg/val/images/010884.jpg: 640x480 24 long sleeve tops, 13 short sleeve tops, 3 trouserss, 7.4ms
# image 282/5250 /kaggle/working/yolo/seg/val/images/010907.jpg: 512x640 33 long sleeve tops, 1 short sleeve top, 4 shortss, 3 skirts, 3 trouserss, 7.3ms
# image 283/5250 /kaggle/working/yolo/seg/val/images/010944.jpg: 640x448 65 long sleeve tops, 18 short sleeve tops, 2 shortss, 1 skirt, 2 trouserss, 7.2ms
# image 284/5250 /kaggle/working/yolo/seg/val/images/011005.jpg: 640x448 33 long sleeve tops, 5 short sleeve tops, 3 trouserss, 6.6ms
# image 285/5250 /kaggle/working/yolo/seg/val/images/011027.jpg: 640x384 6 long sleeve tops, 2 short sleeve tops, 2 shortss, 7.4ms
# image 286/5250 /kaggle/working/yolo/seg/val/images/011034.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.1ms
# image 287/5250 /kaggle/working/yolo/seg/val/images/011075.jpg: 640x608 4 long sleeve tops, 21 short sleeve tops, 2 shortss, 7.7ms
# image 288/5250 /kaggle/working/yolo/seg/val/images/011096.jpg: 640x480 3 short sleeve tops, 1 skirt, 7.6ms
# image 289/5250 /kaggle/working/yolo/seg/val/images/011105.jpg: 640x480 8 short sleeve tops, 1 skirt, 3 trouserss, 6.8ms
# image 290/5250 /kaggle/working/yolo/seg/val/images/011113.jpg: 640x640 1 long sleeve top, 15 short sleeve tops, 3 skirts, 6 trouserss, 7.6ms
# image 291/5250 /kaggle/working/yolo/seg/val/images/011197.jpg: 640x448 20 short sleeve tops, 11 shortss, 7.3ms
# image 292/5250 /kaggle/working/yolo/seg/val/images/011249.jpg: 640x576 4 long sleeve tops, 40 short sleeve tops, 2 shortss, 1 skirt, 1 trousers, 7.5ms
# image 293/5250 /kaggle/working/yolo/seg/val/images/011265.jpg: 640x448 4 long sleeve tops, 8 short sleeve tops, 1 skirt, 3 trouserss, 7.3ms
# image 294/5250 /kaggle/working/yolo/seg/val/images/011298.jpg: 448x640 13 long sleeve tops, 2 trouserss, 7.2ms
# image 295/5250 /kaggle/working/yolo/seg/val/images/011315.jpg: 640x448 36 long sleeve tops, 2 trouserss, 7.2ms
# image 296/5250 /kaggle/working/yolo/seg/val/images/011317.jpg: 448x640 8 long sleeve tops, 1 shorts, 3 trouserss, 7.1ms
# image 297/5250 /kaggle/working/yolo/seg/val/images/011320.jpg: 640x448 55 long sleeve tops, 7 short sleeve tops, 1 shorts, 1 skirt, 2 trouserss, 7.1ms
# image 298/5250 /kaggle/working/yolo/seg/val/images/011327.jpg: 640x640 2 long sleeve tops, 19 short sleeve tops, 3 shortss, 4 trouserss, 7.5ms
# image 299/5250 /kaggle/working/yolo/seg/val/images/011454.jpg: 640x640 2 long sleeve tops, 16 short sleeve tops, 1 shorts, 1 trousers, 7.3ms
# image 300/5250 /kaggle/working/yolo/seg/val/images/011536.jpg: 640x384 23 long sleeve tops, 13 short sleeve tops, 3 trouserss, 7.5ms
# image 301/5250 /kaggle/working/yolo/seg/val/images/011545.jpg: 480x640 37 long sleeve tops, 4 short sleeve tops, 4 shortss, 3 skirts, 13 trouserss, 7.4ms
# image 302/5250 /kaggle/working/yolo/seg/val/images/011559.jpg: 640x448 27 long sleeve tops, 2 shortss, 1 trousers, 7.6ms
# image 303/5250 /kaggle/working/yolo/seg/val/images/011563.jpg: 640x384 11 long sleeve tops, 51 short sleeve tops, 3 shortss, 1 skirt, 2 trouserss, 7.6ms
# image 304/5250 /kaggle/working/yolo/seg/val/images/011577.jpg: 640x640 14 long sleeve tops, 6 short sleeve tops, 1 shorts, 4 trouserss, 7.5ms
# image 305/5250 /kaggle/working/yolo/seg/val/images/011611.jpg: 640x640 1 long sleeve top, 14 short sleeve tops, 3 shortss, 2 skirts, 7.0ms
# image 306/5250 /kaggle/working/yolo/seg/val/images/011618.jpg: 640x640 5 long sleeve tops, 3 short sleeve tops, 3 shortss, 2 skirts, 4 trouserss, 7.0ms
# image 307/5250 /kaggle/working/yolo/seg/val/images/011647.jpg: 640x448 17 long sleeve tops, 13 short sleeve tops, 2 shortss, 7.2ms
# image 308/5250 /kaggle/working/yolo/seg/val/images/011652.jpg: 640x448 3 short sleeve tops, 3 trouserss, 6.9ms
# image 309/5250 /kaggle/working/yolo/seg/val/images/011737.jpg: 448x640 15 long sleeve tops, 9 short sleeve tops, 15 shortss, 1 skirt, 13 trouserss, 7.2ms
# image 310/5250 /kaggle/working/yolo/seg/val/images/011741.jpg: 640x480 15 long sleeve tops, 21 short sleeve tops, 7 shortss, 4 skirts, 14 trouserss, 7.1ms
# image 311/5250 /kaggle/working/yolo/seg/val/images/011786.jpg: 576x640 2 long sleeve tops, 13 short sleeve tops, 1 shorts, 2 skirts, 7.4ms
# image 312/5250 /kaggle/working/yolo/seg/val/images/011792.jpg: 544x640 13 long sleeve tops, 24 short sleeve tops, 17 shortss, 5 skirts, 4 trouserss, 7.3ms
# image 313/5250 /kaggle/working/yolo/seg/val/images/011801.jpg: 416x640 37 long sleeve tops, 10 short sleeve tops, 14 shortss, 3 skirts, 49 trouserss, 7.1ms
# image 314/5250 /kaggle/working/yolo/seg/val/images/011869.jpg: 640x448 3 short sleeve tops, 2 trouserss, 7.1ms
# image 315/5250 /kaggle/working/yolo/seg/val/images/011945.jpg: 448x640 11 long sleeve tops, 11 short sleeve tops, 7 shortss, 3 skirts, 16 trouserss, 7.5ms
# image 316/5250 /kaggle/working/yolo/seg/val/images/011971.jpg: 640x448 6 long sleeve tops, 1 short sleeve top, 2 trouserss, 7.0ms
# image 317/5250 /kaggle/working/yolo/seg/val/images/012015.jpg: 640x480 12 long sleeve tops, 15 short sleeve tops, 3 shortss, 1 skirt, 2 trouserss, 7.2ms
# image 318/5250 /kaggle/working/yolo/seg/val/images/012017.jpg: 640x480 2 long sleeve tops, 12 short sleeve tops, 2 trouserss, 6.7ms
# image 319/5250 /kaggle/working/yolo/seg/val/images/012037.jpg: 640x448 2 long sleeve tops, 4 short sleeve tops, 2 trouserss, 6.9ms
# image 320/5250 /kaggle/working/yolo/seg/val/images/012111.jpg: 640x576 12 long sleeve tops, 8 short sleeve tops, 11 shortss, 6 trouserss, 7.4ms
# image 321/5250 /kaggle/working/yolo/seg/val/images/012116.jpg: 640x512 1 long sleeve top, 7 short sleeve tops, 5 shortss, 1 skirt, 9 trouserss, 7.1ms
# image 322/5250 /kaggle/working/yolo/seg/val/images/012132.jpg: 640x448 1 long sleeve top, 4 short sleeve tops, 2 trouserss, 7.4ms
# image 323/5250 /kaggle/working/yolo/seg/val/images/012152.jpg: 640x480 5 long sleeve tops, 20 short sleeve tops, 7 shortss, 2 skirts, 7.4ms
# image 324/5250 /kaggle/working/yolo/seg/val/images/012171.jpg: 640x448 14 long sleeve tops, 3 short sleeve tops, 2 shortss, 2 skirts, 1 trousers, 7.0ms
# image 325/5250 /kaggle/working/yolo/seg/val/images/012224.jpg: 640x448 31 long sleeve tops, 4 short sleeve tops, 2 shortss, 9 trouserss, 7.0ms
# image 326/5250 /kaggle/working/yolo/seg/val/images/012239.jpg: 640x480 2 long sleeve tops, 87 short sleeve tops, 1 shorts, 6 trouserss, 7.4ms
# image 327/5250 /kaggle/working/yolo/seg/val/images/012259.jpg: 640x544 5 short sleeve tops, 1 skirt, 2 trouserss, 7.3ms
# image 328/5250 /kaggle/working/yolo/seg/val/images/012275.jpg: 576x640 26 long sleeve tops, 3 short sleeve tops, 1 shorts, 1 skirt, 7 trouserss, 7.4ms
# image 329/5250 /kaggle/working/yolo/seg/val/images/012282.jpg: 640x640 17 long sleeve tops, 3 short sleeve tops, 2 shortss, 7.6ms
# image 330/5250 /kaggle/working/yolo/seg/val/images/012326.jpg: 640x448 19 long sleeve tops, 10 short sleeve tops, 2 shortss, 8.7ms
# image 331/5250 /kaggle/working/yolo/seg/val/images/012329.jpg: 640x448 31 long sleeve tops, 14 short sleeve tops, 2 shortss, 6.6ms
# image 332/5250 /kaggle/working/yolo/seg/val/images/012352.jpg: 640x480 11 long sleeve tops, 15 short sleeve tops, 3 shortss, 2 trouserss, 7.6ms
# image 333/5250 /kaggle/working/yolo/seg/val/images/012379.jpg: 640x384 7 long sleeve tops, 8 short sleeve tops, 6 trouserss, 7.1ms
# image 334/5250 /kaggle/working/yolo/seg/val/images/012495.jpg: 640x640 3 short sleeve tops, 1 shorts, 4 trouserss, 7.5ms
# image 335/5250 /kaggle/working/yolo/seg/val/images/012529.jpg: 640x512 9 short sleeve tops, 2 shortss, 7.0ms
# image 336/5250 /kaggle/working/yolo/seg/val/images/012554.jpg: 640x448 1 long sleeve top, 10 short sleeve tops, 2 shortss, 5 trouserss, 7.3ms
# image 337/5250 /kaggle/working/yolo/seg/val/images/012577.jpg: 640x448 15 long sleeve tops, 2 short sleeve tops, 2 trouserss, 6.4ms
# image 338/5250 /kaggle/working/yolo/seg/val/images/012627.jpg: 640x448 7 long sleeve tops, 8 short sleeve tops, 2 shortss, 6.4ms
# image 339/5250 /kaggle/working/yolo/seg/val/images/012680.jpg: 640x480 1 long sleeve top, 1 short sleeve top, 1 shorts, 1 skirt, 20 trouserss, 7.0ms
# image 340/5250 /kaggle/working/yolo/seg/val/images/012707.jpg: 640x448 7 long sleeve tops, 2 trouserss, 7.1ms
# image 341/5250 /kaggle/working/yolo/seg/val/images/012762.jpg: 640x448 1 long sleeve top, 16 short sleeve tops, 15 shortss, 2 skirts, 15 trouserss, 6.6ms
# image 342/5250 /kaggle/working/yolo/seg/val/images/012830.jpg: 640x448 3 short sleeve tops, 6 shortss, 6.4ms
# image 343/5250 /kaggle/working/yolo/seg/val/images/012903.jpg: 640x512 9 long sleeve tops, 3 short sleeve tops, 2 shortss, 7.1ms
# image 344/5250 /kaggle/working/yolo/seg/val/images/012933.jpg: 640x480 12 long sleeve tops, 4 short sleeve tops, 8 shortss, 1 skirt, 19 trouserss, 7.3ms
# image 345/5250 /kaggle/working/yolo/seg/val/images/012949.jpg: 640x480 16 long sleeve tops, 19 short sleeve tops, 1 skirt, 2 trouserss, 6.6ms
# image 346/5250 /kaggle/working/yolo/seg/val/images/013040.jpg: 640x480 61 long sleeve tops, 20 short sleeve tops, 6.6ms
# image 347/5250 /kaggle/working/yolo/seg/val/images/013102.jpg: 640x512 13 short sleeve tops, 1 skirt, 7.5ms
# image 348/5250 /kaggle/working/yolo/seg/val/images/013276.jpg: 640x608 22 long sleeve tops, 1 trousers, 7.7ms
# image 349/5250 /kaggle/working/yolo/seg/val/images/013286.jpg: 640x384 16 long sleeve tops, 24 short sleeve tops, 2 shortss, 2 skirts, 5 trouserss, 7.5ms
# image 350/5250 /kaggle/working/yolo/seg/val/images/013317.jpg: 640x448 1 long sleeve top, 3 short sleeve tops, 2 shortss, 7.9ms
# image 351/5250 /kaggle/working/yolo/seg/val/images/013321.jpg: 640x448 9 short sleeve tops, 2 shortss, 4 trouserss, 7.0ms
# image 352/5250 /kaggle/working/yolo/seg/val/images/013396.jpg: 480x640 14 long sleeve tops, 5 short sleeve tops, 2 shortss, 1 trousers, 7.6ms
# image 353/5250 /kaggle/working/yolo/seg/val/images/013408.jpg: 640x640 12 long sleeve tops, 6 short sleeve tops, 2 shortss, 7.7ms
# image 354/5250 /kaggle/working/yolo/seg/val/images/013420.jpg: 640x448 1 long sleeve top, 14 short sleeve tops, 1 shorts, 2 trouserss, 7.5ms
# image 355/5250 /kaggle/working/yolo/seg/val/images/013595.jpg: 640x480 7 long sleeve tops, 15 short sleeve tops, 2 trouserss, 7.4ms
# image 356/5250 /kaggle/working/yolo/seg/val/images/013597.jpg: 640x544 12 short sleeve tops, 2 trouserss, 7.7ms
# image 357/5250 /kaggle/working/yolo/seg/val/images/013604.jpg: 640x544 8 long sleeve tops, 20 short sleeve tops, 2 trouserss, 7.4ms
# image 358/5250 /kaggle/working/yolo/seg/val/images/013636.jpg: 640x480 11 long sleeve tops, 6 short sleeve tops, 2 trouserss, 7.4ms
# image 359/5250 /kaggle/working/yolo/seg/val/images/013734.jpg: 640x480 21 long sleeve tops, 1 short sleeve top, 1 skirt, 7.6ms
# image 360/5250 /kaggle/working/yolo/seg/val/images/013762.jpg: 640x480 23 long sleeve tops, 3 short sleeve tops, 1 shorts, 14 trouserss, 6.8ms
# image 361/5250 /kaggle/working/yolo/seg/val/images/013784.jpg: 640x480 13 long sleeve tops, 30 short sleeve tops, 10 shortss, 2 trouserss, 6.7ms
# ...
# image 5135/5250 /kaggle/working/yolo/seg/val/images/188188.jpg: 640x448 2 short sleeve tops, 2 shortss, 7.3ms
# image 5136/5250 /kaggle/working/yolo/seg/val/images/188196.jpg: 480x640 34 long sleeve tops, 68 short sleeve tops, 5 shortss, 2 skirts, 4 trouserss, 7.1ms
# image 5137/5250 /kaggle/working/yolo/seg/val/images/188222.jpg: 640x640 11 long sleeve tops, 16 short sleeve tops, 9 shortss, 2 skirts, 11 trouserss, 7.3ms
# image 5138/5250 /kaggle/working/yolo/seg/val/images/188230.jpg: 640x640 24 long sleeve tops, 8 short sleeve tops, 6 shortss, 14 trouserss, 7.1ms
# image 5139/5250 /kaggle/working/yolo/seg/val/images/188256.jpg: 640x480 49 long sleeve tops, 51 short sleeve tops, 1 shorts, 16 trouserss, 7.1ms
# image 5140/5250 /kaggle/working/yolo/seg/val/images/188271.jpg: 640x480 3 short sleeve tops, 3 shortss, 6.6ms
# image 5141/5250 /kaggle/working/yolo/seg/val/images/188284.jpg: 640x384 1 long sleeve top, 1 short sleeve top, 2 trouserss, 6.9ms
# image 5142/5250 /kaggle/working/yolo/seg/val/images/188302.jpg: 640x448 7 long sleeve tops, 30 short sleeve tops, 3 shortss, 6.9ms
# image 5143/5250 /kaggle/working/yolo/seg/val/images/188304.jpg: 640x512 18 long sleeve tops, 64 short sleeve tops, 2 shortss, 1 skirt, 1 trousers, 7.2ms
# image 5144/5250 /kaggle/working/yolo/seg/val/images/188313.jpg: 640x480 22 short sleeve tops, 5 shortss, 6.9ms
# image 5145/5250 /kaggle/working/yolo/seg/val/images/188315.jpg: 416x640 39 long sleeve tops, 19 short sleeve tops, 6 shortss, 2 skirts, 7.1ms
# image 5146/5250 /kaggle/working/yolo/seg/val/images/188324.jpg: 640x448 3 short sleeve tops, 1 shorts, 1 skirt, 2 trouserss, 7.2ms
# image 5147/5250 /kaggle/working/yolo/seg/val/images/188352.jpg: 640x480 62 long sleeve tops, 123 short sleeve tops, 3 shortss, 4 skirts, 3 trouserss, 7.1ms
# image 5148/5250 /kaggle/working/yolo/seg/val/images/188353.jpg: 640x640 33 long sleeve tops, 10 short sleeve tops, 4 shortss, 13 trouserss, 7.4ms
# image 5149/5250 /kaggle/working/yolo/seg/val/images/188468.jpg: 640x480 31 long sleeve tops, 23 short sleeve tops, 11 shortss, 5 skirts, 1 trousers, 7.0ms
# image 5150/5250 /kaggle/working/yolo/seg/val/images/188496.jpg: 512x640 15 long sleeve tops, 1 short sleeve top, 1 skirt, 7.1ms
# image 5151/5250 /kaggle/working/yolo/seg/val/images/188556.jpg: 640x640 1 long sleeve top, 20 short sleeve tops, 3 shortss, 7.4ms
# image 5152/5250 /kaggle/working/yolo/seg/val/images/188575.jpg: 640x448 19 long sleeve tops, 4 trouserss, 7.0ms
# image 5153/5250 /kaggle/working/yolo/seg/val/images/188595.jpg: 640x640 1 long sleeve top, 4 short sleeve tops, 3 shortss, 1 trousers, 7.3ms
# image 5154/5250 /kaggle/working/yolo/seg/val/images/188638.jpg: 640x480 6 long sleeve tops, 48 short sleeve tops, 7.3ms
# image 5155/5250 /kaggle/working/yolo/seg/val/images/188667.jpg: 640x480 1 long sleeve top, 28 short sleeve tops, 4 trouserss, 6.8ms
# image 5156/5250 /kaggle/working/yolo/seg/val/images/188702.jpg: 640x480 8 short sleeve tops, 6 shortss, 4 skirts, 6 trouserss, 6.6ms
# image 5157/5250 /kaggle/working/yolo/seg/val/images/188748.jpg: 640x480 4 long sleeve tops, 6 short sleeve tops, 1 shorts, 1 skirt, 6.5ms
# image 5158/5250 /kaggle/working/yolo/seg/val/images/188750.jpg: 640x480 5 short sleeve tops, 1 shorts, 1 skirt, 1 trousers, 6.7ms
# image 5159/5250 /kaggle/working/yolo/seg/val/images/188796.jpg: 640x448 20 long sleeve tops, 1 short sleeve top, 1 shorts, 1 skirt, 2 trouserss, 6.9ms
# image 5160/5250 /kaggle/working/yolo/seg/val/images/188807.jpg: 640x480 14 long sleeve tops, 44 short sleeve tops, 3 shortss, 2 skirts, 2 trouserss, 7.5ms
# image 5161/5250 /kaggle/working/yolo/seg/val/images/188815.jpg: 640x640 7 short sleeve tops, 2 shortss, 6 trouserss, 7.1ms
# image 5162/5250 /kaggle/working/yolo/seg/val/images/188878.jpg: 640x448 15 long sleeve tops, 10 short sleeve tops, 2 shortss, 2 trouserss, 7.2ms
# image 5163/5250 /kaggle/working/yolo/seg/val/images/188889.jpg: 640x448 3 short sleeve tops, 1 shorts, 2 trouserss, 6.3ms
# image 5164/5250 /kaggle/working/yolo/seg/val/images/188901.jpg: 640x448 21 long sleeve tops, 6 trouserss, 8.4ms
# image 5165/5250 /kaggle/working/yolo/seg/val/images/188907.jpg: 640x480 51 long sleeve tops, 34 short sleeve tops, 1 trousers, 7.0ms
# image 5166/5250 /kaggle/working/yolo/seg/val/images/188918.jpg: 640x480 26 long sleeve tops, 1 short sleeve top, 2 shortss, 1 skirt, 2 trouserss, 6.6ms
# image 5167/5250 /kaggle/working/yolo/seg/val/images/188931.jpg: 576x640 17 long sleeve tops, 12 short sleeve tops, 4 trouserss, 7.0ms
# image 5168/5250 /kaggle/working/yolo/seg/val/images/189019.jpg: 480x640 21 short sleeve tops, 2 shortss, 2 trouserss, 6.9ms
# image 5169/5250 /kaggle/working/yolo/seg/val/images/189061.jpg: 640x448 22 long sleeve tops, 4 trouserss, 7.1ms
# image 5170/5250 /kaggle/working/yolo/seg/val/images/189067.jpg: 640x384 8 long sleeve tops, 14 short sleeve tops, 7.1ms
# image 5171/5250 /kaggle/working/yolo/seg/val/images/189131.jpg: 608x640 13 long sleeve tops, 21 short sleeve tops, 4 trouserss, 7.0ms
# image 5172/5250 /kaggle/working/yolo/seg/val/images/189187.jpg: 640x448 4 short sleeve tops, 1 skirt, 7.0ms
# image 5173/5250 /kaggle/working/yolo/seg/val/images/189229.jpg: 640x640 1 long sleeve top, 24 short sleeve tops, 2 shortss, 4 skirts, 1 trousers, 7.3ms
# image 5174/5250 /kaggle/working/yolo/seg/val/images/189247.jpg: 640x640 3 short sleeve tops, 2 shortss, 1 skirt, 2 trouserss, 6.8ms
# image 5175/5250 /kaggle/working/yolo/seg/val/images/189258.jpg: 640x640 10 short sleeve tops, 4 shortss, 2 skirts, 5 trouserss, 6.8ms
# image 5176/5250 /kaggle/working/yolo/seg/val/images/189326.jpg: 416x640 24 long sleeve tops, 14 short sleeve tops, 7 shortss, 4 trouserss, 7.2ms
# image 5177/5250 /kaggle/working/yolo/seg/val/images/189362.jpg: 640x640 37 long sleeve tops, 35 shortss, 4 skirts, 13 trouserss, 7.3ms
# image 5178/5250 /kaggle/working/yolo/seg/val/images/189412.jpg: 640x448 11 long sleeve tops, 3 short sleeve tops, 2 shortss, 6.9ms
# image 5179/5250 /kaggle/working/yolo/seg/val/images/189421.jpg: 640x448 6 long sleeve tops, 3 short sleeve tops, 2 trouserss, 6.4ms
# image 5180/5250 /kaggle/working/yolo/seg/val/images/189480.jpg: 640x448 18 long sleeve tops, 5 short sleeve tops, 1 trousers, 6.6ms
# image 5181/5250 /kaggle/working/yolo/seg/val/images/189487.jpg: 640x448 11 long sleeve tops, 5 short sleeve tops, 1 shorts, 13 trouserss, 6.2ms
# image 5182/5250 /kaggle/working/yolo/seg/val/images/189517.jpg: 640x448 9 short sleeve tops, 1 shorts, 2 skirts, 1 trousers, 6.3ms
# image 5183/5250 /kaggle/working/yolo/seg/val/images/189622.jpg: 640x640 32 long sleeve tops, 1 shorts, 1 skirt, 4 trouserss, 7.3ms
# image 5184/5250 /kaggle/working/yolo/seg/val/images/189632.jpg: 640x544 1 long sleeve top, 4 short sleeve tops, 1 skirt, 1 trousers, 7.4ms
# image 5185/5250 /kaggle/working/yolo/seg/val/images/189667.jpg: 640x480 23 long sleeve tops, 39 short sleeve tops, 3 shortss, 5 trouserss, 8.8ms
# image 5186/5250 /kaggle/working/yolo/seg/val/images/189801.jpg: 640x480 42 long sleeve tops, 35 short sleeve tops, 14 shortss, 3 skirts, 7.4ms
# image 5187/5250 /kaggle/working/yolo/seg/val/images/189815.jpg: 640x416 60 long sleeve tops, 27 short sleeve tops, 1 shorts, 1 skirt, 20 trouserss, 8.1ms
# image 5188/5250 /kaggle/working/yolo/seg/val/images/189912.jpg: 640x480 43 long sleeve tops, 8 short sleeve tops, 1 skirt, 1 trousers, 7.4ms
# image 5189/5250 /kaggle/working/yolo/seg/val/images/189948.jpg: 640x640 26 long sleeve tops, 28 short sleeve tops, 7 shortss, 3 trouserss, 7.3ms
# image 5190/5250 /kaggle/working/yolo/seg/val/images/189985.jpg: 448x640 20 long sleeve tops, 2 trouserss, 7.2ms
# image 5191/5250 /kaggle/working/yolo/seg/val/images/190025.jpg: 416x640 31 long sleeve tops, 5 short sleeve tops, 6 shortss, 3 skirts, 15 trouserss, 6.9ms
# image 5192/5250 /kaggle/working/yolo/seg/val/images/190049.jpg: 640x448 9 long sleeve tops, 7 short sleeve tops, 3 trouserss, 7.0ms
# image 5193/5250 /kaggle/working/yolo/seg/val/images/190052.jpg: 640x448 12 long sleeve tops, 9 short sleeve tops, 6.4ms
# image 5194/5250 /kaggle/working/yolo/seg/val/images/190067.jpg: 640x448 5 long sleeve tops, 9 short sleeve tops, 3 shortss, 6.5ms
# image 5195/5250 /kaggle/working/yolo/seg/val/images/190070.jpg: 640x448 8 long sleeve tops, 7 short sleeve tops, 2 shortss, 1 skirt, 6.5ms
# image 5196/5250 /kaggle/working/yolo/seg/val/images/190169.jpg: 640x448 9 short sleeve tops, 2 shortss, 6.4ms
# image 5197/5250 /kaggle/working/yolo/seg/val/images/190170.jpg: 640x448 38 short sleeve tops, 28 shortss, 1 skirt, 3 trouserss, 6.4ms
# image 5198/5250 /kaggle/working/yolo/seg/val/images/190212.jpg: 640x544 10 long sleeve tops, 4 short sleeve tops, 3 shortss, 8 trouserss, 7.4ms
# image 5199/5250 /kaggle/working/yolo/seg/val/images/190284.jpg: 640x512 15 long sleeve tops, 2 shortss, 7.2ms
# image 5200/5250 /kaggle/working/yolo/seg/val/images/190299.jpg: 640x416 3 short sleeve tops, 1 skirt, 7.0ms
# image 5201/5250 /kaggle/working/yolo/seg/val/images/190320.jpg: 640x640 5 short sleeve tops, 2 trouserss, 7.2ms
# image 5202/5250 /kaggle/working/yolo/seg/val/images/190357.jpg: 640x448 1 long sleeve top, 5 short sleeve tops, 2 shortss, 1 skirt, 4 trouserss, 7.0ms
# image 5203/5250 /kaggle/working/yolo/seg/val/images/190374.jpg: 640x448 3 long sleeve tops, 4 short sleeve tops, 2 shortss, 1 skirt, 6.5ms
# image 5204/5250 /kaggle/working/yolo/seg/val/images/190389.jpg: 640x384 2 long sleeve tops, 8 short sleeve tops, 1 skirt, 1 trousers, 7.1ms
# image 5205/5250 /kaggle/working/yolo/seg/val/images/190391.jpg: 640x480 9 long sleeve tops, 35 short sleeve tops, 2 shortss, 3 skirts, 33 trouserss, 7.1ms
# image 5206/5250 /kaggle/working/yolo/seg/val/images/190404.jpg: 640x640 5 long sleeve tops, 31 short sleeve tops, 2 skirts, 16 trouserss, 7.3ms
# image 5207/5250 /kaggle/working/yolo/seg/val/images/190465.jpg: 640x448 8 long sleeve tops, 3 short sleeve tops, 5 skirts, 4 trouserss, 6.8ms
# image 5208/5250 /kaggle/working/yolo/seg/val/images/190589.jpg: 640x512 7 long sleeve tops, 10 short sleeve tops, 7 shortss, 6.8ms
# image 5209/5250 /kaggle/working/yolo/seg/val/images/190728.jpg: 640x480 49 long sleeve tops, 24 short sleeve tops, 6 shortss, 9 trouserss, 6.8ms
# image 5210/5250 /kaggle/working/yolo/seg/val/images/190745.jpg: 640x480 6 long sleeve tops, 17 short sleeve tops, 2 shortss, 39 trouserss, 6.3ms
# image 5211/5250 /kaggle/working/yolo/seg/val/images/190779.jpg: 640x480 5 short sleeve tops, 2 shortss, 1 skirt, 6.5ms
# image 5212/5250 /kaggle/working/yolo/seg/val/images/190791.jpg: 640x544 2 short sleeve tops, 2 shortss, 7.0ms
# image 5213/5250 /kaggle/working/yolo/seg/val/images/190889.jpg: 640x448 3 long sleeve tops, 11 short sleeve tops, 1 shorts, 39 trouserss, 6.8ms
# image 5214/5250 /kaggle/working/yolo/seg/val/images/191006.jpg: 640x480 1 long sleeve top, 9 short sleeve tops, 3 shortss, 6.9ms
# image 5215/5250 /kaggle/working/yolo/seg/val/images/191022.jpg: 640x448 9 short sleeve tops, 2 shortss, 1 skirt, 7.5ms
# image 5216/5250 /kaggle/working/yolo/seg/val/images/191058.jpg: 512x640 12 long sleeve tops, 3 trouserss, 7.2ms
# image 5217/5250 /kaggle/working/yolo/seg/val/images/191123.jpg: 576x640 1 long sleeve top, 15 short sleeve tops, 2 trouserss, 7.2ms
# image 5218/5250 /kaggle/working/yolo/seg/val/images/191198.jpg: 640x512 4 short sleeve tops, 3 shortss, 3 trouserss, 7.3ms
# image 5219/5250 /kaggle/working/yolo/seg/val/images/191203.jpg: 640x480 8 long sleeve tops, 4 shortss, 2 skirts, 10 trouserss, 7.2ms
# image 5220/5250 /kaggle/working/yolo/seg/val/images/191206.jpg: 640x480 13 long sleeve tops, 1 short sleeve top, 2 skirts, 2 trouserss, 6.5ms
# image 5221/5250 /kaggle/working/yolo/seg/val/images/191209.jpg: 640x512 1 long sleeve top, 3 short sleeve tops, 2 shortss, 1 skirt, 2 trouserss, 7.0ms
# image 5222/5250 /kaggle/working/yolo/seg/val/images/191240.jpg: 640x448 2 long sleeve tops, 4 short sleeve tops, 4 trouserss, 6.9ms
# image 5223/5250 /kaggle/working/yolo/seg/val/images/191257.jpg: 640x640 7 long sleeve tops, 8 short sleeve tops, 7 shortss, 20 trouserss, 7.4ms
# image 5224/5250 /kaggle/working/yolo/seg/val/images/191293.jpg: 640x384 18 long sleeve tops, 5 short sleeve tops, 2 shortss, 6.8ms
# image 5225/5250 /kaggle/working/yolo/seg/val/images/191299.jpg: 640x480 117 long sleeve tops, 18 short sleeve tops, 5 shortss, 4 skirts, 14 trouserss, 7.3ms
# image 5226/5250 /kaggle/working/yolo/seg/val/images/191321.jpg: 640x640 4 short sleeve tops, 11 shortss, 1 skirt, 2 trouserss, 7.3ms
# image 5227/5250 /kaggle/working/yolo/seg/val/images/191339.jpg: 640x640 6 long sleeve tops, 2 short sleeve tops, 1 shorts, 30 trouserss, 6.7ms
# image 5228/5250 /kaggle/working/yolo/seg/val/images/191349.jpg: 640x640 36 long sleeve tops, 22 short sleeve tops, 5 shortss, 2 skirts, 23 trouserss, 6.7ms
# image 5229/5250 /kaggle/working/yolo/seg/val/images/191351.jpg: 640x448 10 long sleeve tops, 2 short sleeve tops, 1 shorts, 1 skirt, 6.9ms
# image 5230/5250 /kaggle/working/yolo/seg/val/images/191429.jpg: 640x608 34 long sleeve tops, 6 short sleeve tops, 1 shorts, 2 trouserss, 7.3ms
# image 5231/5250 /kaggle/working/yolo/seg/val/images/191431.jpg: 640x480 15 long sleeve tops, 6 short sleeve tops, 2 skirts, 3 trouserss, 9.5ms
# image 5232/5250 /kaggle/working/yolo/seg/val/images/191455.jpg: 640x448 14 long sleeve tops, 2 trouserss, 7.1ms
# image 5233/5250 /kaggle/working/yolo/seg/val/images/191478.jpg: 640x640 58 long sleeve tops, 7 short sleeve tops, 2 shortss, 9.4ms
# image 5234/5250 /kaggle/working/yolo/seg/val/images/191517.jpg: 640x448 1 long sleeve top, 17 short sleeve tops, 3 shortss, 1 skirt, 6.9ms
# image 5235/5250 /kaggle/working/yolo/seg/val/images/191528.jpg: 640x480 1 long sleeve top, 22 short sleeve tops, 10 shortss, 5 skirts, 7.1ms
# image 5236/5250 /kaggle/working/yolo/seg/val/images/191536.jpg: 640x480 23 long sleeve tops, 10 short sleeve tops, 20 shortss, 4 trouserss, 6.5ms
# image 5237/5250 /kaggle/working/yolo/seg/val/images/191590.jpg: 640x448 3 short sleeve tops, 2 trouserss, 6.8ms
# image 5238/5250 /kaggle/working/yolo/seg/val/images/191651.jpg: 640x576 3 short sleeve tops, 2 shortss, 7.6ms
# image 5239/5250 /kaggle/working/yolo/seg/val/images/191659.jpg: 640x640 4 long sleeve tops, 3 short sleeve tops, 3 shortss, 8.1ms
# image 5240/5250 /kaggle/working/yolo/seg/val/images/191707.jpg: 640x448 12 long sleeve tops, 2 shortss, 7.2ms
# image 5241/5250 /kaggle/working/yolo/seg/val/images/191742.jpg: 640x480 44 long sleeve tops, 7 short sleeve tops, 5 skirts, 1 trousers, 7.0ms
# image 5242/5250 /kaggle/working/yolo/seg/val/images/191748.jpg: 640x480 30 long sleeve tops, 5 short sleeve tops, 1 skirt, 4 trouserss, 6.4ms
# image 5243/5250 /kaggle/working/yolo/seg/val/images/191795.jpg: 640x480 3 long sleeve tops, 18 short sleeve tops, 2 shortss, 6.4ms
# image 5244/5250 /kaggle/working/yolo/seg/val/images/191797.jpg: 640x448 14 short sleeve tops, 2 shortss, 7.0ms
# image 5245/5250 /kaggle/working/yolo/seg/val/images/191819.jpg: 640x384 10 long sleeve tops, 21 short sleeve tops, 6 shortss, 1 skirt, 12 trouserss, 6.9ms
# image 5246/5250 /kaggle/working/yolo/seg/val/images/191858.jpg: 640x384 30 long sleeve tops, 13 short sleeve tops, 1 skirt, 1 trousers, 6.3ms
# image 5247/5250 /kaggle/working/yolo/seg/val/images/191891.jpg: 640x448 15 short sleeve tops, 1 shorts, 1 skirt, 6 trouserss, 7.0ms
# image 5248/5250 /kaggle/working/yolo/seg/val/images/191901.jpg: 640x448 5 long sleeve tops, 6 short sleeve tops, 1 trousers, 6.6ms
# image 5249/5250 /kaggle/working/yolo/seg/val/images/191918.jpg: 640x448 20 long sleeve tops, 2 shortss, 1 trousers, 6.4ms
# image 5250/5250 /kaggle/working/yolo/seg/val/images/191919.jpg: 640x448 29 long sleeve tops, 4 short sleeve tops, 3 trouserss, 6.6ms
# Speed: 2.1ms preprocess, 7.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 448)
# Cached 5250 images
# /tmp/ipykernel_23/863281686.py:109: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   roc_auc = float(np.trapz(all_tpr[idx], all_fpr[idx]))

# %%
def compute_metrics(y_true, y_pred, num_classes=6):

    iou_list = []
    dice_list = []

    for cls in range(1,num_classes):

        intersection = 0
        union = 0
        pred_area = 0
        gt_area = 0

        for gt, pred in zip(y_true, y_pred):

            gt_mask = (gt == cls)
            pred_mask = (pred == cls)

            intersection += np.logical_and(gt_mask, pred_mask).sum()
            union += np.logical_or(gt_mask, pred_mask).sum()

            pred_area += pred_mask.sum()
            gt_area += gt_mask.sum()

        iou = intersection / (union + 1e-16)
        dice = (2 * intersection) / (pred_area + gt_area + 1e-16)

        iou_list.append(iou)
        dice_list.append(dice)

    return iou_list, dice_list, np.mean(iou_list), np.mean(dice_list)

# %%
iou_list, dice_list, mean_iou, mean_dice = compute_metrics(y_true, y_pred)

print("\n" + "="*50)
print("🧵 SEGMENTATION PERFORMANCE")
print("="*50)

for i, cls in enumerate(classes_bg[1:],start=1):
    print(f"{cls:20} | IoU: {iou_list[i-1]:.4f} | Dice(F1): {dice_list[i-1]:.4f}")

print("\n" + "-"*50)
print(f"Mean IoU (mIoU): {mean_iou:.4f}")
print(f"Mean Dice (F1):  {mean_dice:.4f}")
# Out:
# ==================================================
# 🧵 SEGMENTATION PERFORMANCE
# ==================================================
# long sleeve top      | IoU: 0.5592 | Dice(F1): 0.7173
# short sleeve top     | IoU: 0.6877 | Dice(F1): 0.8150
# shorts               | IoU: 0.6729 | Dice(F1): 0.8045
# skirt                | IoU: 0.6315 | Dice(F1): 0.7742
# trousers             | IoU: 0.6753 | Dice(F1): 0.8062
#
# --------------------------------------------------
# Mean IoU (mIoU): 0.6453
# Mean Dice (F1):  0.7834
